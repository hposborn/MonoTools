# %% [markdown]
# ## NamastePymc3 examples
#
# All this code leans hevily on Dan Foreman-Mackey's exoplanet project (http://github.com/dfm/exoplanet), specifically the K2-3 example.

# %%
# Importing the important things:

import numpy as np
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
# %matplotlib inline
import pymc3 as pm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from stellar import starpars

# %%
import NamastePymc3 as namaste

# %% [markdown]
# # TESS example: TIC 128703021
#
# Running on a TESS example, TIC128703021 (this will download the lightcurve).
#
# The inputs here are:
# * list of: initial depths (600ppm)
# * list of: initial t0s (1601.85)
# * stellar dictionary with stellar radius, density, Teff and logg (from spctra/Gaia DR2 in this case)
# * We specify the mission
# * We LoadFromFile (works if there is already a pickled Pymc3 output present - if not, run from scratch)

# %%
# %matplotlib inline

# %%
#Here is the lightcurve:
plt.figure(2,figsize=(20,8))
lc,hdr=namaste.TESS_lc(413432205)
import hpo.planetlib as pl
plt.plot(lc['time'],lc['flux'],'.')
blc=pl.BinLC(np.column_stack((lc['time'][lc['mask']],lc['flux'][lc['mask']],lc['flux_err'][lc['mask']])),1/48)
plt.plot(blc[:,0],blc[:,1],'.')
# Out:
# TESS file
# 19104 18939
# 18939 18939

# %%
plt.figure(3,figsize=(20,8))

plt.plot(lc['time'],lc['flux'],'.')
blc=pl.BinLC(np.column_stack((lc['time'][lc['mask']],lc['flux'][lc['mask']],lc['flux_err'][lc['mask']])),1/48)
plt.plot(blc[:,0],blc[:,1])
plt.xlim(1628,1631)
plt.ylim(-10,6)
# Out:
# (-10, 6)

# %%
dict_out=namaste.Run(128703021, [600e-6], [1601.85],
                        stellardict={'Rs':1.54,'Rs_err':0.18,
                                     'rho_s':0.34872195*1.408,'rho_s_err':(0.08052529*1.408, 0.11735043*1.408),
                                     'Teff':6216,'Teff_err':100,
                                     'logg':4.16,'logg_err':0.12},
                        mission='TESS',LoadFromFile=False,cutDistance=10,n_draws=500)
# Out:
# ['/Users/hosborn/Postdoc/NamastePymc3/TIC00128703021/TIC00128703021_2019-12-06_0_mcmc.pickle', '/Users/hosborn/Postdoc/NamastePymc3/TIC00128703021/TIC00128703021_mcmc.pickle']
# loading from /Users/hosborn/Postdoc/NamastePymc3/TIC00128703021/TIC00128703021.lc
# Initialising transit model
# [1596.77673917 1596.77812809 1596.77951701 ... 1623.89371288 1623.89510176
#  1623.89649063] <class 'numpy.ndarray'> <class 'numpy.float64'>
# Teff: [6216  100  100]
# [1601.85]
# 119.99544021557205 [ 7.77979891  8.03396701  8.28813512  8.54230323  8.79647134  9.05063945
#   9.30480756  9.55897567  9.81314377 10.06731188 10.32147999 10.5756481
#  10.82981621 11.08398432 11.33815243 11.59232053 11.84648864 12.10065675
#  12.35482486 22.04649063]
# 9452 points cut from lightcurve leaving 10075 to process
# Using minimum period(s) of: [7.77979891]
# contrain LDs -  6216 100 4.16 0.12 0.0 1200 [0.33792893 0.21657812] [0.05 0.05]
# Rs __str__ = [1.54]
# RpRs __str__ = [0.0244949]
# u_star __str__ = [0.33792893 0.21657812]
# r_pl __str__ = [0.03772214]
# [7.77979891] t0 <class 'numpy.ndarray'> [1599.95737721 1599.95876614 1599.96432184 1599.96571077 1599.96987754
#  1599.97126647 1599.97265539 1599.97404432 1599.97543324 1599.97960002] 0.0013889181013837515
# optimizing logp for variables: [rb]
# 17it [00:01, 12.78it/s, logp=-2.008933e+03]
# message: Optimization terminated successfully.
# logp: -2058.797744396849 -> -2008.9333717838085
# optimizing logp for variables: [logs2]
# 9it [00:01,  6.87it/s, logp=8.289719e+02]
# message: Optimization terminated successfully.
# logp: -2008.9333717838076 -> 828.9718948080022
# optimizing logp for variables: [t0, P_index]
# 16it [00:02,  7.11it/s, logp=8.376118e+02]
# message: Optimization terminated successfully.
# logp: 828.9718948080003 -> 837.6117937719475
# optimizing logp for variables: [logpower, logs2]
# 10it [00:01,  7.65it/s, logp=8.376227e+02]
# message: Optimization terminated successfully.
# logp: 837.6117937719494 -> 837.6226654067461
# optimizing logp for variables: [logw0]
# 7it [00:02,  3.00it/s, logp=8.376229e+02]
# message: Optimization terminated successfully.
# logp: 837.6226654067461 -> 837.6228557234144
# optimizing logp for variables: [logpower, logw0, logs2, u_star, omega, ecc, rb, P_index, t0, deltamag_contam, mean, Rs, logrho_S]
# 110it [00:01, 55.01it/s, logp=8.681820e+02]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 837.6228557234126 -> 868.1817439566695
# logrho_S                      0.34
# Rs                            0.80
# mean                         -0.92
# deltamag_contam_interval__   -1.39
# t0                           -0.92
# P_index_logodds__            -7.30
# rb_radiusimpact__            -5.48
# ecc_interval__               -1.47
# omega_angle__                -0.50
# u_star_interval__             0.88
# logs2_interval__             -1.39
# logw0_interval__             -1.39
# logpower_interval__          -1.39
# Name: Log-probability of test_point, dtype: float64
# Model loaded
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [logpower, logw0, logs2, u_star, omega, ecc, rb, P_index, t0, deltamag_contam, mean, Rs, logrho_S]
# Sampling 4 chains: 100%|██████████| 3320/3320 [43:39<00:00,  1.27draws/s]
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The acceptance probability does not match the target. It is 0.8121384498170315, but should be close to 0.9. Try to increase the number of tuning steps.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# There were 38 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8135236969356432, but should be close to 0.9. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8070352754033759, but should be close to 0.9. Try to increase the number of tuning steps.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# 878 ( 43 ) removed due to period gap cuts
# plotting
# ---------
# ValueErrorTraceback (most recent call last)
# <ipython-input-22-898d17dc8c6a> in <module>
#       4                                      'Teff':6216,'Teff_err':100,
#       5                                      'logg':4.16,'logg_err':0.12},
# ----> 6                         mission='TESS',LoadFromFile=False,cutDistance=10,n_draws=500)
#
# ~/Postdoc/NamastePymc3/NamastePymc3.py in Run(ID, initdepth, initt0, mission, stellardict, n_draws, overwrite, LoadFromFile, savefileloc, doplots, do_per_gap_cuts, **kwargs)
#     754     if doplots:
#     755         print("plotting")
# --> 756         PlotLC(lc, trace, ID, mission=mission, savename=savenames[0].replace('mcmc.pickle','TransitFit.png'), lcmask=lcmask,tracemask=tracemask)
#     757         PlotCorner(trace, ID, mission=mission, savename=savenames[0].replace('mcmc.pickle','corner.png'),tracemask=tracemask)
#     758
#
# ~/Postdoc/NamastePymc3/NamastePymc3.py in PlotLC(lc, trace, ID, mission, savename, overwrite, savefileloc, returnfig, lcmask, tracemask, zoom_plot_time)
#    1026
#    1027     if 'mult' in trace.varnames:
# -> 1028         pred = trace["light_curves"][tracemask,:,:]/np.tile(trace['mult'],(1,len(trace["light_curves"][0,:,0]),1)).swapaxes(0,2)
#    1029     else:
#    1030         pred = trace["light_curves"][tracemask,:,:]
#
# ValueError: operands could not be broadcast together with shapes (1122,6850,1) (2000,6850,1)

# %%
2457000+1601.85
# Out:
# 2458601.85

# %%
dict_out=namaste.Run(128703021, [600e-6], [1601.85],
                        stellardict={'Rs':1.54,'Rs_err':0.18,
                                     'rho_s':0.34872195*1.408,'rho_s_err':(0.08052529*1.408, 0.11735043*1.408),
                                     'Teff':6216,'Teff_err':100,
                                     'logg':4.16,'logg_err':0.12},
                        mission='TESS',LoadFromFile=True,
                        cutDistance=10,n_draws=500,overwrite=True)
# Out:
# ['/Users/hosborn/Postdoc/NamastePymc3/TIC00128703021/TIC00128703021_2019-11-28_0_mcmc.pickle', '/Users/hosborn/Postdoc/NamastePymc3/TIC00128703021/TIC00128703021_mcmc.pickle']
# TESS file
# 13887 13836
# 13836 13836
# Initialising transit model
# [1596.77673917 1596.77812809 1596.77951701 ... 1623.89371288 1623.89510176
#  1623.89649063] <class 'numpy.ndarray'> <class 'numpy.float64'>
# Teff: [6216  100  100]
# [1601.85]
# 119.99544021557205 [ 7.77979891  8.03396701  8.28813512  8.54230323  8.79647134  9.05063945
#   9.30480756  9.55897567  9.81314377 10.06731188 10.32147999 10.5756481
#  10.82981621 11.08398432 11.33815243 11.59232053 11.84648864 12.10065675
#  12.35482486 22.04649063]
# 9452 points cut from lightcurve leaving 10075 to process
# Using minimum period(s) of: [7.77979891]
# contrain LDs -  6216 100 4.16 0.12 0.0 1200 [0.3382301  0.21671385] [0.05 0.05]
# Rs __str__ = [1.54]
# RpRs __str__ = [0.0244949]
# u_star __str__ = [0.3382301  0.21671385]
# r_pl __str__ = [0.03772214]
# [7.77979891] t0 [1599.95737721 1599.95876614 1599.96432184 1599.96571077 1599.96987754
#  1599.97126647 1599.97265539 1599.97404432 1599.97543324 1599.97960002] 0.0013889181013837515
# ---------
# KeyErrorTraceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/theano/tensor/type.py in dtype_specs(self)
#     268                 'complex64': (complex, 'theano_complex64', 'NPY_COMPLEX64')
# --> 269             }[self.dtype]
#     270         except KeyError:
#
# KeyError: '>f8'
#
# During handling of the above exception, another exception occurred:
#
# TypeErrorTraceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/theano/tensor/basic.py in constant(x, name, ndim, dtype)
#     245     try:
# --> 246         ttype = TensorType(dtype=x_.dtype, broadcastable=bcastable)
#     247         if not constant.enable:
#
# ~/anaconda3/lib/python3.7/site-packages/theano/tensor/type.py in __init__(self, dtype, broadcastable, name, sparse_grad)
#      50         self.broadcastable = tuple(bool(b) for b in broadcastable)
# ---> 51         self.dtype_specs()  # error checking is done there
#      52         self.name = name
#
# ~/anaconda3/lib/python3.7/site-packages/theano/tensor/type.py in dtype_specs(self)
#     271             raise TypeError("Unsupported dtype for %s: %s"
# --> 272                             % (self.__class__.__name__, self.dtype))
#     273
#
# TypeError: Unsupported dtype for TensorType: >f8
#
# During handling of the above exception, another exception occurred:
#
# TypeErrorTraceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/theano/tensor/basic.py in as_tensor_variable(x, name, ndim)
#     193     try:
# --> 194         return constant(x, name=name, ndim=ndim)
#     195     except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/theano/tensor/basic.py in constant(x, name, ndim, dtype)
#     265     except Exception:
# --> 266         raise TypeError("Could not convert %s to TensorType" % x, type(x))
#     267
#
# TypeError: ('Could not convert [1599.95737721 1599.95876614 1599.96432184 ... 1609.6270211  1609.62841\n 1609.62979891] to TensorType', <class 'numpy.ndarray'>)
#
# During handling of the above exception, another exception occurred:
#
# AsTensorErrorTraceback (most recent call last)
# <ipython-input-19-a198b2d1d562> in <module>
#       5                                      'logg':4.16,'logg_err':0.12},
#       6                         mission='TESS',LoadFromFile=True,
# ----> 7                         cutDistance=10,n_draws=500,overwrite=True)
#
# ~/Postdoc/NamastePymc3/NamastePymc3.py in Run(ID, initdepth, initt0, mission, stellardict, n_draws, overwrite, LoadFromFile, savefileloc, doplots, do_per_gap_cuts, **kwargs)
#     713     model, soln, lcmask, P_gap_cuts = init_model(lc['time'], lc['flux'],lc['flux_err'],
#     714                                                  initdepth, initt0, Rstar, rhostar, Teff,
# --> 715                                                  lcmask=lc['mask'], logg=logg, **kwargs)
#     716     #initdur=None,n_pl=1,periods=None,per_index=-8/3,
#     717     #assume_circ=False,use_GP=True,constrain_LD=True,ld_mult=1.5,
#
# ~/Postdoc/NamastePymc3/NamastePymc3.py in init_model(x, y, yerr, initdepth, initt0, Rstar, rhostar, Teff, lcmask, logg, initdur, periods, per_index, assume_circ, use_GP, constrain_LD, ld_mult, useL2, mission, FeH, LoadFromFile, cutDistance)
#     538         print(P_min,t0,x[totalmask][:10],np.nanmedian(np.diff(x[totalmask])))
#     539         # Compute the model light curve using starry
# --> 540         light_curves = xo.LimbDarkLightCurve(u_star).get_light_curve(orbit=orbit, r=r_pl,t=x[totalmask])*1e3
#     541         light_curve = pm.math.sum(light_curves, axis=-1)
#     542         pm.Deterministic("light_curves", light_curves)
#
# ~/anaconda3/lib/python3.7/site-packages/exoplanet/light_curves.py in get_light_curve(self, orbit, r, t, texp, oversample, order, use_in_transit)
#      96         r = tt.as_tensor_variable(r)
#      97         r = tt.reshape(r, (r.size,))
# ---> 98         t = tt.as_tensor_variable(t)
#      99
#     100         if use_in_transit:
#
# ~/anaconda3/lib/python3.7/site-packages/theano/tensor/basic.py in as_tensor_variable(x, name, ndim)
#     198         except Exception:
#     199             str_x = repr(x)
# --> 200         raise AsTensorError("Cannot convert %s to TensorType" % str_x, type(x))
#     201
#     202 # this has a different name, because _as_tensor_variable is the
#
# AsTensorError: ('Cannot convert [1599.95737721 1599.95876614 1599.96432184 ... 1609.6270211  1609.62841\n 1609.62979891] to TensorType', <class 'numpy.ndarray'>)

# %%
import pickle
model=pickle.load(open("TIC00128703021/TIC00128703021_2019-11-28_0_mcmc.pickle",'rb'))

# %%
plt.hist(model['period'][:,0])
# Out:
# (array([1.32e+03, 4.41e+02, 1.44e+02, 5.00e+01, 2.60e+01, 1.20e+01,
#         3.00e+00, 1.00e+00, 1.00e+00, 2.00e+00]),
#  array([ 8.00622763, 16.59296561, 25.17970358, 33.76644155, 42.35317953,
#         50.9399175 , 59.52665547, 68.11339345, 76.70013142, 85.28686939,
#         93.87360737]),
#  <a list of 10 Patch objects>)

# %%
namaste.PlotCorner(dict_out['trace'],128703021, mission='TESS',tracemask=dict_out['tracemask'],varnames=['b', 'ecc', 'logp', 'r_pl', 'u_star', 'vrel'])
# Out:
# ---------
# NameErrorTraceback (most recent call last)
# <ipython-input-8-e01e80f45d94> in <module>
# ----> 1 namaste.PlotCorner(dict_out['trace'],128703021, LoadFromFile=True,overwrite=False,
#       2                    mission='TESS',tracemask=dict_out['tracemask'],
#       3                    varnames=['b', 'ecc', 'logp', 'r_pl', 'u_star', 'vrel'])
#
# NameError: name 'dict_out' is not defined

# %%
namaste.PlotLC(dict_out['light_curve'], dict_out['trace'], 128703021, mission='TESS',tracemask=dict_out['tracemask'])
# Out:
# -------------------------------
# AssertionErrorTraceback (most recent call last)
# <ipython-input-16-09f38c3d1c4f> in <module>
# ----> 1 namaste.PlotLC(dict_out['light_curve'], dict_out['trace'], 128703021, mission='TESS',tracemask=dict_out['tracemask'])
#       2
#       3
#
# ~/Postdoc/NamastePymc3/NamastePymc3.py in PlotLC(lc, trace, ID, mission, savename, overwrite, savefileloc, returnfig, lcmask, tracemask)
#    1115
#    1116     if lcmask is None:
# -> 1117         assert len(lc['time'])==len(trace['gp_pred'][0,:])
#    1118         lcmask=np.tile(True,len(lc['time']))
#    1119
#
# AssertionError:

# %%
namaste.PlotCorner(dict_out['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %%
# Out:
# 0.039810717055349734

# %%
print("running")
# Out:
# running

# %% [markdown]
# # K2 example: EPIC 248847494
#
# As above. With added keywords:
# * `initdur` is a list of initial durations. This is needed here as the inital fits are poor due to the extreme long duration of this object.
# * `cutDistance` - how far from the transit to cut the lightcurve (in order to speed up processing)
# * `overwrite` - overwrites files
# * `doplots` - Whether to output & save plots of transit and corner

# %%
out_dict_k2=namaste.Run(248847494, [1.5e-3], [3134.3],
                        stellardict={'Rs':2.70,'Rs_err':0.12,
                                     'rho_s': 0.064,'rho_s_err':0.007,
                                     'Teff':4898,'Teff_err':68,
                                     'logg':3.52,'logg_err':0.1},doplots=True,
                        mission='K2',cutDistance=5.0,overwrite=True,initdur=[2.1],
                        n_draws=500,constrain_LD=True)

# %%
out_dict_k2=namaste.Run(248847494, [1.5e-3], [3134.3],
                        stellardict={'Rs':2.70,'Rs_err':0.12,
                                     'rho_s': 0.064,'rho_s_err':0.007,
                                     'Teff':4898,'Teff_err':68,
                                     'logg':3.52,'logg_err':0.1},doplots=True,
                        mission='K2',cutDistance=5.0,overwrite=True,initdur=[2.1],
                        n_draws=500,constrain_LD=True)
# Out:
# DEBUG [urllib3.connectionpool._new_conn()]: Starting new HTTPS connection (1): exofop.ipac.caltech.edu:443
# DEBUG [urllib3.connectionpool._make_request()]: https://exofop.ipac.caltech.edu:443 "GET /k2/download_target.php?id=248847494 HTTP/1.1" 200 4433
# K2 campaigns to search: 14
# INFO  [everest.user.DownloadFile()]: Found cached file.
# INFO  [everest.user.load_fits()]: Loading FITS file for 248847494.
# Initialising transit model
# [3072.72831697 3072.74874933 3072.76918168 ... 3152.37160894 3152.39204067
#  3152.41247259] <class 'numpy.ndarray'> <class 'numpy.float64'>
# Teff: [4898   68   68]
# 1103.2130095064515 [61.57168303]
# Using minimum period(s) of: [61.57168303]
# contrain LDs -  4898 68 3.52 0.1 0.0 1200 [0.44545451 0.20364499] [0.05 0.05]
# Rs __str__ = [2.7]
# RpRs __str__ = [0.03872983]
# u_star __str__ = [0.44545451 0.20364499]
# r_pl __str__ = [0.10457055]
# [61.57168303] t0 [3072.72831697 3072.74874933 3072.76918168 3072.78961414 3072.81004639
#  3072.83047875 3072.8509111  3072.87134345 3072.8917758  3072.91220815] 0.020431775654287776
# optimizing logp for variables: ['rb_radiusimpact__']
# message: Optimization terminated successfully.
# logp: -8028.769360313421 -> -7867.402172037065
# optimizing logp for variables: ['logs2_interval__']
# message: Optimization terminated successfully.
# logp: -7867.402172037065 -> -7504.334571553671
# optimizing logp for variables: ['t0', 'P_index_logodds__']
# message: Optimization terminated successfully.
# logp: -7504.334571553671 -> -7497.808496198085
# optimizing logp for variables: ['logpower_interval__', 'logs2_interval__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: -7497.808496198085 -> -7302.208146546384
# optimizing logp for variables: ['logw0_interval__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: -7302.208146546384 -> -5491.515336938507
# optimizing logp for variables: ['logpower_interval__', 'logw0_interval__', 'logs2_interval__', 'u_star_interval__', 'omega_angle__', 'ecc_interval__', 'rb_radiusimpact__', 'P_index_logodds__', 't0', 'mean', 'Rs', 'logrho_S']
# message: Desired error not necessarily achieved due to precision loss.
# logp: -5491.515336938508 -> -3296.649940882362
# P_index_logodds__     -7.70
# Rs                     1.20
# ecc_interval__        -1.47
# logpower_interval__   -1.39
# logrho_S               1.29
# logs2_interval__      -1.39
# logw0_interval__      -1.39
# mean                  -0.92
# omega_angle__         -0.50
# rb_radiusimpact__     -3.47
# t0                    -0.92
# u_star_interval__      0.94
# Name: Log-probability of test_point, dtype: float64
# Model loaded
# Multiprocess sampling (4 chains in 4 jobs)
# INFO  [pymc3.sample()]: Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [logpower, logw0, logs2, u_star, omega, ecc, rb, P_index, t0, mean, Rs, logrho_S]
# INFO  [pymc3._print_step_hierarchy()]: NUTS: [logpower, logw0, logs2, u_star, omega, ecc, rb, P_index, t0, mean, Rs, logrho_S]
# Sampling 4 chains: 100%|██████████| 3320/3320 [1:19:41<00:00,  1.70s/draws]
# The estimated number of effective samples is smaller than 200 for some parameters.
# ERROR [pymc3.log_warning()]: The estimated number of effective samples is smaller than 200 for some parameters.
# 2  removed due to period gap cuts
# 3851 3851 3851 3851 3851 3851
# 2.2103809326259882 2.0294834713348493 1.916164462637984 0.9441636207944417
# varnames =  ['b', 'ecc', 'period', 'r_pl', 'u_star', 'vrel']

# %%
# Out:
# [autoreload of NamastePymc3 failed: Traceback (most recent call last):
#   File "/Users/hosborn/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ModuleNotFoundError: No module named 'isoclassify.isoclassify'
# ]
# loading from /Users/hosborn/Postdoc/NamastePymc3/KIC00008410697/KIC00008410697_2019-11-19_0.lc
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-fdd4ff31ec17> in <module>()
#       2                          stellardict=None,doplots=True,
#       3                          mission='Kepler',cutDistance=10.0,overwrite=False,initdur=[0.8],
# ----> 4                          n_draws=1500,constrain_LD=True)
#
# /Users/hosborn/Postdoc/NamastePymc3/NamastePymc3.py in Run(ID, initdepth, initt0, mission, stellardict, n_draws, overwrite, LoadFromFile, savefileloc, doplots, do_per_gap_cuts, **kwargs)
#     765
#     766     if stellardict is None:
# --> 767         Rstar, rhostar, Teff, logg = starpars.getStellarInfo(ID, hdr, mission, savename.replace('_mcmc.pickle','_starpars.csv'),savedf=True)
#     768     else:
#     769         if type(stellardict['Rs_err'])==tuple:
#
# NameError: name 'getStellarInfo' is not defined

# %% [markdown]
# #### We can plot specific corner plots too with `PlotCorner`

# %%
namaste.PlotCorner(out_dict_k2['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
#namaste.PlotCorner(trace, 248847494, mission='K2',varnames=["b", "ecc", "omega", "logp", "r_pl","u_star","vrel"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %%
namaste.PlotCorner(out_dict_k2['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
#namaste.PlotCorner(trace, 248847494, mission='K2',varnames=["b", "ecc", "omega", "logp", "r_pl","u_star","vrel"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %%
namaste.PlotCorner(out_dict_k2['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %%
namaste.PlotCorner(out_dict_k2['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %%
namaste.PlotCorner(out_dict_k2['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %%
namaste.PlotCorner(out_dict_k2['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %%
namaste.PlotCorner(out_dict_k2['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %%
namaste.PlotCorner(out_dict_k2['trace'], 248847494, mission='K2',varnames=["logS0", "logw0", "logs2", "logpower"])
# Out:
# varnames =  ['logS0', 'logw0', 'logs2', 'logpower']

# %% [markdown]
# # KIC8410697 (from Foreman-Mackey et al, 2016)
#
# A Kepler example now.
# Again we include an initial duration, as well as the necessary initial depth and t0.

# %%
out_dict_kep=namaste.Run(8410697, [5.5e-3], [542.1231],
                         stellardict={'Rs':1.003,'Rs_err':0.23,
                                      'rho_s': 1.201,'rho_s_err':0.7,
                                      'Teff':5918,'Teff_err':160,
                                      'logg':4.371,'logg_err':0.16},doplots=True,
                         mission='Kepler',cutDistance=5.0,initdur=[19.77/24.0])

# %% [markdown]
# # TBD:
#
# ## Let's try the 5-planet HIP 41378 system...
#
# This is slightly more awkward as we have two campaigns and many possible "islands" in the period space...
# What would be nice is if we could cut out the two transits in C16 data and overlay them with the earlier data, thereby fitting a period from the overlaid transits and a second time offset which can be used to give integer period positions.

# %%
mod,trace,lc=namaste.Run(211311380, [400e-6,320e-6,700e-6,1400e-6,5500e-6,700e-6,5500e-6],
                         [2319.283,2330.162,2333.273,2309.020,2353.9162,(2333.273+278.360*4),(2353.9162+542.0793*2)],
                         periods=[5.71493,31.6978,0.0,0.0,0,0,0,0],
                         initdur=[0.0,0.0,13/24.0,14.5/24.0,22/24.0,13/24.0,22/24.0],
                         stellardict={'Rs':1.3,'Rs_err':0.009,
                                     'rho_s': 0.785,'rho_s_err':0.008,
                                     'Teff':6290,'Teff_err':77,
                                     'logg':4.29,'logg_err':0.004},doplots=False,
                         mission='K2',cutDistance=2.5,n_draws=1000,LoadFromFile=True)
# Out:
# Initialising transit model
# Teff: [6290   77   77]
# 1 48.15878780414732
# [4.2861975, 23.77335, 48.15878780414732]
# 242.2539182012057 48.15878780414732
# 1 72.41178780414748
# [4.2861975, 23.77335, 48.15878780414732, 72.41178780414748]
# 323.6788856496838 72.41178780414748
# 1 47.30558973678171
# [4.2861975, 23.77335, 48.15878780414732, 72.41178780414748, 47.30558973678171]
# 999.7000691646358 47.30558973678171
# 1 28.14641135280226
# [4.2861975, 23.77335, 48.15878780414732, 72.41178780414748, 47.30558973678171, 28.14641135280226]
# 242.2539182012057 28.14641135280226
# 1 31.305763086364095
# [4.2861975, 23.77335, 48.15878780414732, 72.41178780414748, 47.30558973678171, 28.14641135280226, 31.305763086364095]
# 999.7000691646358 31.305763086364095
# [0.3288645  0.22105668] [0.05 0.05]
# Rs __str__ = [1.3]
# RpRs __str__ = [0.02       0.01788854 0.02645751 0.03741657 0.07416198 0.02645751
#  0.07416198]
# u_star __str__ = [0.5 0.5]
# r_pl __str__ = [0.026      0.02325511 0.03439477 0.04864155 0.09641058 0.03439477
#  0.09641058]
# [ 4.2861975  23.77335    48.1587878  72.4117878  47.30558974 28.14641135
#  31.30576309] t0 [2306.61061026 2306.63104246 2306.65147447 2306.67190657 2306.69233877
#  2306.71277077 2306.73320296 2306.75363496 2306.77406706 2306.79449926] 0.020431772569281748
# optimizing logp for variables: ['rb_radiusimpact__']
# message: Optimization terminated successfully.
# logp: -7375.366807255498 -> -7204.655434341509
# optimizing logp for variables: ['logs2']
# message: Optimization terminated successfully.
# logp: -7204.655434341509 -> -2547.3466268567545
# optimizing logp for variables: ['t0', 'P_index_logodds__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: -2547.3466268567604 -> -2416.142851345584
# optimizing logp for variables: ['logpower', 'logs2']
# message: Optimization terminated successfully.
# logp: -2416.142851345583 -> 438.6100013992972
# optimizing logp for variables: ['logw0']
# message: Optimization terminated successfully.
# logp: 438.6100013992972 -> 443.7834933714489
# optimizing logp for variables: ['logpower', 'logw0', 'logs2', 'u_star_interval__', 'omega_angle__', 'ecc_interval__', 'rb_radiusimpact__', 'P_index_logodds__', 't0', 'mean', 'Rs', 'logrho_S']
# message: Desired error not necessarily achieved due to precision loss.
# logp: 443.7834933714471 -> 687.8236034579008
# P_index_logodds__   -34.23
# Rs                    3.79
# ecc_interval__      -10.26
# logpower             -3.22
# logrho_S              3.67
# logs2                -3.22
# logw0                -3.22
# mean                 -0.92
# omega_angle__        -3.50
# rb_radiusimpact__   -30.02
# t0                   -6.43
# u_star_interval__   -20.04
# Name: Log-probability of test_point, dtype: float64
# Model loaded

# %%
namaste.PlotCorner(trace, "211311380",mission='K2')
# Out:
# varnames =  ['b', 'ecc', 'period', 'r_pl', 'u_star', 'vrel']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
namaste.PlotLC(lc[:,:3],trace, "211311380",mission='K2',lcmask=lc[:,3].astype(bool),overwrite=True)
# Out:
#  GAP IN X OF  3616
# 3314 3314 3314 3314
# 5972 5447 5447
# 0.09678845153182625 0.49192557186178376 1.7817378581921728 3.621966330086998
# 0.3408564428576677 0.4911737271595013 1.7782240936886462 3.6203566993948653
# 1.2374771193885552 0.4920343711850595 1.7797114135170924 3.61704693359262
# 3.142845199227487 0.492574421789631 1.7816705536389894 3.6170586104852727
# 9.520406072474827 0.4934798877768224 1.7844045058875124 3.6159619674196612
# 9.988881066618285 0.4930186486914814 1.7818970484145595 3.6142589193002834
# 16.33961557437759 0.4928553526681401 1.781013915112098 3.6136645477630194

# %%
len(lc)
# Out:
# 5972

# %%
len(trace["light_curves"][2,:].ravel())
# Out:
# 38129

# %%
pred = trace["light_curves"]

# %%
38129/5447
# Out:
# 7.0

# %%
onepl_mod,onepl_trace,onepl_lc=namaste.Run(8410697, [5.5e-3], [542.1231],
                                        stellardict={'Rs':1.003,'Rs_err':0.23,
                                                     'rho_s': 1.201,'rho_s_err':0.7,
                                                     'Teff':5918,'Teff_err':160,
                                                     'logg':4.371,'logg_err':0.16},doplots=False,
                                        mission='Kepler',cutDistance=5.0,initdur=[19.77/24.0],LoadFromFile=True)
# Out:
# Initialising transit model
# Teff: [5918  160  160]
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-17.7.0-x86_64-i386-64bit-i386-3.6.1-64/lock_dir/lock
# 28 189.7261506698444
# [189.7261506698444]
# 1109.928590027925 189.7261506698444
# INFO  [theano.gof.compilelock._get_lock()]: Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-17.7.0-x86_64-i386-64bit-i386-3.6.1-64/lock_dir/lock
# [0.34851501 0.21932926] [0.05 0.05]
# Rs __str__ = [1.003]
# RpRs __str__ = [0.07416198]
# u_star __str__ = [0.5 0.5]
# r_pl __str__ = [0.07438447]
# [189.72615067] t0 [537.14118877 537.18205683 537.20249072 537.2229247  537.24335878
#  537.26379266 537.28422665 537.30466073 537.32509461 537.34552859] 0.02043392084306106
# optimizing logp for variables: ['rb_radiusimpact__']
# message: Optimization terminated successfully.
# logp: -620.8558013593382 -> -596.2529013336166
# optimizing logp for variables: ['logs2']
# message: Optimization terminated successfully.
# logp: -596.2529013336166 -> -20.143640772074853
# optimizing logp for variables: ['t0', 'P_index_logodds__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: -20.14364077207599 -> -10.701548535264337
# optimizing logp for variables: ['logpower', 'logs2']
# message: Optimization terminated successfully.
# logp: -10.701548535258311 -> 47.209356550982406
# optimizing logp for variables: ['logw0']
# message: Optimization terminated successfully.
# logp: 47.209356550982406 -> 48.97309143365704
# optimizing logp for variables: ['logpower', 'logw0', 'logs2', 'u_star_interval__', 'omega_angle__', 'ecc_interval__', 'rb_radiusimpact__', 'P_index_logodds__', 't0', 'mean', 'Rs', 'logrho_S']
# message: Desired error not necessarily achieved due to precision loss.
# logp: 48.973091433649365 -> 138.9446219728901
# P_index_logodds__    -4.72
# Rs                    0.55
# ecc_interval__       -1.47
# logpower             -3.22
# logrho_S             -0.38
# logs2                -3.22
# logw0                -3.22
# mean                 -0.92
# omega_angle__        -0.50
# rb_radiusimpact__    -3.39
# t0                   -0.92
# u_star_interval__   -18.96
# Name: Log-probability of test_point, dtype: float64
# Model loaded
