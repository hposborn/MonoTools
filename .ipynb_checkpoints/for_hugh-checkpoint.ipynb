# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

import exoplanet as xo
import corner

import pymc3 as pm
import theano.tensor as tt

# %%
x = np.concatenate((np.arange(100,110,0.01), np.arange(200,210,0.01)))

#Adding some randomised sinusoids to mimic stellar variability:
y_sv=abs(np.random.normal(0.002,0.0005))*np.sin((x+np.random.random()*2*np.pi)/(np.random.normal(8,1)))+abs(np.random.normal(0.001,0.0005))*np.sin((x+np.random.random()*2*np.pi)/(np.random.normal(3,0.8)))

y = np.concatenate((np.random.normal(1.0,0.001,1000), np.random.normal(1.0,0.001,1000)))+y_sv
yerr = 0.001 + np.zeros_like(y)

t0s=[105.57, 205.57]

true_orbit = xo.orbits.KeplerianOrbit(period=50.0, t0=t0s[0], b=0.3, omega=0.72, ecc=0.025)
true_model = xo.LimbDarkLightCurve([0.3, 0.2]).get_light_curve(orbit=true_orbit, t=x, r=np.sqrt(0.00325))[:, 0].eval()
y += true_model

plt.figure(figsize=(15,5))
plt.plot(x, y,'.');
# Out:
# /Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %%
#Here we compute the max period and the min period
dur=0.24
max_P=t0s[1]-t0s[0]

#Folding x on maximum period with the first transit at 0.0
folded_x=np.sort(abs((x-t0s[0]-max_P*0.5)%max_P-max_P*0.5))

#minimum P is the first instance of a gap bigger than the duration in absolute phase space:
min_P=np.where(np.diff(folded_x)>dur)[0]
min_P=min_P[0] if len(min_P)>1 else min_P
min_P=np.max(folded_x) if len(min_P)==0 else min_P
period_index = np.arange(1, max_P/min_P, 1)

# %% [markdown]
# # Simple model:
#
# (i.e. circular)

# %%
with pm.Model() as model:

    # The baseline flux
    mean = pm.Normal("mean", mu=1.0, sd=1.0)

    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=1.0)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=1.0)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.01, upper=0.1,  testval=np.sqrt(0.00325))
    b = xo.distributions.ImpactParameter("b", ror=r, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1) / period_index)
    
    logprobs = []
    logpriors = []
    all_lcs = []
    for i, index in enumerate(period_index):
        with pm.Model(name="per_{0}".format(i), model=model) as submodel:
            
            period = periods[i]
            
            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(period=period, t0=t0_1, b=b)
        
            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            light_curve = pm.Deterministic("light_curve", pm.math.sum(light_curves, axis=-1) + mean)  
            all_lcs.append(light_curve)
            
            # Compute the log prob
            loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            logprior = -8 * tt.log(period) / 3
            logprobs.append(loglike + logprior)
            
            #Adding way to keep track of prior probability and lightcurve
            logpriors.append(logprior)

    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    logprior_class = pm.Deterministic("logprior_class", tt.stack(logpriors))
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve
    pm.Deterministic("marginalized_light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
        
    print(model.check_test_point())
    map_soln = xo.optimize(vars=[mean, u, r, b])
    map_soln = xo.optimize(map_soln)
# Out:
# mean               -0.92
# t0_1               -0.92
# t0_2               -0.92
# u_quadlimbdark__   -3.23
# r_interval__       -1.39
# b_impact__         -1.44
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [b, r, u, mean]
# 22it [00:05,  3.97it/s, logp=1.049761e+04]
# message: Optimization terminated successfully.
# logp: 8909.140681635596 -> 10497.605202000846
# optimizing logp for variables: [b, r, u, t0_2, t0_1, mean]
# 40it [00:00, 171.87it/s, logp=1.049899e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 53it [00:00, 171.94it/s, logp=1.049899e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 53it [00:04, 10.84it/s, logp=1.049899e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10497.605202000846 -> 10498.98926463497

# %%
map_soln
# Out:
# {'mean': array(1.0012585),
#  't0_1': array(105.56411368),
#  't0_2': array(205.56852564),
#  'u_quadlimbdark__': array([-1.19246556, -0.45442458]),
#  'r_interval__': array(-0.0653211),
#  'b_impact__': array(-0.14829687),
#  'u': array([0.37472814, 0.10778431]),
#  'r': array(0.0535308),
#  'b': array(0.48777799),
#  'periods': array([100.00441195,  50.00220598,  33.33480398,  25.00110299,
#          20.00088239,  16.66740199,  14.28634456,  12.50055149,
#          11.11160133,  10.0004412 ,   9.09131018,   8.333701  ,
#           7.69264707,   7.14317228,   6.6669608 ,   6.25027575,
#           5.88261247]),
#  'per_0_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_1_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_2_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_3_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_4_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_5_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_6_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_7_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_8_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_9_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_10_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_11_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_12_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_13_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_14_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_15_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'per_16_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585]),
#  'logprob_class': array([-3.00402408e+01, -5.24796633e-07, -1.44602587e+01, -2.71717403e+01,
#         -3.93212703e+01, -4.66717586e+01, -5.37568602e+01, -5.99364278e+01,
#         -6.46188065e+01, -6.81222409e+01, -7.06088622e+01, -7.28881970e+01,
#         -7.52484478e+01, -7.78713166e+01, -8.03877992e+01, -8.25139916e+01,
#         -8.43052173e+01]),
#  'logprior_class': array([-12.28057148, -10.432179  ,  -9.35093871,  -8.58378652,
#          -7.98873705,  -7.50254623,  -7.09147775,  -6.73539403,
#          -6.42130594,  -6.14034456,  -5.88618408,  -5.65415375,
#          -5.44070653,  -5.24308527,  -5.05910428,  -4.88700155,
#          -4.72533589]),
#  'marginalized_light_curve': array([1.0012585, 1.0012585, 1.0012585, ..., 1.0012585, 1.0012585,
#         1.0012585])}

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln["periods"], map_soln["logprob_class"], "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized simple model period probability with circular orbit")
plt.plot(map_soln["periods"],map_soln["logprior_class"],'-o',label='log_priors')
#[map_soln['per_'+str(n)+'_log_prior'] for n in range(17)],'-o',label='log_priors')
plt.legend()

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln["per_16_light_curve"][:1000],alpha=0.5)
plt.plot(x[:1000],map_soln["per_1_light_curve"][:1000],alpha=0.5)
plt.plot(x[:1000],map_soln["marginalized_light_curve"][:1000],'--',alpha=0.75,linewidth=2.0)

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln["per_16_light_curve"][1000:],alpha=0.5)
plt.plot(x[1000:],map_soln["per_1_light_curve"][1000:],alpha=0.5)
plt.plot(x[1000:],map_soln["marginalized_light_curve"][1000:],'--',alpha=0.75,linewidth=2.0)

# %% [markdown]
# Clear preference for the correct model here. That's good to see.

# %% [markdown]
# # Adding GPs & stellar info. Maintaining circular orbit:

# %%
with pm.Model() as model_gp_circ:

    #Baseline flux is now in the GPs, so deleting this:
    #mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    logprobs = []
    logpriors= []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=model_gp_circ) as submodel:
            
            period = periods[i]
            
            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1)
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred = pm.Deterministic("gp_pred", gp.predict())
            gp_preds.append(gp.predict())
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-8/3 (occurrence rate (P^-1) * window function (P^-1) * transit probability (P^-2/3) )
            logprior = -8 * tt.log(period) / 3
            logprobs.append(loglike + logprior)
            logpriors.append(logprior)

    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    logprior_class = pm.Deterministic("logprior_class", tt.stack(logpriors))
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve and gp prediction
    pm.Deterministic("marginalized_light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    pm.Deterministic("marginalized_gp_pred", tt.sum(tt.stack(gp_preds) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(model_gp_circ.test_point)
    print(model_gp_circ.check_test_point())
    map_soln_gp_circ = xo.optimize(vars=[r, b])
    map_soln_gp_circ = xo.optimize(start=map_soln_gp_circ, vars=[logs2])
    map_soln_gp_circ = xo.optimize(start=map_soln_gp_circ, vars=[t0_1, t0_2])
    map_soln_gp_circ = xo.optimize(start=map_soln_gp_circ, vars=[logs2, logpower])
    map_soln_gp_circ = xo.optimize(start=map_soln_gp_circ, vars=[logw0])
    map_soln_gp_circ = xo.optimize(start=map_soln_gp_circ, vars=[r,b,Rs,u])

    map_soln_gp_circ = xo.optimize(map_soln_gp_circ)
# Out:
# {'Rs': array(1.), 'logrho_S': array(0.), 't0_1': array(105.57), 't0_2': array(205.57), 'u_quadlimbdark__': array([-1.09861229, -0.84729786]), 'r_interval__': array(0.), 'b_impact__': array(-0.59116847), 'logs2': array(-6.65444898), 'logw0_interval__': array(-0.60183699), 'logpower_interval__': array(1.18693347)}
# Rs                     0.29
# logrho_S              -0.23
# t0_1                  -0.00
# t0_2                  -0.00
# u_quadlimbdark__      -3.23
# r_interval__          -1.39
# b_impact__            -1.47
# logs2                 -0.92
# logw0_interval__      -1.48
# logpower_interval__   -1.72
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [b, r, Rs]
# 0it [00:00, ?it/s]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 16it [00:07,  2.18it/s, logp=-1.671167e+04]
# message: Optimization terminated successfully.
# logp: -16724.40533635273 -> -16711.665724008402
# optimizing logp for variables: [logs2]
# 0it [00:00, ?it/s]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 13it [00:06,  1.95it/s, logp=-2.821456e+03]
# message: Optimization terminated successfully.
# logp: -16711.665724008402 -> -2821.4560347560314
# optimizing logp for variables: [t0_2, t0_1]
# 10it [00:05,  1.78it/s, logp=-2.821456e+03]
# message: Optimization terminated successfully.
# logp: -2821.4560347560314 -> -2821.456016855567
# optimizing logp for variables: [logpower, logs2]
# 50it [00:06,  7.72it/s, logp=9.543855e+03]
# message: Optimization terminated successfully.
# logp: -2821.456016855567 -> 9543.85506863918
# optimizing logp for variables: [logw0]
# 13it [00:06,  1.88it/s, logp=1.068950e+04]
# message: Optimization terminated successfully.
# logp: 9543.85506863918 -> 10689.50100421717
# optimizing logp for variables: [u, Rs, b, r]
# 20it [00:07,  2.81it/s, logp=1.070082e+04]
# message: Optimization terminated successfully.
# logp: 10689.501004217158 -> 10700.817888953505
# optimizing logp for variables: [logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs]
# 0it [00:00, ?it/s]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 106it [00:00, 131.30it/s, logp=1.088424e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 118it [00:00, 131.41it/s, logp=1.088424e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 119it [00:06, 17.04it/s, logp=1.088424e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10700.817888953505 -> 10884.238581311822

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_gp_circ["periods"], map_soln_gp_circ["logprob_class"], "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-8/3 prior, circular orbit")
plt.plot(map_soln_gp_circ["periods"],map_soln_gp_circ["logprior_class"],'-o',label='log_priors')
#[map_soln_gp_circ['per_'+str(n)+'_log_prior'] for n in range(17)]
plt.legend()

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_gp_circ["per_16_light_curve"][:1000]+map_soln_gp_circ["per_16_gp_pred"][:1000],label='shortest-P')
plt.plot(x[:1000],map_soln_gp_circ["per_1_light_curve"][:1000]+map_soln_gp_circ["per_1_gp_pred"][:1000],label='longest-P')
plt.plot(x[:1000],map_soln_gp_circ["marginalized_light_curve"][:1000]+map_soln_gp_circ["marginalized_gp_pred"][:1000],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_gp_circ["per_16_light_curve"][1000:]+map_soln_gp_circ["per_16_gp_pred"][1000:],label='shortest-P')
plt.plot(x[1000:],map_soln_gp_circ["per_1_light_curve"][1000:]+map_soln_gp_circ["per_1_gp_pred"][1000:],label='longest-P')
plt.plot(x[1000:],map_soln_gp_circ["marginalized_light_curve"][1000:]+map_soln_gp_circ["marginalized_gp_pred"][1000:],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

# %% [markdown]
# Ok, we're good for circular+GP.
#
# Next stage:

# %% [markdown]
# # Adding Complexity - eccentricity

# %%
with pm.Model() as model_ecc:

    # The baseline flux
    mean = pm.Normal("mean", mu=1.0, sd=1.0)

    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=1.0)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=1.0)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.01, upper=0.1,  testval=np.sqrt(0.00325))
    b = xo.distributions.ImpactParameter("b", ror=r, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1) / period_index)
    
    #Initialising eccentricity and omega:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)
    ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
    omega = xo.distributions.Angle("omega")

    logprobs = []
    logpriors = []
    all_lcs = []
    for i, index in enumerate(period_index):
        with pm.Model(name="per_{0}".format(i), model=model_ecc) as submodel:
            
            period = periods[i]
            
            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(period=period, t0=t0_1, b=b,ecc=ecc,omega=omega)
        
            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            light_curve = pm.Deterministic("light_curve", pm.math.sum(light_curves, axis=-1) + mean)  
            all_lcs.append(light_curve)
            
            # Compute the log prob
            loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            logprior = -8 * tt.log(period) / 3
            logprobs.append(loglike + logprior)
            
            #Adding way to keep track of prior probability and lightcurve
            logpriors.append(logprior)

    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    logprior_class = pm.Deterministic("logprior_class", tt.stack(logpriors))
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve
    pm.Deterministic("marginalized_light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
        
    print(model_ecc.check_test_point())
    map_soln_ecc = xo.optimize(vars=[mean, u, r, b, ecc, omega])
    map_soln_ecc = xo.optimize(map_soln_ecc)
# Out:
# mean               -0.92
# t0_1               -0.92
# t0_2               -0.92
# u_quadlimbdark__   -3.23
# r_interval__       -1.39
# b_impact__         -1.44
# ecc_interval__     -1.85
# omega_angle__      -0.50
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [omega, ecc, b, r, u, mean]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=8.905877e+03]
# 1it [00:00, 64.81it/s, logp=8.905877e+03]
# 2it [00:00, 84.63it/s, logp=8.905877e+03]
# 3it [00:00, 93.38it/s, logp=-1.017504e+09]
# 4it [00:00, 100.37it/s, logp=1.048223e+04]
# 5it [00:00, 104.16it/s, logp=9.781730e+03]
# 6it [00:00, 108.36it/s, logp=1.030721e+04]
# 7it [00:00, 110.36it/s, logp=1.038238e+04]
# 8it [00:00, 112.14it/s, logp=1.049226e+04]
# 9it [00:00, 113.01it/s, logp=1.050491e+04]
# 10it [00:00, 114.16it/s, logp=1.051419e+04]
# 11it [00:00, 114.29it/s, logp=1.051544e+04]
# 12it [00:00, 112.79it/s, logp=1.051102e+04]
# 13it [00:00, 120.66it/s, logp=1.051102e+04]
# 13it [00:00, 120.66it/s, logp=1.051572e+04]
# 14it [00:00, 120.66it/s, logp=1.051613e+04]
# 15it [00:00, 120.66it/s, logp=1.051606e+04]
# 16it [00:00, 120.66it/s, logp=1.051629e+04]
# 17it [00:00, 120.66it/s, logp=1.051635e+04]
# 18it [00:00, 120.66it/s, logp=1.051637e+04]
# 19it [00:00, 120.66it/s, logp=1.051637e+04]
# 20it [00:00, 120.66it/s, logp=1.051637e+04]
# 21it [00:00, 120.66it/s, logp=1.051637e+04]
# 22it [00:00, 120.66it/s, logp=1.051637e+04]
# 23it [00:00, 111.56it/s, logp=1.051637e+04]
# 23it [00:00, 111.56it/s, logp=1.051638e+04]
# 24it [00:00, 111.56it/s, logp=1.051638e+04]
# 25it [00:00, 111.56it/s, logp=1.051639e+04]
# 26it [00:00, 111.56it/s, logp=1.051640e+04]
# 27it [00:00, 111.56it/s, logp=1.051642e+04]
# 28it [00:00, 111.56it/s, logp=1.051645e+04]
# 29it [00:00, 111.56it/s, logp=1.051645e+04]
# 30it [00:00, 111.56it/s, logp=1.051646e+04]
# 31it [00:00, 111.56it/s, logp=1.051646e+04]
# 32it [00:00, 111.56it/s, logp=1.051647e+04]
# 33it [00:00, 107.47it/s, logp=1.051647e+04]
# 33it [00:00, 107.47it/s, logp=1.051647e+04]
# 34it [00:00, 107.47it/s, logp=1.051647e+04]
# 35it [00:00, 107.47it/s, logp=1.051647e+04]
# 36it [00:00, 107.47it/s, logp=1.051647e+04]
# 37it [00:00, 107.47it/s, logp=1.051647e+04]
# 38it [00:00, 107.47it/s, logp=1.051647e+04]
# 39it [00:00, 107.47it/s, logp=1.051647e+04]
# 40it [00:00, 107.47it/s, logp=1.051647e+04]
# 41it [00:00, 107.47it/s, logp=1.051647e+04]
# 42it [00:00, 107.47it/s, logp=1.051647e+04]
# 43it [00:00, 102.53it/s, logp=1.051647e+04]
# 43it [00:00, 102.53it/s, logp=1.051647e+04]
# 44it [00:00, 102.53it/s, logp=1.051647e+04]
# 45it [00:00, 102.53it/s, logp=1.051647e+04]
# 46it [00:00, 102.53it/s, logp=1.051647e+04]
# 47it [00:00, 102.53it/s, logp=1.051647e+04]
# 48it [00:00, 102.53it/s, logp=1.051647e+04]
# 49it [00:00, 102.53it/s, logp=1.051647e+04]
# 50it [00:00, 102.53it/s, logp=1.051647e+04]
# 51it [00:00, 102.53it/s, logp=1.051647e+04]
# 52it [00:00, 102.53it/s, logp=1.051647e+04]
# 53it [00:00, 98.99it/s, logp=1.051647e+04]
# 53it [00:00, 98.99it/s, logp=1.051647e+04]
# 54it [00:00, 98.99it/s, logp=1.051647e+04]
# 55it [00:00, 98.99it/s, logp=1.051647e+04]
# 56it [00:00, 98.99it/s, logp=1.051647e+04]
# 57it [00:00, 98.99it/s, logp=1.051647e+04]
# 58it [00:00, 98.99it/s, logp=1.051647e+04]
# 59it [00:00, 98.99it/s, logp=1.051647e+04]
# 60it [00:00, 98.99it/s, logp=1.051647e+04]
# 61it [00:00, 98.99it/s, logp=1.051647e+04]
# 62it [00:00, 98.99it/s, logp=1.051647e+04]
# 63it [00:00, 98.99it/s, logp=1.051647e+04]
# 64it [00:00, 100.95it/s, logp=1.051647e+04]
# 64it [00:00, 100.95it/s, logp=1.051647e+04]
# 65it [00:00, 100.95it/s, logp=1.051647e+04]
# 66it [00:00, 100.95it/s, logp=1.051647e+04]
# 67it [00:00, 100.95it/s, logp=1.051647e+04]
# 68it [00:00, 100.95it/s, logp=1.051647e+04]
# 69it [00:00, 100.95it/s, logp=1.051647e+04]
# 70it [00:00, 100.95it/s, logp=1.051647e+04]
# 71it [00:00, 100.95it/s, logp=1.051647e+04]
# 72it [00:00, 100.95it/s, logp=1.051647e+04]
# 73it [00:00, 96.26it/s, logp=1.051647e+04]
# 73it [00:00, 96.26it/s, logp=1.051647e+04]
# 74it [00:00, 96.26it/s, logp=1.051647e+04]
# 75it [00:00, 96.26it/s, logp=1.051647e+04]
# 76it [00:00, 96.26it/s, logp=1.051647e+04]
# 77it [00:00, 96.26it/s, logp=1.051647e+04]
# 78it [00:00, 96.26it/s, logp=1.051647e+04]
# 79it [00:00, 96.26it/s, logp=1.051647e+04]
# 80it [00:00, 96.26it/s, logp=1.051647e+04]
# 81it [00:00, 96.26it/s, logp=1.051647e+04]
# 82it [00:00, 91.74it/s, logp=1.051647e+04]
# 82it [00:00, 91.74it/s, logp=1.051647e+04]
# 83it [00:00, 91.74it/s, logp=1.051647e+04]
# 84it [00:00, 91.74it/s, logp=1.051647e+04]
# 85it [00:00, 91.74it/s, logp=1.051647e+04]
# 86it [00:00, 91.74it/s, logp=1.051647e+04]
# 87it [00:00, 91.74it/s, logp=1.051647e+04]
# 88it [00:00, 91.74it/s, logp=1.051647e+04]
# 89it [00:00, 91.74it/s, logp=1.051647e+04]
# 90it [00:00, 91.74it/s, logp=1.051647e+04]
# 91it [00:00, 87.62it/s, logp=1.051647e+04]
# 91it [00:00, 87.62it/s, logp=1.051647e+04]
# 92it [00:00, 87.62it/s, logp=1.051647e+04]
# 93it [00:00, 87.62it/s, logp=1.051647e+04]
# 94it [00:01, 87.62it/s, logp=1.051647e+04]
# 95it [00:01, 87.62it/s, logp=1.051647e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 96it [00:01, 87.62it/s, logp=1.051647e+04]
# 97it [00:01, 87.62it/s, logp=1.051647e+04]
# 98it [00:01, 87.62it/s, logp=1.051647e+04]
# 99it [00:01, 87.62it/s, logp=1.051647e+04]
# 100it [00:01, 87.62it/s, logp=1.051647e+04]
# 101it [00:01, 87.62it/s, logp=1.051647e+04]
# 102it [00:01, 87.62it/s, logp=1.051647e+04]
# 103it [00:01, 94.20it/s, logp=1.051647e+04]
# 103it [00:01, 94.20it/s, logp=1.051647e+04]
# 104it [00:01, 94.20it/s, logp=1.051647e+04]
# 105it [00:01, 94.20it/s, logp=1.051647e+04]
# 106it [00:01, 94.20it/s, logp=1.051647e+04]
# 107it [00:01, 94.20it/s, logp=1.051647e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 108it [00:08, 12.28it/s, logp=1.051647e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 8905.876683775223 -> 10516.466971223945
# optimizing logp for variables: [omega, ecc, b, r, u, t0_2, t0_1, mean]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=1.051647e+04]
# 1it [00:00, 71.17it/s, logp=1.051647e+04]
# 2it [00:00, 86.60it/s, logp=1.051647e+04]
# 3it [00:00, 91.32it/s, logp=1.016042e+04]
# 4it [00:00, 96.84it/s, logp=1.038248e+04]
# 5it [00:00, 96.59it/s, logp=1.051440e+04]
# 6it [00:00, 97.62it/s, logp=1.051735e+04]
# 7it [00:00, 98.48it/s, logp=-4.599874e+03]
# 8it [00:00, 100.26it/s, logp=1.051735e+04]
# 9it [00:00, 100.23it/s, logp=1.051735e+04]
# 10it [00:00, 100.48it/s, logp=1.051735e+04]
# 11it [00:00, 109.72it/s, logp=1.051735e+04]
# 11it [00:00, 109.72it/s, logp=1.051735e+04]
# 12it [00:00, 109.72it/s, logp=1.051735e+04]
# 13it [00:00, 109.72it/s, logp=1.051737e+04]
# 14it [00:00, 109.72it/s, logp=1.051743e+04]
# 15it [00:00, 109.72it/s, logp=1.051756e+04]
# 16it [00:00, 109.72it/s, logp=1.050214e+04]
# 17it [00:00, 109.72it/s, logp=1.051756e+04]
# 18it [00:00, 109.72it/s, logp=1.051757e+04]
# 19it [00:00, 109.72it/s, logp=1.051759e+04]
# 20it [00:00, 109.72it/s, logp=1.051762e+04]
# 21it [00:00, 109.72it/s, logp=1.051762e+04]
# 22it [00:00, 109.72it/s, logp=1.051763e+04]
# 23it [00:00, 110.96it/s, logp=1.051763e+04]
# 23it [00:00, 110.96it/s, logp=1.051763e+04]
# 24it [00:00, 110.96it/s, logp=1.051764e+04]
# 25it [00:00, 110.96it/s, logp=1.051764e+04]
# 26it [00:00, 110.96it/s, logp=1.051766e+04]
# 27it [00:00, 110.96it/s, logp=1.051696e+04]
# 28it [00:00, 110.96it/s, logp=1.051768e+04]
# 29it [00:00, 110.96it/s, logp=1.051770e+04]
# 30it [00:00, 110.96it/s, logp=1.051241e+04]
# 31it [00:00, 110.96it/s, logp=1.051770e+04]
# 32it [00:00, 110.96it/s, logp=1.051770e+04]
# 33it [00:00, 110.96it/s, logp=1.051771e+04]
# 34it [00:00, 110.96it/s, logp=1.051773e+04]
# 35it [00:00, 113.35it/s, logp=1.051773e+04]
# 35it [00:00, 113.35it/s, logp=1.051775e+04]
# 36it [00:00, 113.35it/s, logp=1.051777e+04]
# 37it [00:00, 113.35it/s, logp=1.051777e+04]
# 38it [00:00, 113.35it/s, logp=1.051778e+04]
# 39it [00:00, 113.35it/s, logp=1.051778e+04]
# 40it [00:00, 113.35it/s, logp=1.051778e+04]
# 41it [00:00, 113.35it/s, logp=1.051778e+04]
# 42it [00:00, 113.35it/s, logp=1.051779e+04]
# 43it [00:00, 113.35it/s, logp=1.051780e+04]
# 44it [00:00, 113.35it/s, logp=1.051780e+04]
# 45it [00:00, 113.35it/s, logp=1.051780e+04]
# 46it [00:00, 113.35it/s, logp=1.051780e+04]
# 47it [00:00, 115.08it/s, logp=1.051780e+04]
# 47it [00:00, 115.08it/s, logp=1.051780e+04]
# 48it [00:00, 115.08it/s, logp=1.051780e+04]
# 49it [00:00, 115.08it/s, logp=1.051780e+04]
# 50it [00:00, 115.08it/s, logp=1.051780e+04]
# 51it [00:00, 115.08it/s, logp=1.051780e+04]
# 52it [00:00, 115.08it/s, logp=1.051780e+04]
# 53it [00:00, 115.08it/s, logp=1.051780e+04]
# 54it [00:00, 115.08it/s, logp=1.051780e+04]
# 55it [00:00, 115.08it/s, logp=1.051780e+04]
# 56it [00:00, 115.08it/s, logp=1.051780e+04]
# 57it [00:00, 115.08it/s, logp=1.051780e+04]
# 58it [00:00, 115.08it/s, logp=1.051780e+04]
# 59it [00:00, 115.24it/s, logp=1.051780e+04]
# 59it [00:00, 115.24it/s, logp=1.051780e+04]
# 60it [00:00, 115.24it/s, logp=1.051780e+04]
# 61it [00:00, 115.24it/s, logp=1.051780e+04]
# 62it [00:00, 115.24it/s, logp=1.051780e+04]
# 63it [00:00, 115.24it/s, logp=1.051780e+04]
# 64it [00:00, 115.24it/s, logp=1.051780e+04]
# 65it [00:00, 115.24it/s, logp=1.051780e+04]
# 66it [00:00, 115.24it/s, logp=1.051780e+04]
# 67it [00:00, 115.24it/s, logp=1.051780e+04]
# 68it [00:00, 115.24it/s, logp=1.051780e+04]
# 69it [00:00, 115.24it/s, logp=1.051780e+04]
# 70it [00:00, 115.24it/s, logp=1.051780e+04]
# 71it [00:00, 115.24it/s, logp=1.051780e+04]
# 72it [00:00, 118.94it/s, logp=1.051780e+04]
# 72it [00:00, 118.94it/s, logp=1.051780e+04]
# 73it [00:00, 118.94it/s, logp=1.051780e+04]
# 74it [00:00, 118.94it/s, logp=1.051780e+04]
# 75it [00:00, 118.94it/s, logp=1.051780e+04]
# 76it [00:00, 118.94it/s, logp=1.051780e+04]
# 77it [00:00, 118.94it/s, logp=1.051780e+04]
# 78it [00:00, 118.94it/s, logp=1.051780e+04]
# 79it [00:00, 118.94it/s, logp=1.051780e+04]
# 80it [00:00, 118.94it/s, logp=1.051780e+04]
# 81it [00:00, 118.94it/s, logp=1.051780e+04]
# 82it [00:00, 118.94it/s, logp=1.051780e+04]
# 83it [00:00, 118.94it/s, logp=1.051780e+04]
# 84it [00:00, 118.94it/s, logp=1.051780e+04]
# 85it [00:00, 118.94it/s, logp=1.051780e+04]
# 86it [00:00, 123.40it/s, logp=1.051780e+04]
# 86it [00:00, 123.40it/s, logp=1.051780e+04]
# 87it [00:00, 123.40it/s, logp=1.051780e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 88it [00:00, 123.40it/s, logp=1.051780e+04]
# 89it [00:00, 123.40it/s, logp=1.051780e+04]
# 90it [00:00, 123.40it/s, logp=1.051780e+04]
# 91it [00:00, 123.40it/s, logp=1.051780e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 92it [00:00, 123.40it/s, logp=1.051780e+04]
# 93it [00:00, 123.40it/s, logp=1.051780e+04]
# 94it [00:00, 123.40it/s, logp=1.051780e+04]
# 95it [00:00, 123.40it/s, logp=1.051780e+04]
# 96it [00:00, 123.40it/s, logp=1.051780e+04]
# 97it [00:00, 123.40it/s, logp=1.051780e+04]
# 98it [00:00, 123.40it/s, logp=1.051780e+04]
# 99it [00:00, 124.46it/s, logp=1.051780e+04]
# 99it [00:00, 124.46it/s, logp=1.051780e+04]
# 100it [00:00, 124.46it/s, logp=1.051780e+04]
# 101it [00:00, 124.46it/s, logp=1.051780e+04]
# 102it [00:00, 124.46it/s, logp=1.051780e+04]
# 103it [00:00, 124.46it/s, logp=1.051780e+04]
# 104it [00:00, 124.46it/s, logp=1.051780e+04]
# 105it [00:00, 124.46it/s, logp=1.051780e+04]
# 106it [00:00, 124.46it/s, logp=1.051780e+04]
# 107it [00:00, 124.46it/s, logp=1.051780e+04]
# 108it [00:00, 124.46it/s, logp=1.051780e+04]
# 109it [00:00, 124.46it/s, logp=1.051780e+04]
# 110it [00:00, 124.46it/s, logp=1.051780e+04]
# 111it [00:00, 124.46it/s, logp=1.051780e+04]
# 112it [00:00, 124.46it/s, logp=1.051780e+04]
# 113it [00:00, 126.62it/s, logp=1.051780e+04]
# 113it [00:00, 126.62it/s, logp=1.051780e+04]
# 114it [00:00, 126.62it/s, logp=1.051780e+04]
# 115it [00:00, 126.62it/s, logp=1.051780e+04]
# 116it [00:00, 126.62it/s, logp=1.051780e+04]
# 117it [00:00, 126.62it/s, logp=1.051780e+04]
# 118it [00:00, 126.62it/s, logp=1.051780e+04]
# 119it [00:00, 126.62it/s, logp=1.051780e+04]
# 120it [00:00, 126.62it/s, logp=1.051780e+04]
# 121it [00:00, 126.62it/s, logp=1.051780e+04]
# 122it [00:01, 126.62it/s, logp=1.051780e+04]
# 123it [00:01, 126.62it/s, logp=1.051780e+04]
# 124it [00:01, 126.62it/s, logp=1.051780e+04]
# 125it [00:01, 126.62it/s, logp=1.051780e+04]
# 126it [00:01, 127.51it/s, logp=1.051780e+04]
# 126it [00:01, 127.51it/s, logp=1.051780e+04]
# 127it [00:01, 127.51it/s, logp=1.051780e+04]
# 128it [00:01, 127.51it/s, logp=1.051780e+04]
# 129it [00:01, 127.51it/s, logp=1.051780e+04]
# 130it [00:01, 127.51it/s, logp=1.051780e+04]
# 131it [00:01, 127.51it/s, logp=1.051780e+04]
# 132it [00:01, 127.51it/s, logp=1.051780e+04]
# 133it [00:01, 127.51it/s, logp=1.051780e+04]
# 134it [00:01, 127.51it/s, logp=1.051780e+04]
# 135it [00:01, 127.51it/s, logp=1.051780e+04]
# 136it [00:01, 127.51it/s, logp=1.051780e+04]
# 137it [00:01, 127.51it/s, logp=1.051780e+04]
# 138it [00:01, 127.51it/s, logp=1.051780e+04]
# 139it [00:01, 127.51it/s, logp=1.051780e+04]
# 140it [00:01, 129.00it/s, logp=1.051780e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 140it [00:01, 129.00it/s, logp=1.051780e+04]
# 141it [00:01, 129.00it/s, logp=1.051780e+04]
# 142it [00:01, 129.00it/s, logp=1.051780e+04]
# 143it [00:01, 129.00it/s, logp=1.051780e+04]
# 144it [00:01, 129.00it/s, logp=1.051780e+04]
# 145it [00:01, 129.00it/s, logp=1.051780e+04]
# 146it [00:01, 129.00it/s, logp=1.051780e+04]
# 147it [00:01, 129.00it/s, logp=1.051780e+04]
# 148it [00:01, 129.00it/s, logp=1.051780e+04]
# 149it [00:01, 129.00it/s, logp=1.051780e+04]
# 150it [00:01, 129.00it/s, logp=1.051780e+04]
# 151it [00:01, 129.00it/s, logp=1.051780e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 152it [00:09, 15.97it/s, logp=1.051780e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10516.466971223945 -> 10517.799071782974

# %%
map_soln_ecc
# Out:
# {'mean': array(1.00125844),
#  't0_1': array(105.56438511),
#  't0_2': array(205.56838206),
#  'u_quadlimbdark__': array([-1.25887426, -0.50044178]),
#  'r_interval__': array(-0.08292641),
#  'b_impact__': array(-0.49992574),
#  'ecc_interval__': array(-1.25129243),
#  'omega_angle__': array([0.54509823, 4.43879127]),
#  'u': array([0.35500559, 0.11527916]),
#  'r': array(0.05313522),
#  'b': array(0.39761976),
#  'periods': array([100.00399694,  50.00199847,  33.33466565,  25.00099924,
#          20.00079939,  16.66733282,  14.28628528,  12.50049962,
#          11.11155522,  10.00039969,   9.09127245,   8.33366641,
#           7.69261515,   7.14314264,   6.66693313,   6.25024981,
#           5.88258806]),
#  'ecc': array(0.22248204),
#  'omega': array(0.12219151),
#  'per_0_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_1_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_2_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_3_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_4_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_5_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_6_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_7_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_8_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_9_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_10_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_11_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_12_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_13_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_14_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_15_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_16_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'logprob_class': array([-3.03745956e+01, -2.84355337e-07, -1.50730414e+01, -2.77738639e+01,
#         -4.04112452e+01, -4.72566631e+01, -5.45431119e+01, -6.03069779e+01,
#         -6.52619727e+01, -6.87979097e+01, -7.09700140e+01, -7.30619254e+01,
#         -7.56604627e+01, -7.85342033e+01, -8.12722869e+01, -8.33515847e+01,
#         -8.49806240e+01]),
#  'logprior_class': array([-12.28056041, -10.43216793,  -9.35092764,  -8.58377545,
#          -7.98872598,  -7.50253516,  -7.09146668,  -6.73538297,
#          -6.42129487,  -6.1403335 ,  -5.88617302,  -5.65414268,
#          -5.44069546,  -5.2430742 ,  -5.05909321,  -4.88699049,
#          -4.72532483]),
#  'marginalized_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844])}

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_ecc["periods"], map_soln_ecc["logprob_class"], "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized simple model period probability with eccentric orbit")
plt.plot(map_soln_ecc["periods"],map_soln_ecc["logprior_class"],'-o',label='log_priors')
#[map_soln['per_'+str(n)+'_log_prior'] for n in range(17)],'-o',label='log_priors')
plt.legend()

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_ecc["per_16_light_curve"][:1000],alpha=0.5)
plt.plot(x[:1000],map_soln_ecc["per_1_light_curve"][:1000],alpha=0.5)
plt.plot(x[:1000],map_soln_ecc["marginalized_light_curve"][:1000],'--',alpha=0.75,linewidth=2.0)

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_ecc["per_16_light_curve"][1000:],alpha=0.5)
plt.plot(x[1000:],map_soln_ecc["per_1_light_curve"][1000:],alpha=0.5)
plt.plot(x[1000:],map_soln_ecc["marginalized_light_curve"][1000:],'--',alpha=0.75,linewidth=2.0)

# %% [markdown]
# # Let's try putting ecc & omega inside the submodel

# %%
with pm.Model() as model_ecc_2:

    # The baseline flux
    mean = pm.Normal("mean", mu=1.0, sd=1.0)

    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=1.0)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=1.0)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.01, upper=0.1,  testval=np.sqrt(0.00325))
    b = xo.distributions.ImpactParameter("b", ror=r, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1) / period_index)
    
    #Initialising eccentricity and omega:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)

    logprobs = []
    logpriors = []
    all_lcs = []
    for i, index in enumerate(period_index):
        with pm.Model(name="per_{0}".format(i), model=model_ecc_2) as submodel:
            
            period = periods[i]
            ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03, testval=np.random.random())
            omega = xo.distributions.Angle("omega")

            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(period=period, t0=t0_1, b=b,
                                             ecc=ecc,omega=omega)
        
            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            light_curve = pm.Deterministic("light_curve", pm.math.sum(light_curves, axis=-1) + mean)  
            all_lcs.append(light_curve)
            
            # Compute the log prob
            loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            logprior = -8 * tt.log(period) / 3
            logprobs.append(loglike + logprior)
            
            #Adding way to keep track of prior probability and lightcurve
            logpriors.append(logprior)

    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    logprior_class = pm.Deterministic("logprior_class", tt.stack(logpriors))
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve
    pm.Deterministic("marginalized_light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
        
    print(model_ecc_2.check_test_point())
    map_soln_ecc_2 = xo.optimize(vars=[mean, u, r, b, ecc, omega])
    map_soln_ecc_2 = xo.optimize(map_soln_ecc_2)
# Out:
# mean                    -0.92
# t0_1                    -0.92
# t0_2                    -0.92
# u_quadlimbdark__        -3.23
# r_interval__            -1.39
# b_impact__              -1.44
# per_0_ecc_interval__    -1.27
# per_0_omega_angle__     -0.50
# per_1_ecc_interval__    -1.22
# per_1_omega_angle__     -0.50
# per_2_ecc_interval__    -1.23
# per_2_omega_angle__     -0.50
# per_3_ecc_interval__    -1.39
# per_3_omega_angle__     -0.50
# per_4_ecc_interval__    -1.29
# per_4_omega_angle__     -0.50
# per_5_ecc_interval__    -9.13
# per_5_omega_angle__     -0.50
# per_6_ecc_interval__    -1.28
# per_6_omega_angle__     -0.50
# per_7_ecc_interval__    -1.94
# per_7_omega_angle__     -0.50
# per_8_ecc_interval__    -1.53
# per_8_omega_angle__     -0.50
# per_9_ecc_interval__    -1.65
# per_9_omega_angle__     -0.50
# per_10_ecc_interval__   -7.98
# per_10_omega_angle__    -0.50
# per_11_ecc_interval__   -3.96
# per_11_omega_angle__    -0.50
# per_12_ecc_interval__   -2.22
# per_12_omega_angle__    -0.50
# per_13_ecc_interval__   -2.35
# per_13_omega_angle__    -0.50
# per_14_ecc_interval__   -2.93
# per_14_omega_angle__    -0.50
# per_15_ecc_interval__   -1.42
# per_15_omega_angle__    -0.50
# per_16_ecc_interval__   -1.22
# per_16_omega_angle__    -0.50
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [per_16_omega, per_16_ecc, b, r, u, mean]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=8.856353e+03]
# 1it [00:00, 53.79it/s, logp=8.856353e+03]
# 2it [00:00, 73.57it/s, logp=8.856353e+03]
# 3it [00:00, 83.03it/s, logp=-1.017485e+09]
# 4it [00:00, 89.81it/s, logp=1.043807e+04]
# 5it [00:00, 95.14it/s, logp=9.800136e+03]
# 6it [00:00, 96.77it/s, logp=1.025128e+04]
# 7it [00:00, 97.33it/s, logp=1.028524e+04]
# 8it [00:00, 99.07it/s, logp=1.043898e+04]
# 9it [00:00, 99.32it/s, logp=1.044074e+04]
# 10it [00:00, 99.58it/s, logp=1.044651e+04]
# 11it [00:00, 108.68it/s, logp=1.044651e+04]
# 11it [00:00, 108.68it/s, logp=1.045508e+04]
# 12it [00:00, 108.68it/s, logp=1.046104e+04]
# 13it [00:00, 108.68it/s, logp=1.046385e+04]
# 14it [00:00, 108.68it/s, logp=1.046503e+04]
# 15it [00:00, 108.68it/s, logp=1.046520e+04]
# 16it [00:00, 108.68it/s, logp=1.046544e+04]
# 17it [00:00, 108.68it/s, logp=1.046541e+04]
# 18it [00:00, 108.68it/s, logp=1.046550e+04]
# 19it [00:00, 108.68it/s, logp=1.046551e+04]
# 20it [00:00, 108.68it/s, logp=1.046551e+04]
# 21it [00:00, 108.68it/s, logp=1.046551e+04]
# 22it [00:00, 108.68it/s, logp=1.046551e+04]
# 23it [00:00, 110.11it/s, logp=1.046551e+04]
# 23it [00:00, 110.11it/s, logp=1.046551e+04]
# 24it [00:00, 110.11it/s, logp=1.046551e+04]
# 25it [00:00, 110.11it/s, logp=1.046551e+04]
# 26it [00:00, 110.11it/s, logp=1.046551e+04]
# 27it [00:00, 110.11it/s, logp=1.046551e+04]
# 28it [00:00, 110.11it/s, logp=1.046551e+04]
# 29it [00:00, 110.11it/s, logp=1.046551e+04]
# 30it [00:00, 110.11it/s, logp=1.046551e+04]
# 31it [00:00, 110.11it/s, logp=1.046551e+04]
# 32it [00:00, 110.11it/s, logp=1.046551e+04]
# 33it [00:00, 110.11it/s, logp=1.046551e+04]
# 34it [00:00, 110.11it/s, logp=1.046551e+04]
# 35it [00:00, 110.71it/s, logp=1.046551e+04]
# 35it [00:00, 110.71it/s, logp=1.046551e+04]
# 36it [00:00, 110.71it/s, logp=1.046551e+04]
# 37it [00:00, 110.71it/s, logp=1.046551e+04]
# 38it [00:00, 110.71it/s, logp=1.046551e+04]
# 39it [00:00, 110.71it/s, logp=1.046551e+04]
# 40it [00:00, 110.71it/s, logp=1.046551e+04]
# 41it [00:00, 110.71it/s, logp=1.046551e+04]
# 42it [00:00, 110.71it/s, logp=1.046551e+04]
# 43it [00:00, 110.71it/s, logp=1.046551e+04]
# 44it [00:00, 110.71it/s, logp=1.046551e+04]
# 45it [00:00, 110.71it/s, logp=1.046551e+04]
# 46it [00:00, 110.71it/s, logp=1.046551e+04]
# 47it [00:00, 111.76it/s, logp=1.046551e+04]
# 47it [00:00, 111.76it/s, logp=1.046551e+04]
# 48it [00:00, 111.76it/s, logp=1.046551e+04]
# 49it [00:00, 111.76it/s, logp=1.046551e+04]
# 50it [00:00, 111.76it/s, logp=1.046551e+04]
# 51it [00:00, 111.76it/s, logp=1.046551e+04]
# 52it [00:00, 111.76it/s, logp=1.046551e+04]
# 53it [00:00, 111.76it/s, logp=1.046551e+04]
# 54it [00:00, 111.76it/s, logp=1.046551e+04]
# 55it [00:00, 111.76it/s, logp=1.046551e+04]
# 56it [00:00, 111.76it/s, logp=1.046551e+04]
# 57it [00:00, 111.76it/s, logp=1.046551e+04]
# 58it [00:00, 111.76it/s, logp=1.046551e+04]
# 59it [00:00, 111.73it/s, logp=1.046551e+04]
# 59it [00:00, 111.73it/s, logp=1.046551e+04]
# 60it [00:00, 111.73it/s, logp=1.046551e+04]
# 61it [00:00, 111.73it/s, logp=1.046551e+04]
# 62it [00:00, 111.73it/s, logp=1.046551e+04]
# 63it [00:00, 111.73it/s, logp=1.046551e+04]
# 64it [00:00, 111.73it/s, logp=1.046551e+04]
# 65it [00:00, 111.73it/s, logp=1.046551e+04]
# 66it [00:00, 111.73it/s, logp=1.046551e+04]
# 67it [00:00, 111.73it/s, logp=1.046551e+04]
# 68it [00:00, 111.73it/s, logp=1.046551e+04]
# 69it [00:00, 111.73it/s, logp=1.046551e+04]
# 70it [00:00, 111.73it/s, logp=1.046551e+04]
# 71it [00:00, 111.73it/s, logp=1.046551e+04]
# 71it [00:00, 111.73it/s, logp=1.046551e+04]
# 72it [00:00, 111.73it/s, logp=1.046551e+04]
# 73it [00:00, 111.73it/s, logp=1.046551e+04]
# 74it [00:00, 111.73it/s, logp=1.046551e+04]
# 75it [00:00, 111.73it/s, logp=1.046551e+04]
# 76it [00:00, 111.73it/s, logp=1.046551e+04]
# 77it [00:00, 111.73it/s, logp=1.046551e+04]
# 78it [00:00, 111.73it/s, logp=1.046551e+04]
# 79it [00:00, 111.73it/s, logp=1.046551e+04]
# 80it [00:00, 111.73it/s, logp=1.046551e+04]
# 81it [00:00, 111.73it/s, logp=1.046551e+04]
# 82it [00:00, 111.20it/s, logp=1.046551e+04]
# 82it [00:00, 111.20it/s, logp=1.046551e+04]
# 83it [00:00, 111.20it/s, logp=1.046551e+04]
# 84it [00:00, 111.20it/s, logp=1.046551e+04]
# 85it [00:00, 111.20it/s, logp=1.046551e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 86it [00:00, 111.20it/s, logp=1.046551e+04]
# 87it [00:00, 111.20it/s, logp=1.046551e+04]
# 88it [00:00, 111.20it/s, logp=1.046551e+04]
# 89it [00:00, 111.20it/s, logp=1.046551e+04]
# 90it [00:00, 111.20it/s, logp=1.046551e+04]
# 91it [00:00, 111.20it/s, logp=1.046551e+04]
# 92it [00:00, 111.20it/s, logp=1.046551e+04]
# 93it [00:00, 110.83it/s, logp=1.046551e+04]
# 93it [00:00, 110.83it/s, logp=1.046551e+04]
# 94it [00:00, 110.83it/s, logp=1.046551e+04]
# 95it [00:00, 110.83it/s, logp=1.046551e+04]
# 96it [00:00, 110.83it/s, logp=1.046551e+04]
# 97it [00:00, 110.83it/s, logp=1.046551e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 98it [00:10,  9.68it/s, logp=1.046551e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 8856.353014608565 -> 10465.509436267532
# optimizing logp for variables: [per_16_omega, per_16_ecc, per_15_omega, per_15_ecc, per_14_omega, per_14_ecc, per_13_omega, per_13_ecc, per_12_omega, per_12_ecc, per_11_omega, per_11_ecc, per_10_omega, per_10_ecc, per_9_omega, per_9_ecc, per_8_omega, per_8_ecc, per_7_omega, per_7_ecc, per_6_omega, per_6_ecc, per_5_omega, per_5_ecc, per_4_omega, per_4_ecc, per_3_omega, per_3_ecc, per_2_omega, per_2_ecc, per_1_omega, per_1_ecc, per_0_omega, per_0_ecc, b, r, u, t0_2, t0_1, mean]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=1.046551e+04]
# 1it [00:00, 35.46it/s, logp=1.046551e+04]
# 2it [00:00, 49.12it/s, logp=1.046551e+04]
# 3it [00:00, 55.42it/s, logp=1.022022e+04]
# 4it [00:00, 58.95it/s, logp=1.037436e+04]
# 5it [00:00, 62.65it/s, logp=1.046317e+04]
# 6it [00:00, 64.52it/s, logp=1.046636e+04]
# 7it [00:00, 65.33it/s, logp=-1.796724e+03]
# 8it [00:00, 74.11it/s, logp=-1.796724e+03]
# 8it [00:00, 74.11it/s, logp=1.046636e+04]
# 9it [00:00, 74.11it/s, logp=1.046636e+04]
# 10it [00:00, 74.11it/s, logp=1.046636e+04]
# 11it [00:00, 74.11it/s, logp=1.046636e+04]
# 12it [00:00, 74.11it/s, logp=1.046637e+04]
# 13it [00:00, 74.11it/s, logp=1.046640e+04]
# 14it [00:00, 74.11it/s, logp=1.046651e+04]
# 15it [00:00, 74.11it/s, logp=1.046695e+04]
# 16it [00:00, 75.39it/s, logp=1.046695e+04]
# 16it [00:00, 75.39it/s, logp=1.046813e+04]
# 17it [00:00, 75.39it/s, logp=1.047283e+04]
# 18it [00:00, 75.39it/s, logp=1.049081e+04]
# 19it [00:00, 75.39it/s, logp=1.055265e+04]
# 20it [00:00, 75.39it/s, logp=1.043324e+04]
# 21it [00:00, 75.39it/s, logp=1.052565e+04]
# 22it [00:00, 75.39it/s, logp=1.055489e+04]
# 23it [00:00, 75.39it/s, logp=1.055921e+04]
# 24it [00:00, 75.39it/s, logp=1.057511e+04]
# 25it [00:00, 77.61it/s, logp=1.057511e+04]
# 25it [00:00, 77.61it/s, logp=1.061088e+04]
# 26it [00:00, 77.61it/s, logp=1.064227e+04]
# 27it [00:00, 77.61it/s, logp=1.068553e+04]
# 28it [00:00, 77.61it/s, logp=1.072674e+04]
# 29it [00:00, 77.61it/s, logp=1.077057e+04]
# 30it [00:00, 77.61it/s, logp=1.079193e+04]
# 31it [00:00, 77.61it/s, logp=1.080530e+04]
# 32it [00:00, 77.61it/s, logp=1.081262e+04]
# 33it [00:00, 77.61it/s, logp=1.081318e+04]
# 34it [00:00, 79.77it/s, logp=1.081318e+04]
# 34it [00:00, 79.77it/s, logp=1.081413e+04]
# 35it [00:00, 79.77it/s, logp=1.081523e+04]
# 36it [00:00, 79.77it/s, logp=1.081571e+04]
# 37it [00:00, 79.77it/s, logp=1.081593e+04]
# 38it [00:00, 79.77it/s, logp=1.081603e+04]
# 39it [00:00, 79.77it/s, logp=1.081611e+04]
# 40it [00:00, 79.77it/s, logp=1.081609e+04]
# 41it [00:00, 79.77it/s, logp=1.081613e+04]
# 42it [00:00, 79.77it/s, logp=1.081617e+04]
# 43it [00:00, 81.90it/s, logp=1.081617e+04]
# 43it [00:00, 81.90it/s, logp=1.081623e+04]
# 44it [00:00, 81.90it/s, logp=1.081633e+04]
# 45it [00:00, 81.90it/s, logp=1.081652e+04]
# 46it [00:00, 81.90it/s, logp=1.081689e+04]
# 47it [00:00, 81.90it/s, logp=1.081635e+04]
# 48it [00:00, 81.90it/s, logp=1.081717e+04]
# 49it [00:00, 81.90it/s, logp=1.081636e+04]
# 50it [00:00, 81.90it/s, logp=1.081729e+04]
# 51it [00:00, 81.90it/s, logp=1.081749e+04]
# 52it [00:00, 83.02it/s, logp=1.081749e+04]
# 52it [00:00, 83.02it/s, logp=1.081778e+04]
# 53it [00:00, 83.02it/s, logp=1.081800e+04]
# 54it [00:00, 83.02it/s, logp=1.081817e+04]
# 55it [00:00, 83.02it/s, logp=1.081835e+04]
# 56it [00:00, 83.02it/s, logp=1.081839e+04]
# 57it [00:00, 83.02it/s, logp=1.081842e+04]
# 58it [00:00, 83.02it/s, logp=1.081847e+04]
# 59it [00:00, 83.02it/s, logp=1.081853e+04]
# 60it [00:00, 83.02it/s, logp=1.081860e+04]
# 61it [00:00, 82.89it/s, logp=1.081860e+04]
# 61it [00:00, 82.89it/s, logp=1.081871e+04]
# 62it [00:00, 82.89it/s, logp=1.081879e+04]
# 63it [00:00, 82.89it/s, logp=1.081885e+04]
# 64it [00:00, 82.89it/s, logp=1.081889e+04]
# 65it [00:00, 82.89it/s, logp=1.081891e+04]
# 66it [00:00, 82.89it/s, logp=1.081892e+04]
# 67it [00:00, 82.89it/s, logp=1.081892e+04]
# 68it [00:00, 82.89it/s, logp=1.081892e+04]
# 69it [00:00, 82.89it/s, logp=1.081894e+04]
# 70it [00:00, 83.58it/s, logp=1.081894e+04]
# 70it [00:00, 83.58it/s, logp=1.081895e+04]
# 71it [00:00, 83.58it/s, logp=1.081895e+04]
# 72it [00:00, 83.58it/s, logp=1.081896e+04]
# 73it [00:00, 83.58it/s, logp=1.081898e+04]
# 74it [00:00, 83.58it/s, logp=1.081900e+04]
# 75it [00:00, 83.58it/s, logp=1.081901e+04]
# 76it [00:00, 83.58it/s, logp=1.081901e+04]
# 77it [00:00, 83.58it/s, logp=1.081901e+04]
# 78it [00:00, 83.58it/s, logp=1.081902e+04]
# 79it [00:00, 83.45it/s, logp=1.081902e+04]
# 79it [00:00, 83.45it/s, logp=1.081903e+04]
# 80it [00:00, 83.45it/s, logp=1.081903e+04]
# 81it [00:00, 83.45it/s, logp=1.081904e+04]
# 82it [00:01, 83.45it/s, logp=1.081904e+04]
# 83it [00:01, 83.45it/s, logp=1.081904e+04]
# 84it [00:01, 83.45it/s, logp=1.081904e+04]
# 85it [00:01, 83.45it/s, logp=1.081904e+04]
# 86it [00:01, 83.45it/s, logp=1.081904e+04]
# 87it [00:01, 83.45it/s, logp=1.081904e+04]
# 88it [00:01, 82.96it/s, logp=1.081904e+04]
# 88it [00:01, 82.96it/s, logp=1.081904e+04]
# 89it [00:01, 82.96it/s, logp=1.081904e+04]
# 90it [00:01, 82.96it/s, logp=1.081904e+04]
# 91it [00:01, 82.96it/s, logp=1.081904e+04]
# 92it [00:01, 82.96it/s, logp=1.081904e+04]
# 93it [00:01, 82.96it/s, logp=1.081904e+04]
# 94it [00:01, 82.96it/s, logp=1.081904e+04]
# 95it [00:01, 82.96it/s, logp=1.081905e+04]
# 96it [00:01, 82.96it/s, logp=1.081905e+04]
# 97it [00:01, 84.01it/s, logp=1.081905e+04]
# 97it [00:01, 84.01it/s, logp=1.081905e+04]
# 98it [00:01, 84.01it/s, logp=1.081905e+04]
# 99it [00:01, 84.01it/s, logp=1.081905e+04]
# 100it [00:01, 84.01it/s, logp=1.081905e+04]
# 101it [00:01, 84.01it/s, logp=1.081905e+04]
# 102it [00:01, 84.01it/s, logp=1.081905e+04]
# 103it [00:01, 84.01it/s, logp=1.081905e+04]
# 104it [00:01, 84.01it/s, logp=1.081905e+04]
# 105it [00:01, 84.01it/s, logp=1.081905e+04]
# 106it [00:01, 84.35it/s, logp=1.081905e+04]
# 106it [00:01, 84.35it/s, logp=1.081905e+04]
# 107it [00:01, 84.35it/s, logp=1.081905e+04]
# 108it [00:01, 84.35it/s, logp=1.081905e+04]
# 109it [00:01, 84.35it/s, logp=1.081905e+04]
# 110it [00:01, 84.35it/s, logp=1.081905e+04]
# 111it [00:01, 84.35it/s, logp=1.081905e+04]
# 112it [00:01, 84.35it/s, logp=1.081905e+04]
# 113it [00:01, 84.35it/s, logp=1.081905e+04]
# 114it [00:01, 84.35it/s, logp=1.081905e+04]
# 115it [00:01, 84.23it/s, logp=1.081905e+04]
# 115it [00:01, 84.23it/s, logp=1.081905e+04]
# 116it [00:01, 84.23it/s, logp=1.081905e+04]
# 117it [00:01, 84.23it/s, logp=1.081905e+04]
# 118it [00:01, 84.23it/s, logp=1.081905e+04]
# 119it [00:01, 84.23it/s, logp=1.081905e+04]
# 120it [00:01, 84.23it/s, logp=1.081905e+04]
# 121it [00:01, 84.23it/s, logp=1.081905e+04]
# 122it [00:01, 84.23it/s, logp=1.081905e+04]
# 123it [00:01, 84.23it/s, logp=1.081905e+04]
# 124it [00:01, 85.85it/s, logp=1.081905e+04]
# 124it [00:01, 85.85it/s, logp=1.081905e+04]
# 125it [00:01, 85.85it/s, logp=1.081905e+04]
# 126it [00:01, 85.85it/s, logp=1.081905e+04]
# 127it [00:01, 85.85it/s, logp=1.081905e+04]
# 128it [00:01, 85.85it/s, logp=1.081905e+04]
# 129it [00:01, 85.85it/s, logp=1.081905e+04]
# 130it [00:01, 85.85it/s, logp=1.081905e+04]
# 131it [00:01, 85.85it/s, logp=1.081905e+04]
# 132it [00:01, 85.85it/s, logp=1.081905e+04]
# 133it [00:01, 86.04it/s, logp=1.081905e+04]
# 133it [00:01, 86.04it/s, logp=1.081905e+04]
# 134it [00:01, 86.04it/s, logp=1.081905e+04]
# 135it [00:01, 86.04it/s, logp=1.081905e+04]
# 136it [00:01, 86.04it/s, logp=1.081905e+04]
# 137it [00:01, 86.04it/s, logp=1.081905e+04]
# 138it [00:01, 86.04it/s, logp=1.081905e+04]
# 139it [00:01, 86.04it/s, logp=1.081905e+04]
# 140it [00:01, 86.04it/s, logp=1.081905e+04]
# 141it [00:01, 86.04it/s, logp=1.081905e+04]
# 142it [00:01, 86.10it/s, logp=1.081905e+04]
# 142it [00:01, 86.10it/s, logp=1.081905e+04]
# 143it [00:01, 86.10it/s, logp=1.081905e+04]
# 144it [00:01, 86.10it/s, logp=1.081905e+04]
# 145it [00:01, 86.10it/s, logp=1.081905e+04]
# 146it [00:01, 86.10it/s, logp=1.081905e+04]
# 147it [00:01, 86.10it/s, logp=1.081905e+04]
# 148it [00:01, 86.10it/s, logp=1.081905e+04]
# 149it [00:01, 86.10it/s, logp=1.081905e+04]
# 150it [00:01, 86.10it/s, logp=1.081905e+04]
# 151it [00:01, 86.98it/s, logp=1.081905e+04]
# 151it [00:01, 86.98it/s, logp=1.081905e+04]
# 152it [00:01, 86.98it/s, logp=1.081905e+04]
# 153it [00:01, 86.98it/s, logp=1.081905e+04]
# 154it [00:01, 86.98it/s, logp=1.081905e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 155it [00:01, 86.98it/s, logp=1.081905e+04]
# 156it [00:01, 86.98it/s, logp=1.081905e+04]
# 157it [00:01, 86.98it/s, logp=1.081905e+04]
# 158it [00:01, 86.98it/s, logp=1.081905e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 159it [00:01, 86.98it/s, logp=1.081905e+04]
# 160it [00:01, 84.98it/s, logp=1.081905e+04]
# 160it [00:01, 84.98it/s, logp=1.081905e+04]
# 161it [00:01, 84.98it/s, logp=1.081905e+04]
# 162it [00:01, 84.98it/s, logp=1.081905e+04]
# 163it [00:01, 84.98it/s, logp=1.081905e+04]
# 164it [00:01, 84.98it/s, logp=1.081905e+04]
# 165it [00:01, 84.98it/s, logp=1.081905e+04]
# 166it [00:01, 84.98it/s, logp=1.081905e+04]
# 167it [00:01, 84.98it/s, logp=1.081905e+04]
# 168it [00:02, 84.98it/s, logp=1.081905e+04]
# 169it [00:02, 85.04it/s, logp=1.081905e+04]
# 169it [00:02, 85.04it/s, logp=1.081905e+04]
# 170it [00:02, 85.04it/s, logp=1.081905e+04]
# 171it [00:02, 85.04it/s, logp=1.081905e+04]
# 172it [00:02, 85.04it/s, logp=1.081905e+04]
# 173it [00:02, 85.04it/s, logp=1.081905e+04]
# 174it [00:02, 85.04it/s, logp=1.081905e+04]
# 175it [00:02, 85.04it/s, logp=1.081905e+04]
# 176it [00:02, 85.04it/s, logp=1.081905e+04]
# 177it [00:02, 85.04it/s, logp=1.081905e+04]
# 178it [00:02, 86.06it/s, logp=1.081905e+04]
# 178it [00:02, 86.06it/s, logp=1.081905e+04]
# 179it [00:02, 86.06it/s, logp=1.081905e+04]
# 180it [00:02, 86.06it/s, logp=1.081905e+04]
# 181it [00:02, 86.06it/s, logp=1.081905e+04]
# 182it [00:02, 86.06it/s, logp=1.081905e+04]
# 183it [00:02, 86.06it/s, logp=1.081905e+04]
# 184it [00:02, 86.06it/s, logp=1.081905e+04]
# 185it [00:02, 86.06it/s, logp=1.081905e+04]
# 186it [00:02, 86.06it/s, logp=1.081905e+04]
# 187it [00:02, 87.02it/s, logp=1.081905e+04]
# 187it [00:02, 87.02it/s, logp=1.081905e+04]
# 188it [00:02, 87.02it/s, logp=1.081905e+04]
# 189it [00:02, 87.02it/s, logp=1.081905e+04]
# 190it [00:02, 87.02it/s, logp=1.081905e+04]
# 191it [00:02, 87.02it/s, logp=1.081905e+04]
# 192it [00:02, 87.02it/s, logp=1.081905e+04]
# 193it [00:02, 87.02it/s, logp=1.081905e+04]
# 194it [00:02, 87.02it/s, logp=1.081905e+04]
# 195it [00:02, 87.02it/s, logp=1.081905e+04]
# 196it [00:02, 87.07it/s, logp=1.081905e+04]
# 196it [00:02, 87.07it/s, logp=1.081905e+04]
# 197it [00:02, 87.07it/s, logp=1.081905e+04]
# 198it [00:02, 87.07it/s, logp=1.081905e+04]
# 199it [00:02, 87.07it/s, logp=1.081905e+04]
# 200it [00:02, 87.07it/s, logp=1.081905e+04]
# 201it [00:02, 87.07it/s, logp=1.081905e+04]
# 202it [00:02, 87.07it/s, logp=1.081905e+04]
# 203it [00:02, 87.07it/s, logp=1.081905e+04]
# 204it [00:02, 87.07it/s, logp=1.081905e+04]
# 205it [00:02, 86.69it/s, logp=1.081905e+04]
# 205it [00:02, 86.69it/s, logp=1.081905e+04]
# 206it [00:02, 86.69it/s, logp=1.081905e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 207it [00:02, 86.69it/s, logp=1.081905e+04]
# 208it [00:02, 86.69it/s, logp=1.081905e+04]
# 209it [00:02, 86.69it/s, logp=1.081905e+04]
# 210it [00:02, 86.69it/s, logp=1.081905e+04]
# 211it [00:02, 86.69it/s, logp=1.081905e+04]
# 212it [00:02, 86.69it/s, logp=1.081905e+04]
# 213it [00:02, 86.69it/s, logp=1.081905e+04]
# 214it [00:02, 85.27it/s, logp=1.081905e+04]
# 214it [00:02, 85.27it/s, logp=1.081905e+04]
# 215it [00:02, 85.27it/s, logp=1.081905e+04]
# 216it [00:02, 85.27it/s, logp=1.081905e+04]
# 217it [00:02, 85.27it/s, logp=1.081905e+04]
# 218it [00:02, 85.27it/s, logp=1.081905e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 219it [00:15, 14.56it/s, logp=1.081905e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10465.509436267532 -> 10819.048489652103

# %%
map_soln_ecc_2
# Out:
# {'mean': array(1.00125844),
#  't0_1': array(105.5642482),
#  't0_2': array(205.56824355),
#  'u_quadlimbdark__': array([-1.25900062, -0.50065717]),
#  'r_interval__': array(-0.08299073),
#  'b_impact__': array(-0.50148454),
#  'per_0_ecc_interval__': array(-1.25126341),
#  'per_0_omega_angle__': array([0.09100466, 4.47120992]),
#  'per_1_ecc_interval__': array(-1.25211515),
#  'per_1_omega_angle__': array([0.56057212, 4.43686365]),
#  'per_2_ecc_interval__': array(-1.25236633),
#  'per_2_omega_angle__': array([-2.06495865, -3.96685592]),
#  'per_3_ecc_interval__': array(-1.25126341),
#  'per_3_omega_angle__': array([-0.00762802,  4.47212946]),
#  'per_4_ecc_interval__': array(-1.25126341),
#  'per_4_omega_angle__': array([-3.89276203e-07,  4.47213596e+00]),
#  'per_5_ecc_interval__': array(-1.25126342),
#  'per_5_omega_angle__': array([-1.20766791e-09,  4.47213596e+00]),
#  'per_6_ecc_interval__': array(-1.25126341),
#  'per_6_omega_angle__': array([-4.51115115e-12,  4.47213596e+00]),
#  'per_7_ecc_interval__': array(-1.25126341),
#  'per_7_omega_angle__': array([-7.76358150e-14,  4.47213596e+00]),
#  'per_8_ecc_interval__': array(-1.25126341),
#  'per_8_omega_angle__': array([-3.26238843e-16,  4.47213596e+00]),
#  'per_9_ecc_interval__': array(-1.25126341),
#  'per_9_omega_angle__': array([-2.84088708e-18,  4.47213596e+00]),
#  'per_10_ecc_interval__': array(-1.25126341),
#  'per_10_omega_angle__': array([-1.52229520e-19,  4.47213596e+00]),
#  'per_11_ecc_interval__': array(-1.25126341),
#  'per_11_omega_angle__': array([-1.03714952e-21,  4.47213596e+00]),
#  'per_12_ecc_interval__': array(-1.25126341),
#  'per_12_omega_angle__': array([-2.16429351e-23,  4.47213596e+00]),
#  'per_13_ecc_interval__': array(-1.25126341),
#  'per_13_omega_angle__': array([-1.58855247e-24,  4.47213596e+00]),
#  'per_14_ecc_interval__': array(-1.25126341),
#  'per_14_omega_angle__': array([-1.60028725e-25,  4.47213596e+00]),
#  'per_15_ecc_interval__': array(-1.25126341),
#  'per_15_omega_angle__': array([-5.00685783e-27,  4.47213596e+00]),
#  'per_16_ecc_interval__': array(-1.25126341),
#  'per_16_omega_angle__': array([1.47473846, 4.22198372]),
#  'u': array([0.35494052, 0.11532108]),
#  'r': array(0.05313378),
#  'b': array(0.39723349),
#  'periods': array([100.00399535,  50.00199768,  33.33466512,  25.00099884,
#          20.00079907,  16.66733256,  14.28628505,  12.50049942,
#          11.11155504,  10.00039954,   9.0912723 ,   8.33366628,
#           7.69261503,   7.14314253,   6.66693302,   6.25024971,
#           5.88258796]),
#  'per_0_ecc': array(0.22248706),
#  'per_0_omega': array(0.02035066),
#  'per_0_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_1_ecc': array(0.22233976),
#  'per_1_omega': array(0.12567832),
#  'per_1_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_2_ecc': array(0.22229634),
#  'per_2_omega': array(-2.66163818),
#  'per_2_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_3_ecc': array(0.22248706),
#  'per_3_omega': array(-0.00170568),
#  'per_3_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_4_ecc': array(0.22248706),
#  'per_4_omega': array(-8.70448051e-08),
#  'per_4_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_5_ecc': array(0.22248706),
#  'per_5_omega': array(-2.70042753e-10),
#  'per_5_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_6_ecc': array(0.22248706),
#  'per_6_omega': array(-1.00872406e-12),
#  'per_6_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_7_ecc': array(0.22248706),
#  'per_7_omega': array(-1.7359896e-14),
#  'per_7_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_8_ecc': array(0.22248706),
#  'per_8_omega': array(-7.29492229e-17),
#  'per_8_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_9_ecc': array(0.22248706),
#  'per_9_omega': array(-6.35241663e-19),
#  'per_9_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_10_ecc': array(0.22248706),
#  'per_10_omega': array(-3.40395555e-20),
#  'per_10_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_11_ecc': array(0.22248706),
#  'per_11_omega': array(-2.31913682e-22),
#  'per_11_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_12_ecc': array(0.22248706),
#  'per_12_omega': array(-4.83950741e-24),
#  'per_12_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_13_ecc': array(0.22248706),
#  'per_13_omega': array(-3.55211131e-25),
#  'per_13_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_14_ecc': array(0.22248706),
#  'per_14_omega': array(-3.57835106e-26),
#  'per_14_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_15_ecc': array(0.22248706),
#  'per_15_omega': array(-1.11956744e-27),
#  'per_15_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'per_16_ecc': array(0.22248706),
#  'per_16_omega': array(0.33605098),
#  'per_16_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844]),
#  'logprob_class': array([-37.48837471,  -1.37458874,  -0.2916146 , -24.8914207 ,
#         -37.36834519, -45.22234035, -51.72497831, -58.03583506,
#         -62.9002837 , -67.31340095, -70.30727305, -72.3109879 ,
#         -74.177647  , -76.58002118, -79.33808642, -81.89709879,
#         -89.80536015]),
#  'logprior_class': array([-12.28056037, -10.43216789,  -9.3509276 ,  -8.58377541,
#          -7.98872594,  -7.50253512,  -7.09146664,  -6.73538293,
#          -6.42129483,  -6.14033346,  -5.88617298,  -5.65414264,
#          -5.44069542,  -5.24307416,  -5.05909317,  -4.88699044,
#          -4.72532479]),
#  'marginalized_light_curve': array([1.00125844, 1.00125844, 1.00125844, ..., 1.00125844, 1.00125844,
#         1.00125844])}

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_ecc_2["periods"], map_soln_ecc_2["logprob_class"], "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized simple model period probability with eccentric orbit")
plt.plot(map_soln_ecc_2["periods"],map_soln_ecc_2["logprior_class"],'-o',label='log_priors')
plt.ylabel('log(prob)')
plt.legend(loc=3)
ax2 = plt.gca().twinx()
ax2.set_ylabel('ecc')  # we already handled the x-label with ax1
#ax2.plot(map_soln_ecc_2["periods"], [map_soln_ecc_2['per_'+str(n)+'_omega'] for n in range(17)],'-or',label='omega')
ax2.plot(map_soln_ecc_2["periods"], [map_soln_ecc_2['per_'+str(n)+'_ecc'] for n in range(17)],'-ok',label='ecc')
#[map_soln['per_'+str(n)+'_log_prior'] for n in range(17)],'-o',label='log_priors')
plt.legend(loc=4)

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_ecc_2["per_16_light_curve"][:1000],alpha=0.5)
plt.plot(x[:1000],map_soln_ecc_2["per_1_light_curve"][:1000],alpha=0.5)
plt.plot(x[:1000],map_soln_ecc_2["marginalized_light_curve"][:1000],'--',alpha=0.75,linewidth=2.0)

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_ecc_2["per_16_light_curve"][1000:],alpha=0.5)
plt.plot(x[1000:],map_soln_ecc_2["per_1_light_curve"][1000:],alpha=0.5)
plt.plot(x[1000:],map_soln_ecc_2["marginalized_light_curve"][1000:],'--',alpha=0.75,linewidth=2.0)

# %% [markdown]
# Ok, that's slightly weird - why is the 33d period now the most likely? And why is eccentricity so stuck at 0.222?

# %% [markdown]
# # Adding both GPs & eccentricity
#
# But let's not marginalise over ecc or omega just yet

# %%
with pm.Model() as model_gp_ecc:

    #Baseline flux is now in the GPs, so deleting this:
    #mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    #Initialising eccentricity and omega:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)
    ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
    omega = xo.distributions.Angle("omega")

    logprobs = []
    logpriors= []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=model_gp_ecc) as submodel:
            
            period = periods[i]
            
            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1)
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred = pm.Deterministic("gp_pred", gp.predict())
            gp_preds.append(gp.predict())
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-8/3 (occurrence rate (P^-1) * window function (P^-1) * transit probability (P^-2/3) )
            logprior = -8 / 3 * tt.log(period) 
            logprobs.append(loglike + logprior)
            logpriors.append(logprior)

    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    logprior_class = pm.Deterministic("logprior_class", tt.stack(logpriors))
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve and gp prediction
    pm.Deterministic("marginalized_light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    pm.Deterministic("marginalized_gp_pred", tt.sum(tt.stack(gp_preds) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(model_gp_ecc.test_point)
    print(model_gp_ecc.check_test_point())
    map_soln_gp_ecc = xo.optimize(vars=[r, b])
    map_soln_gp_ecc = xo.optimize(start=map_soln_gp_ecc, vars=[logs2])
    map_soln_gp_ecc = xo.optimize(start=map_soln_gp_ecc, vars=[t0_1, t0_2])
    map_soln_gp_ecc = xo.optimize(start=map_soln_gp_ecc, vars=[logs2, logpower])
    map_soln_gp_ecc = xo.optimize(start=map_soln_gp_ecc, vars=[logw0])
    map_soln_gp_ecc = xo.optimize(start=map_soln_gp_ecc, vars=[r,b,ecc,Rs,u])

    map_soln_gp_ecc = xo.optimize(map_soln_gp_ecc)
# Out:
# {'Rs': array(1.), 'logrho_S': array(0.), 't0_1': array(105.57), 't0_2': array(205.57), 'u_quadlimbdark__': array([-1.09861229, -0.84729786]), 'r_interval__': array(0.), 'b_impact__': array(-0.59116847), 'logs2': array(-6.65444898), 'logw0_interval__': array(-0.60183699), 'logpower_interval__': array(1.18693347), 'ecc_interval__': array(-1.11022302e-16), 'omega_angle__': array([0., 1.])}
# Rs                     0.29
# logrho_S              -0.23
# t0_1                  -0.00
# t0_2                  -0.00
# u_quadlimbdark__      -3.23
# r_interval__          -1.39
# b_impact__            -1.47
# logs2                 -0.92
# logw0_interval__      -1.48
# logpower_interval__   -1.72
# ecc_interval__        -1.85
# omega_angle__         -0.50
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [b, r, Rs]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-1.672495e+04]
# 1it [00:00, 63.75it/s, logp=-1.672495e+04]
# 2it [00:00, 83.60it/s, logp=-1.672495e+04]
# 3it [00:00, 91.33it/s, logp=-1.671567e+04]
# 4it [00:00, 96.29it/s, logp=-1.671585e+04]
# 5it [00:00, 98.87it/s, logp=-1.671531e+04]
# 6it [00:00, 94.84it/s, logp=-1.671471e+04]
# 7it [00:00, 93.11it/s, logp=-1.671406e+04]
# 8it [00:00, 93.17it/s, logp=-1.671397e+04]
# 9it [00:00, 92.89it/s, logp=-1.671396e+04]
# 10it [00:00, 93.12it/s, logp=-1.671396e+04]
# 11it [00:00, 101.36it/s, logp=-1.671396e+04]
# 11it [00:00, 101.36it/s, logp=-1.671395e+04]
# 12it [00:00, 101.36it/s, logp=-1.671395e+04]
# 13it [00:00, 101.36it/s, logp=-1.671395e+04]
# 14it [00:00, 101.36it/s, logp=-1.671395e+04]
# 15it [00:00, 101.36it/s, logp=-1.671395e+04]
# 16it [00:11,  1.35it/s, logp=-1.671395e+04]
# message: Optimization terminated successfully.
# logp: -16724.951510485695 -> -16713.954663209875
# optimizing logp for variables: [logs2]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-1.671395e+04]
# 1it [00:00, 56.41it/s, logp=-1.671395e+04]
# 2it [00:00, 75.24it/s, logp=-1.671395e+04]
# 3it [00:00, 85.78it/s, logp=-1.616640e+04]
# 4it [00:00, 92.19it/s, logp=-4.235771e+03]
# 5it [00:00, 96.44it/s, logp=-1.663474e+04]
# 6it [00:00, 97.81it/s, logp=-4.143676e+03]
# 7it [00:00, 99.19it/s, logp=-2.825790e+03]
# 8it [00:00, 101.39it/s, logp=-4.391634e+03]
# 9it [00:00, 102.53it/s, logp=-2.823808e+03]
# 10it [00:00, 103.81it/s, logp=-2.823751e+03]
# 11it [00:00, 105.16it/s, logp=-2.823751e+03]
# 12it [00:00, 113.86it/s, logp=-2.823751e+03]
# 13it [00:12,  1.01it/s, logp=-2.823751e+03]
# message: Optimization terminated successfully.
# logp: -16713.954663209875 -> -2823.7513164651095
# optimizing logp for variables: [t0_2, t0_1]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-2.823751e+03]
# 1it [00:00, 61.13it/s, logp=-2.823751e+03]
# 2it [00:00, 80.75it/s, logp=-2.823751e+03]
# 3it [00:00, 90.86it/s, logp=-2.823768e+03]
# 4it [00:00, 91.45it/s, logp=-2.823752e+03]
# 5it [00:00, 91.82it/s, logp=-2.823751e+03]
# 6it [00:00, 92.77it/s, logp=-2.823752e+03]
# 7it [00:00, 93.81it/s, logp=-2.823751e+03]
# 8it [00:00, 93.97it/s, logp=-2.823751e+03]
# 9it [00:00, 94.40it/s, logp=-2.823751e+03]
# 10it [00:00, 93.70it/s, logp=-2.823751e+03]
# 11it [00:00, 102.01it/s, logp=-2.823751e+03]
# 11it [00:00, 102.01it/s, logp=-2.823751e+03]
# 12it [00:00, 102.01it/s, logp=-2.823751e+03]
# 13it [00:00, 102.01it/s, logp=-2.823751e+03]
# 14it [00:00, 102.01it/s, logp=-2.823751e+03]
# 15it [00:00, 102.01it/s, logp=-2.823751e+03]
# 16it [00:00, 102.01it/s, logp=-2.823751e+03]
# 18it [00:10,  1.78it/s, logp=-2.823751e+03]
# message: Optimization terminated successfully.
# logp: -2823.7513164651095 -> -2823.7512504260417
# optimizing logp for variables: [logpower, logs2]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-2.823751e+03]
# 1it [00:00, 16.76it/s, logp=-2.823751e+03]
# 2it [00:00, 28.04it/s, logp=-2.823751e+03]
# 3it [00:00, 36.89it/s, logp=-2.607402e+03]
# 4it [00:00, 42.74it/s, logp=-2.286264e+03]
# 5it [00:00, 44.93it/s, logp=-1.202179e+03]
# 6it [00:00, 52.69it/s, logp=-1.202179e+03]
# 6it [00:00, 52.69it/s, logp=3.897608e+03]
# 7it [00:00, 52.69it/s, logp=-7.246079e+06]
# 8it [00:00, 52.69it/s, logp=3.908209e+03]
# 9it [00:00, 52.69it/s, logp=-9.899432e+05]
# 10it [00:00, 52.69it/s, logp=7.982273e+03]
# 11it [00:00, 52.69it/s, logp=-3.642532e+04]
# 12it [00:00, 52.69it/s, logp=9.343304e+03]
# 13it [00:00, 55.89it/s, logp=9.343304e+03]
# 13it [00:00, 55.89it/s, logp=-6.909675e+06]
# 14it [00:00, 55.89it/s, logp=9.344162e+03]
# 15it [00:00, 55.89it/s, logp=9.466944e+03]
# 16it [00:00, 55.89it/s, logp=9.467143e+03]
# 17it [00:00, 55.89it/s, logp=9.467192e+03]
# 18it [00:00, 55.89it/s, logp=9.467286e+03]
# 19it [00:00, 55.11it/s, logp=9.467286e+03]
# 19it [00:00, 55.11it/s, logp=9.467462e+03]
# 20it [00:00, 55.11it/s, logp=9.467796e+03]
# 21it [00:00, 55.11it/s, logp=9.468425e+03]
# 22it [00:00, 55.11it/s, logp=9.469587e+03]
# 23it [00:00, 55.11it/s, logp=9.471673e+03]
# 24it [00:00, 55.11it/s, logp=9.475269e+03]
# 25it [00:00, 55.11it/s, logp=9.481224e+03]
# 26it [00:00, 58.70it/s, logp=9.481224e+03]
# 26it [00:00, 58.70it/s, logp=9.491072e+03]
# 27it [00:00, 58.70it/s, logp=9.495411e+03]
# 28it [00:00, 58.70it/s, logp=9.491948e+03]
# 29it [00:00, 58.70it/s, logp=9.503285e+03]
# 30it [00:00, 58.70it/s, logp=-3.419390e+08]
# 31it [00:00, 58.70it/s, logp=9.503285e+03]
# 32it [00:00, 58.70it/s, logp=9.503285e+03]
# 33it [00:00, 58.70it/s, logp=-5.063811e+07]
# 34it [00:00, 58.70it/s, logp=9.507111e+03]
# 35it [00:00, 58.70it/s, logp=9.196410e+03]
# 36it [00:00, 66.24it/s, logp=9.196410e+03]
# 36it [00:00, 66.24it/s, logp=9.508632e+03]
# 37it [00:00, 66.24it/s, logp=9.511631e+03]
# 38it [00:00, 66.24it/s, logp=9.522173e+03]
# 39it [00:00, 66.24it/s, logp=9.540377e+03]
# 40it [00:00, 66.24it/s, logp=9.543038e+03]
# 41it [00:00, 66.24it/s, logp=9.543045e+03]
# 42it [00:00, 66.24it/s, logp=9.543105e+03]
# 43it [00:00, 66.24it/s, logp=9.543108e+03]
# 44it [00:00, 69.15it/s, logp=9.543108e+03]
# 44it [00:00, 69.15it/s, logp=9.543108e+03]
# 46it [00:13,  3.46it/s, logp=9.543108e+03]
# message: Optimization terminated successfully.
# logp: -2823.7512504260417 -> 9543.10825173744
# optimizing logp for variables: [logw0]
#
# 0it [00:00, ?it/s]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 0it [00:00, ?it/s, logp=9.543108e+03]
# 1it [00:00, 50.89it/s, logp=9.543108e+03]
# 2it [00:00, 68.00it/s, logp=9.543108e+03]
# 3it [00:00, 75.66it/s, logp=1.068859e+04]
# 4it [00:00, 81.70it/s, logp=1.068859e+04]
# 5it [00:00, 86.14it/s, logp=1.068859e+04]
# 6it [00:00, 90.20it/s, logp=1.068861e+04]
# 7it [00:00, 93.45it/s, logp=1.068867e+04]
# 8it [00:00, 96.02it/s, logp=1.068876e+04]
# 9it [00:00, 97.75it/s, logp=1.068877e+04]
# 10it [00:00, 99.45it/s, logp=1.068877e+04]
# 11it [00:00, 108.67it/s, logp=1.068877e+04]
# 11it [00:00, 108.67it/s, logp=1.068877e+04]
# 12it [00:00, 108.67it/s, logp=1.068877e+04]
# 13it [00:00, 108.67it/s, logp=1.068877e+04]
# 14it [00:00, 108.67it/s, logp=1.068877e+04]
# 15it [00:00, 108.67it/s, logp=1.068877e+04]
# 16it [00:00, 108.67it/s, logp=1.068877e+04]
# 17it [00:00, 108.67it/s, logp=1.068877e+04]
# 18it [00:00, 108.67it/s, logp=1.068877e+04]
# 19it [00:00, 108.67it/s, logp=1.068877e+04]
# 20it [00:00, 99.32it/s, logp=1.068877e+04]
# 20it [00:00, 99.32it/s, logp=1.068877e+04]
# 21it [00:00, 99.32it/s, logp=1.068877e+04]
# 22it [00:00, 99.32it/s, logp=1.068877e+04]
# 23it [00:00, 99.32it/s, logp=1.068877e+04]
# 24it [00:00, 99.32it/s, logp=1.068877e+04]
# 25it [00:00, 99.32it/s, logp=1.068877e+04]
# 26it [00:00, 99.32it/s, logp=1.068877e+04]
# 27it [00:00, 99.32it/s, logp=1.068877e+04]
# 28it [00:00, 89.47it/s, logp=1.068877e+04]
# 28it [00:00, 89.47it/s, logp=1.068877e+04]
# 29it [00:00, 89.47it/s, logp=1.068877e+04]
# 30it [00:00, 89.47it/s, logp=1.068877e+04]
# 31it [00:00, 89.47it/s, logp=1.068877e+04]
# 32it [00:00, 89.47it/s, logp=1.068877e+04]
# 33it [00:00, 89.47it/s, logp=1.068877e+04]
# 34it [00:00, 89.47it/s, logp=1.068877e+04]
# 35it [00:00, 89.47it/s, logp=1.068877e+04]
# 36it [00:00, 85.63it/s, logp=1.068877e+04]
# 36it [00:00, 85.63it/s, logp=1.068877e+04]
# 37it [00:00, 85.63it/s, logp=1.068877e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 38it [00:00, 85.63it/s, logp=1.068877e+04]
# 39it [00:00, 85.63it/s, logp=1.068877e+04]
# 40it [00:00, 85.63it/s, logp=1.068877e+04]
# 41it [00:00, 85.63it/s, logp=1.068877e+04]
# 42it [00:00, 85.63it/s, logp=1.068877e+04]
# 43it [00:00, 85.63it/s, logp=1.068877e+04]
# 44it [00:00, 85.63it/s, logp=1.068877e+04]
# 45it [00:00, 85.63it/s, logp=1.068877e+04]
# 46it [00:00, 86.04it/s, logp=1.068877e+04]
# 46it [00:00, 86.04it/s, logp=1.068877e+04]
# 47it [00:00, 86.04it/s, logp=1.068877e+04]
# 48it [00:00, 86.04it/s, logp=1.068877e+04]
# 49it [00:00, 86.04it/s, logp=1.068877e+04]
# 50it [00:11, 86.04it/s, logp=1.068877e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 50it [00:12,  3.94it/s, logp=1.068877e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 9543.10825173744 -> 10688.7653010549
# optimizing logp for variables: [u, Rs, ecc, b, r]
#
# 0it [00:00, ?it/s]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 0it [00:00, ?it/s, logp=1.068877e+04]
# 1it [00:00, 42.57it/s, logp=1.068877e+04]
# 2it [00:00, 57.30it/s, logp=1.068877e+04]
# 3it [00:00, 63.84it/s, logp=1.067375e+04]
# 4it [00:00, 67.71it/s, logp=1.069612e+04]
# 5it [00:00, 61.14it/s, logp=1.068008e+04]
# 6it [00:00, 65.26it/s, logp=1.069120e+04]
# 7it [00:00, 68.36it/s, logp=1.069622e+04]
# 8it [00:00, 77.55it/s, logp=1.069622e+04]
# 8it [00:00, 77.55it/s, logp=1.069640e+04]
# 9it [00:00, 77.55it/s, logp=1.069668e+04]
# 10it [00:00, 77.55it/s, logp=1.069697e+04]
# 11it [00:00, 77.55it/s, logp=1.069659e+04]
# 12it [00:00, 77.55it/s, logp=1.069705e+04]
# 13it [00:00, 77.55it/s, logp=1.069716e+04]
# 14it [00:00, 77.55it/s, logp=1.069724e+04]
# 15it [00:00, 77.55it/s, logp=1.069731e+04]
# 16it [00:00, 77.55it/s, logp=1.069731e+04]
# 17it [00:00, 77.55it/s, logp=1.069733e+04]
# 18it [00:00, 81.17it/s, logp=1.069733e+04]
# 18it [00:00, 81.17it/s, logp=1.069735e+04]
# 19it [00:00, 81.17it/s, logp=1.069735e+04]
# 20it [00:00, 81.17it/s, logp=1.069735e+04]
# 21it [00:00, 81.17it/s, logp=1.069735e+04]
# 22it [00:00, 81.17it/s, logp=1.069735e+04]
# 23it [00:00, 81.17it/s, logp=1.069735e+04]
# 24it [00:00, 81.17it/s, logp=1.069735e+04]
# 25it [00:00, 81.17it/s, logp=1.069735e+04]
# 26it [00:00, 81.17it/s, logp=1.069735e+04]
# 27it [00:00, 81.17it/s, logp=1.069735e+04]
# 28it [00:00, 84.46it/s, logp=1.069735e+04]
# 29it [00:10,  2.66it/s, logp=1.069735e+04]
# message: Optimization terminated successfully.
# logp: 10688.7653010549 -> 10697.3512300003
# optimizing logp for variables: [omega, ecc, logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs]
#
# 0it [00:00, ?it/s]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 0it [00:00, ?it/s, logp=1.069735e+04]
# 1it [00:00, 35.22it/s, logp=1.069735e+04]
# 2it [00:00, 47.87it/s, logp=1.069735e+04]
# 3it [00:00, 53.36it/s, logp=1.063592e+04]
# 4it [00:00, 57.68it/s, logp=1.065495e+04]
# 5it [00:00, 60.96it/s, logp=1.068526e+04]
# 6it [00:00, 63.59it/s, logp=1.069749e+04]
# 7it [00:00, 64.41it/s, logp=1.069791e+04]
# 8it [00:00, 73.08it/s, logp=1.069791e+04]
# 8it [00:00, 73.08it/s, logp=1.069741e+04]
# 9it [00:00, 73.08it/s, logp=1.069822e+04]
# 10it [00:00, 73.08it/s, logp=1.069957e+04]
# 11it [00:00, 73.08it/s, logp=1.070197e+04]
# 12it [00:00, 73.08it/s, logp=1.067966e+04]
# 13it [00:00, 73.08it/s, logp=1.070214e+04]
# 14it [00:00, 73.08it/s, logp=1.070249e+04]
# 15it [00:00, 73.08it/s, logp=1.070390e+04]
# 16it [00:00, 74.11it/s, logp=1.070390e+04]
# 16it [00:00, 74.11it/s, logp=1.070671e+04]
# 17it [00:00, 74.11it/s, logp=1.070679e+04]
# 18it [00:00, 74.11it/s, logp=1.070695e+04]
# 19it [00:00, 74.11it/s, logp=1.070769e+04]
# 20it [00:00, 74.11it/s, logp=1.071310e+04]
# 21it [00:00, 74.11it/s, logp=1.067361e+04]
# 22it [00:00, 74.11it/s, logp=1.071448e+04]
# 23it [00:00, 74.11it/s, logp=1.053850e+04]
# 24it [00:00, 75.36it/s, logp=1.053850e+04]
# 24it [00:00, 75.36it/s, logp=1.071473e+04]
# 25it [00:00, 75.36it/s, logp=1.071522e+04]
# 26it [00:00, 75.36it/s, logp=1.071693e+04]
# 27it [00:00, 75.36it/s, logp=1.072035e+04]
# 28it [00:00, 75.36it/s, logp=1.068049e+04]
# 29it [00:00, 75.36it/s, logp=1.072162e+04]
# 30it [00:00, 75.36it/s, logp=1.072466e+04]
# 31it [00:00, 75.36it/s, logp=1.076015e+04]
# 32it [00:00, 76.49it/s, logp=1.076015e+04]
# 32it [00:00, 76.49it/s, logp=1.072575e+04]
# 33it [00:00, 76.49it/s, logp=1.075983e+04]
# 34it [00:00, 76.49it/s, logp=1.076787e+04]
# 35it [00:00, 76.49it/s, logp=-1.121659e+07]
# 36it [00:00, 76.49it/s, logp=1.076787e+04]
# 37it [00:00, 76.49it/s, logp=1.076791e+04]
# 38it [00:00, 76.49it/s, logp=1.076800e+04]
# 39it [00:00, 76.49it/s, logp=1.076835e+04]
# 40it [00:00, 76.49it/s, logp=1.076948e+04]
# 41it [00:00, 78.19it/s, logp=1.076948e+04]
# 41it [00:00, 78.19it/s, logp=1.077217e+04]
# 42it [00:00, 78.19it/s, logp=1.077731e+04]
# 43it [00:00, 78.19it/s, logp=1.078714e+04]
# 44it [00:00, 78.19it/s, logp=1.080534e+04]
# 45it [00:00, 78.19it/s, logp=1.082775e+04]
# 46it [00:00, 78.19it/s, logp=1.084885e+04]
# 47it [00:00, 78.19it/s, logp=1.086705e+04]
# 48it [00:00, 78.19it/s, logp=1.084793e+04]
# 49it [00:00, 78.19it/s, logp=1.087284e+04]
# 50it [00:00, 79.61it/s, logp=1.087284e+04]
# 50it [00:00, 79.61it/s, logp=1.087979e+04]
# 51it [00:00, 79.61it/s, logp=1.088534e+04]
# 52it [00:00, 79.61it/s, logp=1.088856e+04]
# 53it [00:00, 79.61it/s, logp=1.089330e+04]
# 54it [00:00, 79.61it/s, logp=1.089666e+04]
# 55it [00:00, 79.61it/s, logp=1.089838e+04]
# 56it [00:00, 79.61it/s, logp=1.089897e+04]
# 57it [00:00, 79.61it/s, logp=1.089941e+04]
# 58it [00:00, 79.61it/s, logp=1.089976e+04]
# 59it [00:00, 80.47it/s, logp=1.089976e+04]
# 59it [00:00, 80.47it/s, logp=1.090033e+04]
# 60it [00:00, 80.47it/s, logp=1.090074e+04]
# 61it [00:00, 80.47it/s, logp=1.090084e+04]
# 62it [00:00, 80.47it/s, logp=1.090091e+04]
# 63it [00:00, 80.47it/s, logp=1.090093e+04]
# 64it [00:00, 80.47it/s, logp=1.090095e+04]
# 65it [00:00, 80.47it/s, logp=1.090098e+04]
# 66it [00:00, 80.47it/s, logp=1.090102e+04]
# 67it [00:00, 79.95it/s, logp=1.090102e+04]
# 67it [00:00, 79.95it/s, logp=1.090103e+04]
# 68it [00:00, 79.95it/s, logp=1.090104e+04]
# 69it [00:00, 79.95it/s, logp=1.090105e+04]
# 70it [00:00, 79.95it/s, logp=1.090106e+04]
# 71it [00:00, 79.95it/s, logp=1.090107e+04]
# 72it [00:00, 79.95it/s, logp=1.090109e+04]
# 73it [00:00, 79.95it/s, logp=1.090112e+04]
# 74it [00:00, 79.95it/s, logp=1.090116e+04]
# 75it [00:00, 79.48it/s, logp=1.090116e+04]
# 75it [00:00, 79.48it/s, logp=1.090121e+04]
# 76it [00:00, 79.48it/s, logp=1.090125e+04]
# 77it [00:00, 79.48it/s, logp=1.090126e+04]
# 78it [00:00, 79.48it/s, logp=1.090127e+04]
# 79it [00:01, 79.48it/s, logp=1.090128e+04]
# 80it [00:01, 79.48it/s, logp=1.090128e+04]
# 81it [00:01, 79.48it/s, logp=1.090128e+04]
# 82it [00:01, 79.48it/s, logp=1.090128e+04]
# 83it [00:01, 79.48it/s, logp=1.090128e+04]
# 84it [00:01, 80.05it/s, logp=1.090128e+04]
# 84it [00:01, 80.05it/s, logp=1.090128e+04]
# 85it [00:01, 80.05it/s, logp=1.090128e+04]
# 86it [00:01, 80.05it/s, logp=1.090128e+04]
# 87it [00:01, 80.05it/s, logp=1.090128e+04]
# 88it [00:01, 80.05it/s, logp=1.090128e+04]
# 89it [00:01, 80.05it/s, logp=1.090128e+04]
# 90it [00:01, 80.05it/s, logp=1.090128e+04]
# 91it [00:01, 80.05it/s, logp=1.090129e+04]
# 92it [00:01, 80.05it/s, logp=1.090129e+04]
# 93it [00:01, 80.41it/s, logp=1.090129e+04]
# 93it [00:01, 80.41it/s, logp=1.090130e+04]
# 94it [00:01, 80.41it/s, logp=1.090131e+04]
# 95it [00:01, 80.41it/s, logp=1.090130e+04]
# 96it [00:01, 80.41it/s, logp=1.090131e+04]
# 97it [00:01, 80.41it/s, logp=1.090131e+04]
# 98it [00:01, 80.41it/s, logp=1.090132e+04]
# 99it [00:01, 80.41it/s, logp=1.090132e+04]
# 100it [00:01, 80.41it/s, logp=1.090132e+04]
# 101it [00:01, 80.41it/s, logp=1.090132e+04]
# 102it [00:01, 80.96it/s, logp=1.090132e+04]
# 102it [00:01, 80.96it/s, logp=1.090132e+04]
# 103it [00:01, 80.96it/s, logp=1.090132e+04]
# 104it [00:01, 80.96it/s, logp=1.090132e+04]
# 105it [00:01, 80.96it/s, logp=1.090132e+04]
# 106it [00:01, 80.96it/s, logp=1.090132e+04]
# 107it [00:01, 80.96it/s, logp=1.090132e+04]
# 108it [00:01, 80.96it/s, logp=1.090132e+04]
# 109it [00:01, 80.96it/s, logp=1.090132e+04]
# 110it [00:01, 80.96it/s, logp=1.090132e+04]
# 111it [00:01, 81.87it/s, logp=1.090132e+04]
# 111it [00:01, 81.87it/s, logp=1.090132e+04]
# 112it [00:01, 81.87it/s, logp=1.090132e+04]
# 113it [00:01, 81.87it/s, logp=1.090132e+04]
# 114it [00:01, 81.87it/s, logp=1.090132e+04]
# 115it [00:01, 81.87it/s, logp=1.090132e+04]
# 116it [00:01, 81.87it/s, logp=1.090132e+04]
# 117it [00:01, 81.87it/s, logp=1.090132e+04]
# 118it [00:01, 81.87it/s, logp=1.090132e+04]
# 119it [00:01, 81.87it/s, logp=1.090132e+04]
# 120it [00:01, 82.71it/s, logp=1.090132e+04]
# 120it [00:01, 82.71it/s, logp=1.090132e+04]
# 121it [00:01, 82.71it/s, logp=1.090132e+04]
# 122it [00:01, 82.71it/s, logp=1.090132e+04]
# 123it [00:01, 82.71it/s, logp=1.090132e+04]
# 124it [00:01, 82.71it/s, logp=1.090132e+04]
# 125it [00:01, 82.71it/s, logp=1.090132e+04]
# 126it [00:01, 82.71it/s, logp=1.090132e+04]
# 127it [00:01, 82.71it/s, logp=1.090132e+04]
# 128it [00:01, 82.71it/s, logp=1.090132e+04]
# 129it [00:01, 83.11it/s, logp=1.090132e+04]
# 129it [00:01, 83.11it/s, logp=1.090132e+04]
# 130it [00:01, 83.11it/s, logp=1.090132e+04]
# 131it [00:01, 83.11it/s, logp=1.090132e+04]
# 132it [00:01, 83.11it/s, logp=1.090132e+04]
# 133it [00:01, 83.11it/s, logp=1.090132e+04]
# 134it [00:01, 83.11it/s, logp=1.090132e+04]
# 135it [00:01, 83.11it/s, logp=1.090132e+04]
# 136it [00:01, 83.11it/s, logp=1.090132e+04]
# 137it [00:01, 83.11it/s, logp=1.090132e+04]
# 138it [00:01, 84.11it/s, logp=1.090132e+04]
# 138it [00:01, 84.11it/s, logp=1.090132e+04]
# 139it [00:01, 84.11it/s, logp=1.090132e+04]
# 140it [00:01, 84.11it/s, logp=1.090132e+04]
# 141it [00:01, 84.11it/s, logp=1.090132e+04]
# 142it [00:01, 84.11it/s, logp=1.090132e+04]
# 143it [00:01, 84.11it/s, logp=1.090132e+04]
# 144it [00:01, 84.11it/s, logp=1.090132e+04]
# 145it [00:01, 84.11it/s, logp=1.090132e+04]
# 146it [00:01, 84.11it/s, logp=1.090132e+04]
# 147it [00:01, 83.19it/s, logp=1.090132e+04]
# 147it [00:01, 83.19it/s, logp=1.090132e+04]
# 148it [00:01, 83.19it/s, logp=1.090132e+04]
# 149it [00:01, 83.19it/s, logp=1.090132e+04]
# 150it [00:01, 83.19it/s, logp=1.090132e+04]
# 151it [00:01, 83.19it/s, logp=1.090132e+04]
# 152it [00:01, 83.19it/s, logp=1.090132e+04]
# 153it [00:01, 83.19it/s, logp=1.090132e+04]
# 154it [00:01, 83.19it/s, logp=1.090132e+04]
# 155it [00:01, 83.19it/s, logp=1.090132e+04]
# 156it [00:01, 81.64it/s, logp=1.090132e+04]
# 156it [00:01, 81.64it/s, logp=1.090132e+04]
# 157it [00:01, 81.64it/s, logp=1.090132e+04]
# 158it [00:01, 81.64it/s, logp=1.090132e+04]
# 159it [00:01, 81.64it/s, logp=1.090132e+04]
# 160it [00:01, 81.64it/s, logp=1.090132e+04]
# 161it [00:02, 81.64it/s, logp=1.090132e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 162it [00:02, 81.64it/s, logp=1.090132e+04]
# 163it [00:02, 81.64it/s, logp=1.090132e+04]
# 164it [00:02, 81.64it/s, logp=1.090132e+04]
# 165it [00:02, 80.83it/s, logp=1.090132e+04]
# 165it [00:02, 80.83it/s, logp=1.090132e+04]
# 166it [00:02, 80.83it/s, logp=1.090132e+04]
# 167it [00:02, 80.83it/s, logp=1.090132e+04]
# 168it [00:02, 80.83it/s, logp=1.090132e+04]
# 169it [00:02, 80.83it/s, logp=1.090132e+04]
# 170it [00:02, 80.83it/s, logp=1.090132e+04]
# 171it [00:02, 80.83it/s, logp=1.090132e+04]
# 172it [00:02, 80.83it/s, logp=1.090132e+04]
# 173it [00:02, 80.83it/s, logp=1.090132e+04]
# 174it [00:02, 81.65it/s, logp=1.090132e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 174it [00:13, 13.36it/s, logp=1.090132e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10697.3512300003 -> 10901.315750436033

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_gp_ecc["periods"], map_soln_gp_ecc["logprob_class"], "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-8/3 prior, eccentric orbit")
plt.plot(map_soln_gp_ecc["periods"],map_soln_gp_ecc["logprior_class"],'-o',label='log_priors')
#[map_soln_gp_ecc['per_'+str(n)+'_log_prior'] for n in range(17)]
plt.legend()

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_gp_ecc["per_16_light_curve"][:1000]+map_soln_gp_ecc["per_16_gp_pred"][:1000],label='shortest-P')
plt.plot(x[:1000],map_soln_gp_ecc["per_1_light_curve"][:1000]+map_soln_gp_ecc["per_1_gp_pred"][:1000],label='longest-P')
plt.plot(x[:1000],map_soln_gp_ecc["marginalized_light_curve"][:1000]+map_soln_gp_ecc["marginalized_gp_pred"][:1000],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_gp_ecc["per_16_light_curve"][1000:]+map_soln_gp_ecc["per_16_gp_pred"][1000:],label='shortest-P')
plt.plot(x[1000:],map_soln_gp_ecc["per_1_light_curve"][1000:]+map_soln_gp_ecc["per_1_gp_pred"][1000:],label='longest-P')
plt.plot(x[1000:],map_soln_gp_ecc["marginalized_light_curve"][1000:]+map_soln_gp_ecc["marginalized_gp_pred"][1000:],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

# %% [markdown]
# Now we're going the other way! The longest period solution is most favoured! And I can't really see why...

# %% [markdown]
# # Marginalising over ecc & omega (with GPs)

# %%
with pm.Model() as model_gp_marg_ecc:

    #Baseline flux is now in the GPs, so deleting this:
    #mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    #Initialising eccentricity and omega:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)

    logprobs = []
    logpriors= []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=model_gp_marg_ecc) as submodel:
            
            period = pm.Deterministic("period", periods[i])
            ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
            omega = xo.distributions.Angle("omega")

            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1)
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred = pm.Deterministic("gp_pred", gp.predict())
            gp_preds.append(gp.predict())
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-8/3 (occurrence rate (P^-1) * window function (P^-1) * transit probability (P^-2/3) )
            logprior = -8 * tt.log(period) / 3
            logprobs.append(loglike + logprior)
            logpriors.append(logprior)

    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    logprior_class = pm.Deterministic("logprior_class", tt.stack(logpriors))
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve and gp prediction
    pm.Deterministic("marginalized_light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    pm.Deterministic("marginalized_gp_pred", tt.sum(tt.stack(gp_preds) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(model_gp_marg_ecc.test_point)
    print(model_gp_marg_ecc.check_test_point())
    map_soln_gp_marg_ecc = xo.optimize(vars=[r, b])
    map_soln_gp_marg_ecc = xo.optimize(start=map_soln_gp_marg_ecc, vars=[logs2])
    map_soln_gp_marg_ecc = xo.optimize(start=map_soln_gp_marg_ecc, vars=[t0_1, t0_2])
    map_soln_gp_marg_ecc = xo.optimize(start=map_soln_gp_marg_ecc, vars=[logs2, logpower])
    map_soln_gp_marg_ecc = xo.optimize(start=map_soln_gp_marg_ecc, vars=[logw0])
    map_soln_gp_marg_ecc = xo.optimize(start=map_soln_gp_marg_ecc, vars=[r,b,ecc,Rs,u])

    map_soln_gp_marg_ecc = xo.optimize(map_soln_gp_marg_ecc)
# Out:
# {'Rs': array(1.), 'logrho_S': array(0.), 't0_1': array(105.57), 't0_2': array(205.57), 'u_quadlimbdark__': array([-1.09861229, -0.84729786]), 'r_interval__': array(0.), 'b_impact__': array(-0.59116847), 'logs2': array(-6.65444898), 'logw0_interval__': array(-0.60183699), 'logpower_interval__': array(1.18693347), 'per_0_ecc_interval__': array(-1.11022302e-16), 'per_0_omega_angle__': array([0., 1.]), 'per_1_ecc_interval__': array(-1.11022302e-16), 'per_1_omega_angle__': array([0., 1.]), 'per_2_ecc_interval__': array(-1.11022302e-16), 'per_2_omega_angle__': array([0., 1.]), 'per_3_ecc_interval__': array(-1.11022302e-16), 'per_3_omega_angle__': array([0., 1.]), 'per_4_ecc_interval__': array(-1.11022302e-16), 'per_4_omega_angle__': array([0., 1.]), 'per_5_ecc_interval__': array(-1.11022302e-16), 'per_5_omega_angle__': array([0., 1.]), 'per_6_ecc_interval__': array(-1.11022302e-16), 'per_6_omega_angle__': array([0., 1.]), 'per_7_ecc_interval__': array(-1.11022302e-16), 'per_7_omega_angle__': array([0., 1.]), 'per_8_ecc_interval__': array(-1.11022302e-16), 'per_8_omega_angle__': array([0., 1.]), 'per_9_ecc_interval__': array(-1.11022302e-16), 'per_9_omega_angle__': array([0., 1.]), 'per_10_ecc_interval__': array(-1.11022302e-16), 'per_10_omega_angle__': array([0., 1.]), 'per_11_ecc_interval__': array(-1.11022302e-16), 'per_11_omega_angle__': array([0., 1.]), 'per_12_ecc_interval__': array(-1.11022302e-16), 'per_12_omega_angle__': array([0., 1.]), 'per_13_ecc_interval__': array(-1.11022302e-16), 'per_13_omega_angle__': array([0., 1.]), 'per_14_ecc_interval__': array(-1.11022302e-16), 'per_14_omega_angle__': array([0., 1.]), 'per_15_ecc_interval__': array(-1.11022302e-16), 'per_15_omega_angle__': array([0., 1.]), 'per_16_ecc_interval__': array(-1.11022302e-16), 'per_16_omega_angle__': array([0., 1.])}
# Rs                       0.29
# logrho_S                -0.23
# t0_1                    -0.00
# t0_2                    -0.00
# u_quadlimbdark__        -3.23
# r_interval__            -1.39
# b_impact__              -1.47
# logs2                   -0.92
# logw0_interval__        -1.48
# logpower_interval__     -1.72
# per_0_ecc_interval__    -1.85
# per_0_omega_angle__     -0.50
# per_1_ecc_interval__    -1.85
# per_1_omega_angle__     -0.50
# per_2_ecc_interval__    -1.85
# per_2_omega_angle__     -0.50
# per_3_ecc_interval__    -1.85
# per_3_omega_angle__     -0.50
# per_4_ecc_interval__    -1.85
# per_4_omega_angle__     -0.50
# per_5_ecc_interval__    -1.85
# per_5_omega_angle__     -0.50
# per_6_ecc_interval__    -1.85
# per_6_omega_angle__     -0.50
# per_7_ecc_interval__    -1.85
# per_7_omega_angle__     -0.50
# per_8_ecc_interval__    -1.85
# per_8_omega_angle__     -0.50
# per_9_ecc_interval__    -1.85
# per_9_omega_angle__     -0.50
# per_10_ecc_interval__   -1.85
# per_10_omega_angle__    -0.50
# per_11_ecc_interval__   -1.85
# per_11_omega_angle__    -0.50
# per_12_ecc_interval__   -1.85
# per_12_omega_angle__    -0.50
# per_13_ecc_interval__   -1.85
# per_13_omega_angle__    -0.50
# per_14_ecc_interval__   -1.85
# per_14_omega_angle__    -0.50
# per_15_ecc_interval__   -1.85
# per_15_omega_angle__    -0.50
# per_16_ecc_interval__   -1.85
# per_16_omega_angle__    -0.50
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [b, r, Rs]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-1.676256e+04]
# 1it [00:00, 49.37it/s, logp=-1.676256e+04]
# 2it [00:00, 66.58it/s, logp=-1.676256e+04]
# 3it [00:00, 72.25it/s, logp=-1.675329e+04]
# 4it [00:00, 76.08it/s, logp=-1.675346e+04]
# 5it [00:00, 79.05it/s, logp=-1.675292e+04]
# 6it [00:00, 81.43it/s, logp=-1.675232e+04]
# 7it [00:00, 82.67it/s, logp=-1.675167e+04]
# 8it [00:00, 83.63it/s, logp=-1.675158e+04]
# 9it [00:00, 85.25it/s, logp=-1.675157e+04]
# 10it [00:00, 94.05it/s, logp=-1.675157e+04]
# 10it [00:00, 94.05it/s, logp=-1.675157e+04]
# 11it [00:00, 94.05it/s, logp=-1.675157e+04]
# 12it [00:00, 94.05it/s, logp=-1.675157e+04]
# 13it [00:00, 94.05it/s, logp=-1.675157e+04]
# 14it [00:00, 94.05it/s, logp=-1.675157e+04]
# 15it [00:00, 94.05it/s, logp=-1.675157e+04]
# 16it [00:13,  1.18it/s, logp=-1.675157e+04]
# message: Optimization terminated successfully.
# logp: -16762.562357678107 -> -16751.565510402288
# optimizing logp for variables: [logs2]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-1.675157e+04]
# 1it [00:00, 60.70it/s, logp=-1.675157e+04]
# 2it [00:00, 79.61it/s, logp=-1.675157e+04]
# 3it [00:00, 88.46it/s, logp=-1.620401e+04]
# 4it [00:00, 94.33it/s, logp=-4.273381e+03]
# 5it [00:00, 99.24it/s, logp=-1.667235e+04]
# 6it [00:00, 102.58it/s, logp=-4.181287e+03]
# 7it [00:00, 104.87it/s, logp=-2.863401e+03]
# 8it [00:00, 106.65it/s, logp=-4.429245e+03]
# 9it [00:00, 108.32it/s, logp=-2.861418e+03]
# 10it [00:00, 109.79it/s, logp=-2.861362e+03]
# 11it [00:00, 111.06it/s, logp=-2.861362e+03]
# 12it [00:00, 111.70it/s, logp=-2.861362e+03]
# 13it [00:12,  1.08it/s, logp=-2.861362e+03]
# message: Optimization terminated successfully.
# logp: -16751.565510402288 -> -2861.362163657524
# optimizing logp for variables: [t0_2, t0_1]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-2.861362e+03]
# 1it [00:00, 42.62it/s, logp=-2.861362e+03]
# 2it [00:00, 57.12it/s, logp=-2.861362e+03]
# 3it [00:00, 63.87it/s, logp=-2.861379e+03]
# 4it [00:00, 66.63it/s, logp=-2.861362e+03]
# 5it [00:00, 69.31it/s, logp=-2.861362e+03]
# 6it [00:00, 70.79it/s, logp=-2.861363e+03]
# 7it [00:00, 72.21it/s, logp=-2.861362e+03]
# 8it [00:00, 73.40it/s, logp=-2.861362e+03]
# 9it [00:00, 81.94it/s, logp=-2.861362e+03]
# 9it [00:00, 81.94it/s, logp=-2.861362e+03]
# 10it [00:00, 81.94it/s, logp=-2.861362e+03]
# 11it [00:00, 81.94it/s, logp=-2.861362e+03]
# 12it [00:00, 81.94it/s, logp=-2.861362e+03]
# 13it [00:00, 81.94it/s, logp=-2.861362e+03]
# 14it [00:00, 81.94it/s, logp=-2.861362e+03]
# 15it [00:00, 81.94it/s, logp=-2.861362e+03]
# 16it [00:00, 81.94it/s, logp=-2.861362e+03]
# 17it [00:00, 81.94it/s, logp=-2.861362e+03]
# 18it [00:14,  1.23it/s, logp=-2.861362e+03]
# message: Optimization terminated successfully.
# logp: -2861.362163657524 -> -2861.362097618456
# optimizing logp for variables: [logpower, logs2]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-2.861362e+03]
# 1it [00:00, 50.84it/s, logp=-2.861362e+03]
# 2it [00:00, 63.11it/s, logp=-2.861362e+03]
# 3it [00:00, 69.69it/s, logp=-2.645013e+03]
# 4it [00:00, 74.35it/s, logp=-2.323875e+03]
# 5it [00:00, 76.49it/s, logp=-1.239790e+03]
# 6it [00:00, 78.02it/s, logp=3.859997e+03]
# 7it [00:00, 78.88it/s, logp=-7.246116e+06]
# 8it [00:00, 81.26it/s, logp=3.870598e+03]
# 9it [00:00, 81.76it/s, logp=-9.899808e+05]
# 10it [00:00, 88.55it/s, logp=-9.899808e+05]
# 10it [00:00, 88.55it/s, logp=7.944662e+03]
# 11it [00:00, 88.55it/s, logp=-3.646293e+04]
# 12it [00:00, 88.55it/s, logp=9.305693e+03]
# 13it [00:00, 88.55it/s, logp=-6.909713e+06]
# 14it [00:00, 88.55it/s, logp=9.306551e+03]
# 15it [00:00, 88.55it/s, logp=9.429334e+03]
# 16it [00:00, 88.55it/s, logp=9.429532e+03]
# 17it [00:00, 88.55it/s, logp=9.429582e+03]
# 18it [00:00, 88.55it/s, logp=9.429675e+03]
# 19it [00:00, 87.02it/s, logp=9.429675e+03]
# 19it [00:00, 87.02it/s, logp=9.429851e+03]
# 20it [00:00, 87.02it/s, logp=9.430186e+03]
# 21it [00:00, 87.02it/s, logp=9.430815e+03]
# 22it [00:00, 87.02it/s, logp=9.431976e+03]
# 23it [00:00, 87.02it/s, logp=9.434062e+03]
# 24it [00:00, 87.02it/s, logp=9.437658e+03]
# 25it [00:00, 87.02it/s, logp=9.443612e+03]
# 26it [00:00, 87.02it/s, logp=9.453460e+03]
# 27it [00:00, 87.02it/s, logp=9.457838e+03]
# 28it [00:00, 85.39it/s, logp=9.457838e+03]
# 28it [00:00, 85.39it/s, logp=9.454340e+03]
# 29it [00:00, 85.39it/s, logp=9.465676e+03]
# 30it [00:00, 85.39it/s, logp=-3.419397e+08]
# 31it [00:00, 85.39it/s, logp=9.465676e+03]
# 32it [00:00, 85.39it/s, logp=9.465676e+03]
# 33it [00:00, 85.39it/s, logp=-5.097182e+07]
# 34it [00:00, 85.39it/s, logp=9.469502e+03]
# 35it [00:00, 85.39it/s, logp=9.159067e+03]
# 36it [00:00, 85.39it/s, logp=9.471023e+03]
# 37it [00:00, 85.05it/s, logp=9.471023e+03]
# 37it [00:00, 85.05it/s, logp=9.474021e+03]
# 38it [00:00, 85.05it/s, logp=9.484563e+03]
# 39it [00:00, 85.05it/s, logp=9.502766e+03]
# 40it [00:00, 85.05it/s, logp=9.505427e+03]
# 41it [00:00, 85.05it/s, logp=9.505434e+03]
# 42it [00:00, 85.05it/s, logp=9.505494e+03]
# 43it [00:00, 85.05it/s, logp=9.505497e+03]
# 44it [00:00, 85.05it/s, logp=9.505497e+03]
# 45it [00:00, 83.39it/s, logp=9.505497e+03]
# 45it [00:00, 83.39it/s, logp=9.505497e+03]
# 46it [00:17,  2.66it/s, logp=9.505497e+03]
# message: Optimization terminated successfully.
# logp: -2861.362097618456 -> 9505.497404545007
# optimizing logp for variables: [logw0]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=9.505497e+03]
# 1it [00:00, 44.44it/s, logp=9.505497e+03]
# 2it [00:00, 59.16it/s, logp=9.505497e+03]
# 3it [00:00, 66.82it/s, logp=1.065098e+04]
# 4it [00:00, 71.47it/s, logp=1.065098e+04]
# 5it [00:00, 73.12it/s, logp=1.065098e+04]
# 6it [00:00, 73.77it/s, logp=1.065100e+04]
# 7it [00:00, 74.67it/s, logp=1.065106e+04]
# 8it [00:00, 75.75it/s, logp=1.065115e+04]
# 9it [00:00, 84.23it/s, logp=1.065115e+04]
# 9it [00:00, 84.23it/s, logp=1.065115e+04]
# 10it [00:00, 84.23it/s, logp=1.065115e+04]
# 11it [00:00, 84.23it/s, logp=1.065115e+04]
# 12it [00:00, 84.23it/s, logp=1.065115e+04]
# 13it [00:18,  1.41s/it, logp=1.065115e+04]
# message: Optimization terminated successfully.
# logp: 9505.497404545007 -> 10651.154453787425
# optimizing logp for variables: [u, Rs, per_16_ecc, b, r]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=1.065115e+04]
# 1it [00:00, 45.69it/s, logp=1.065115e+04]
# 2it [00:00, 56.99it/s, logp=1.065115e+04]
# 3it [00:00, 63.97it/s, logp=1.063268e+04]
# 4it [00:00, 68.44it/s, logp=1.065810e+04]
# 5it [00:00, 70.66it/s, logp=1.065598e+04]
# 6it [00:00, 69.60it/s, logp=1.065546e+04]
# 7it [00:00, 72.12it/s, logp=1.065849e+04]
# 8it [00:00, 73.47it/s, logp=1.065912e+04]
# 9it [00:00, 81.50it/s, logp=1.065912e+04]
# 9it [00:00, 81.50it/s, logp=1.065915e+04]
# 10it [00:00, 81.50it/s, logp=1.065945e+04]
# 11it [00:00, 81.50it/s, logp=1.065978e+04]
# 12it [00:00, 81.50it/s, logp=1.065979e+04]
# 13it [00:00, 81.50it/s, logp=1.065979e+04]
# 14it [00:00, 81.50it/s, logp=1.065979e+04]
# 15it [00:00, 81.50it/s, logp=1.065979e+04]
# 16it [00:00, 81.50it/s, logp=1.065979e+04]
# 17it [00:00, 80.35it/s, logp=1.065979e+04]
# 17it [00:00, 80.35it/s, logp=1.065979e+04]
# 18it [00:00, 80.35it/s, logp=1.065979e+04]
# 19it [00:00, 80.35it/s, logp=1.065979e+04]
# 20it [00:14,  1.38it/s, logp=1.065979e+04]
# message: Optimization terminated successfully.
# logp: 10651.154453787425 -> 10659.792179888589
# optimizing logp for variables: [per_16_omega, per_16_ecc, per_15_omega, per_15_ecc, per_14_omega, per_14_ecc, per_13_omega, per_13_ecc, per_12_omega, per_12_ecc, per_11_omega, per_11_ecc, per_10_omega, per_10_ecc, per_9_omega, per_9_ecc, per_8_omega, per_8_ecc, per_7_omega, per_7_ecc, per_6_omega, per_6_ecc, per_5_omega, per_5_ecc, per_4_omega, per_4_ecc, per_3_omega, per_3_ecc, per_2_omega, per_2_ecc, per_1_omega, per_1_ecc, per_0_omega, per_0_ecc, logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=1.065979e+04]
# 1it [00:00, 30.87it/s, logp=1.065979e+04]
# 2it [00:00, 41.79it/s, logp=1.065979e+04]
# 3it [00:00, 46.98it/s, logp=1.064807e+04]
# 4it [00:00, 50.05it/s, logp=1.063549e+04]
# 5it [00:00, 52.69it/s, logp=1.064830e+04]
# 6it [00:00, 52.72it/s, logp=1.065983e+04]
# 7it [00:00, 61.07it/s, logp=1.065983e+04]
# 7it [00:00, 61.07it/s, logp=1.065999e+04]
# 8it [00:00, 61.07it/s, logp=1.066041e+04]
# 9it [00:00, 61.07it/s, logp=1.066109e+04]
# 10it [00:00, 61.07it/s, logp=1.066330e+04]
# 11it [00:00, 61.07it/s, logp=1.067198e+04]
# 12it [00:00, 61.07it/s, logp=1.070412e+04]
# 13it [00:00, 61.07it/s, logp=1.066769e+04]
# 14it [00:00, 61.12it/s, logp=1.066769e+04]
# 14it [00:00, 61.12it/s, logp=1.071764e+04]
# 15it [00:00, 61.12it/s, logp=1.073528e+04]
# 16it [00:00, 61.12it/s, logp=1.076388e+04]
# 17it [00:00, 61.12it/s, logp=1.078696e+04]
# 18it [00:00, 61.12it/s, logp=1.082980e+04]
# 19it [00:00, 61.12it/s, logp=1.090196e+04]
# 20it [00:00, 60.49it/s, logp=1.090196e+04]
# 20it [00:00, 60.49it/s, logp=-1.154189e+09]
# 21it [00:00, 60.49it/s, logp=1.090196e+04]
# 22it [00:00, 60.49it/s, logp=1.090196e+04]
# 23it [00:00, 60.49it/s, logp=-2.484340e+05]
# 24it [00:00, 60.49it/s, logp=1.091827e+04]
# 25it [00:00, 60.49it/s, logp=1.093798e+04]
# 26it [00:00, 60.49it/s, logp=1.097092e+04]
# 27it [00:00, 60.69it/s, logp=1.097092e+04]
# 27it [00:00, 60.69it/s, logp=1.103927e+04]
# 28it [00:00, 60.69it/s, logp=1.099479e+04]
# 29it [00:00, 60.69it/s, logp=1.103916e+04]
# 30it [00:00, 60.69it/s, logp=1.104150e+04]
# 31it [00:00, 60.69it/s, logp=1.104540e+04]
# 32it [00:00, 60.69it/s, logp=1.105232e+04]
# 33it [00:00, 60.46it/s, logp=1.105232e+04]
# 33it [00:00, 60.46it/s, logp=1.107455e+04]
# 34it [00:00, 60.46it/s, logp=-6.419354e+04]
# 35it [00:00, 60.46it/s, logp=1.107456e+04]
# 36it [00:00, 60.46it/s, logp=1.107511e+04]
# 37it [00:00, 60.46it/s, logp=1.104798e+04]
# 38it [00:00, 60.46it/s, logp=1.107636e+04]
# 39it [00:00, 60.04it/s, logp=1.107636e+04]
# 39it [00:00, 60.04it/s, logp=1.107993e+04]
# 40it [00:00, 60.04it/s, logp=1.107105e+04]
# 41it [00:00, 60.04it/s, logp=1.108383e+04]
# 42it [00:00, 60.04it/s, logp=1.105361e+04]
# 43it [00:00, 60.04it/s, logp=1.108528e+04]
# 44it [00:00, 60.04it/s, logp=1.108829e+04]
# 45it [00:00, 60.04it/s, logp=1.109103e+04]
# 46it [00:00, 60.40it/s, logp=1.109103e+04]
# 46it [00:00, 60.40it/s, logp=1.110324e+04]
# 47it [00:00, 60.40it/s, logp=1.103292e+04]
# 48it [00:00, 60.40it/s, logp=1.110324e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 49it [00:00, 60.40it/s, logp=1.110324e+04]
# 50it [00:00, 60.40it/s, logp=1.111364e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 51it [00:00, 60.40it/s, logp=1.094363e+04]
# 52it [00:00, 59.56it/s, logp=1.094363e+04]
# 52it [00:00, 59.56it/s, logp=1.111364e+04]
# 53it [00:00, 59.56it/s, logp=1.111364e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 54it [00:00, 59.56it/s, logp=1.094363e+04]
# 55it [00:00, 59.56it/s, logp=1.111743e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 56it [00:00, 59.56it/s, logp=1.112453e+04]
# 57it [00:00, 59.56it/s, logp=1.113714e+04]
# 58it [00:00, 59.46it/s, logp=1.113714e+04]
# 58it [00:00, 59.46it/s, logp=1.114683e+04]
# 59it [00:01, 59.46it/s, logp=1.114854e+04]
# 60it [00:01, 59.46it/s, logp=1.116420e+04]
# 61it [00:01, 59.46it/s, logp=1.116453e+04]
# 62it [00:01, 59.46it/s, logp=1.116519e+04]
# 63it [00:01, 59.46it/s, logp=1.116727e+04]
# 64it [00:01, 59.46it/s, logp=1.117097e+04]
# 65it [00:01, 59.95it/s, logp=1.117097e+04]
# 65it [00:01, 59.95it/s, logp=1.117598e+04]
# 66it [00:01, 59.95it/s, logp=1.118154e+04]
# 67it [00:01, 59.95it/s, logp=1.118602e+04]
# 68it [00:01, 59.95it/s, logp=1.119002e+04]
# 69it [00:01, 59.95it/s, logp=1.119554e+04]
# 70it [00:01, 59.95it/s, logp=1.118606e+04]
# 71it [00:01, 59.96it/s, logp=1.118606e+04]
# 71it [00:01, 59.96it/s, logp=1.119647e+04]
# 72it [00:01, 59.96it/s, logp=1.119773e+04]
# 73it [00:01, 59.96it/s, logp=1.119833e+04]
# 74it [00:01, 59.96it/s, logp=1.119924e+04]
# 75it [00:01, 59.96it/s, logp=1.120008e+04]
# 76it [00:01, 59.96it/s, logp=1.120039e+04]
# 77it [00:01, 59.58it/s, logp=1.120039e+04]
# 77it [00:01, 59.58it/s, logp=1.120065e+04]
# 78it [00:01, 59.58it/s, logp=1.120096e+04]
# 79it [00:01, 59.58it/s, logp=1.120118e+04]
# 80it [00:01, 59.58it/s, logp=1.120146e+04]
# 81it [00:01, 59.58it/s, logp=1.120174e+04]
# 82it [00:01, 59.58it/s, logp=1.120186e+04]
# 83it [00:01, 58.82it/s, logp=1.120186e+04]
# 83it [00:01, 58.82it/s, logp=1.120197e+04]
# 84it [00:01, 58.82it/s, logp=1.120202e+04]
# 85it [00:01, 58.82it/s, logp=1.120205e+04]
# 86it [00:01, 58.82it/s, logp=1.120208e+04]
# 87it [00:01, 58.82it/s, logp=1.120210e+04]
# 88it [00:01, 58.82it/s, logp=1.120213e+04]
# 89it [00:01, 58.82it/s, logp=1.120215e+04]
# 90it [00:01, 59.40it/s, logp=1.120215e+04]
# 90it [00:01, 59.40it/s, logp=1.120217e+04]
# 91it [00:01, 59.40it/s, logp=1.120220e+04]
# 92it [00:01, 59.40it/s, logp=1.120223e+04]
# 93it [00:01, 59.40it/s, logp=1.120226e+04]
# 94it [00:01, 59.40it/s, logp=1.120228e+04]
# 95it [00:01, 59.40it/s, logp=1.120230e+04]
# 96it [00:01, 59.40it/s, logp=1.120230e+04]
# 97it [00:01, 59.12it/s, logp=1.120230e+04]
# 97it [00:01, 59.12it/s, logp=1.120230e+04]
# 98it [00:01, 59.12it/s, logp=1.120231e+04]
# 99it [00:01, 59.12it/s, logp=1.120231e+04]
# 100it [00:01, 59.12it/s, logp=1.120231e+04]
# 101it [00:01, 59.12it/s, logp=1.120231e+04]
# 102it [00:01, 59.12it/s, logp=1.120231e+04]
# 103it [00:01, 59.23it/s, logp=1.120231e+04]
# 103it [00:01, 59.23it/s, logp=1.120231e+04]
# 104it [00:01, 59.23it/s, logp=1.120231e+04]
# 105it [00:01, 59.23it/s, logp=1.120231e+04]
# 106it [00:01, 59.23it/s, logp=1.120231e+04]
# 107it [00:01, 59.23it/s, logp=1.120231e+04]
# 108it [00:01, 59.23it/s, logp=1.120232e+04]
# 109it [00:01, 59.37it/s, logp=1.120232e+04]
# 109it [00:01, 59.37it/s, logp=1.120232e+04]
# 110it [00:01, 59.37it/s, logp=1.120232e+04]
# 111it [00:01, 59.37it/s, logp=1.120233e+04]
# 112it [00:01, 59.37it/s, logp=1.120233e+04]
# 113it [00:01, 59.37it/s, logp=1.120233e+04]
# 114it [00:01, 59.37it/s, logp=1.120234e+04]
# 115it [00:01, 59.37it/s, logp=1.120234e+04]
# 116it [00:01, 59.77it/s, logp=1.120234e+04]
# 116it [00:01, 59.77it/s, logp=1.120234e+04]
# 117it [00:01, 59.77it/s, logp=1.120234e+04]
# 118it [00:01, 59.77it/s, logp=1.120234e+04]
# 119it [00:02, 59.77it/s, logp=1.120234e+04]
# 120it [00:02, 59.77it/s, logp=1.120234e+04]
# 121it [00:02, 59.77it/s, logp=1.120234e+04]
# 122it [00:02, 59.77it/s, logp=1.120234e+04]
# 123it [00:02, 60.35it/s, logp=1.120234e+04]
# 123it [00:02, 60.35it/s, logp=1.120234e+04]
# 124it [00:02, 60.35it/s, logp=1.120234e+04]
# 125it [00:02, 60.35it/s, logp=1.120234e+04]
# 126it [00:02, 60.35it/s, logp=1.120234e+04]
# 127it [00:02, 60.35it/s, logp=1.120234e+04]
# 128it [00:02, 60.35it/s, logp=1.120234e+04]
# 129it [00:02, 60.35it/s, logp=1.120234e+04]
# 130it [00:02, 60.36it/s, logp=1.120234e+04]
# 130it [00:02, 60.36it/s, logp=1.120234e+04]
# 131it [00:02, 60.36it/s, logp=1.120234e+04]
# 132it [00:02, 60.36it/s, logp=1.120234e+04]
# 133it [00:02, 60.36it/s, logp=1.120234e+04]
# 134it [00:02, 60.36it/s, logp=1.120234e+04]
# 135it [00:02, 60.36it/s, logp=1.120234e+04]
# 136it [00:02, 60.36it/s, logp=1.120234e+04]
# 137it [00:02, 60.45it/s, logp=1.120234e+04]
# 137it [00:02, 60.45it/s, logp=1.120234e+04]
# 138it [00:02, 60.45it/s, logp=1.120234e+04]
# 139it [00:02, 60.45it/s, logp=1.120234e+04]
# 140it [00:02, 60.45it/s, logp=1.120234e+04]
# 141it [00:02, 60.45it/s, logp=1.120234e+04]
# 142it [00:02, 60.45it/s, logp=1.120234e+04]
# 143it [00:02, 60.45it/s, logp=1.120234e+04]
# 144it [00:02, 60.81it/s, logp=1.120234e+04]
# 144it [00:02, 60.81it/s, logp=1.120234e+04]
# 145it [00:02, 60.81it/s, logp=1.120234e+04]
# 146it [00:02, 60.81it/s, logp=1.120234e+04]
# 147it [00:02, 60.81it/s, logp=1.120234e+04]
# 148it [00:02, 60.81it/s, logp=1.120234e+04]
# 149it [00:02, 60.81it/s, logp=1.120234e+04]
# 150it [00:02, 60.81it/s, logp=1.120234e+04]
# 151it [00:02, 60.63it/s, logp=1.120234e+04]
# 151it [00:02, 60.63it/s, logp=1.120234e+04]
# 152it [00:02, 60.63it/s, logp=1.120234e+04]
# 153it [00:02, 60.63it/s, logp=1.120234e+04]
# 154it [00:02, 60.63it/s, logp=1.120234e+04]
# 155it [00:02, 60.63it/s, logp=1.120234e+04]
# 156it [00:02, 60.63it/s, logp=1.120234e+04]
# 157it [00:02, 60.63it/s, logp=1.120234e+04]
# 158it [00:02, 59.49it/s, logp=1.120234e+04]
# 158it [00:02, 59.49it/s, logp=1.120234e+04]
# 159it [00:02, 59.49it/s, logp=1.120234e+04]
# 160it [00:02, 59.49it/s, logp=1.120234e+04]
# 161it [00:02, 59.49it/s, logp=1.120234e+04]
# 162it [00:02, 59.49it/s, logp=1.120234e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 163it [00:02, 59.49it/s, logp=1.120234e+04]
# 164it [00:02, 57.73it/s, logp=1.120234e+04]
# 164it [00:02, 57.73it/s, logp=1.120234e+04]
# 165it [00:02, 57.73it/s, logp=1.120234e+04]
# 166it [00:02, 57.73it/s, logp=1.120234e+04]
# 167it [00:02, 57.73it/s, logp=1.120234e+04]
# 168it [00:02, 57.73it/s, logp=1.120234e+04]
# 169it [00:02, 57.73it/s, logp=1.120234e+04]
# 170it [00:02, 56.19it/s, logp=1.120234e+04]
# 170it [00:02, 56.19it/s, logp=1.120234e+04]
# 171it [00:02, 56.19it/s, logp=1.120234e+04]
# 172it [00:02, 56.19it/s, logp=1.120234e+04]
# 173it [00:02, 56.19it/s, logp=1.120234e+04]
# 174it [00:02, 56.19it/s, logp=1.120234e+04]
# 175it [00:13, 56.19it/s, logp=1.120234e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 175it [00:20,  8.42it/s, logp=1.120234e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10659.792179888582 -> 11202.339149750145

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_gp_marg_ecc["periods"], map_soln_gp_marg_ecc["logprob_class"], "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-8/3 prior, marginalised eccentric orbit")
plt.plot(map_soln_gp_marg_ecc["periods"],map_soln_gp_marg_ecc["logprior_class"],'-o',label='log_priors')
#[map_soln_gp_marg_ecc['per_'+str(n)+'_log_prior'] for n in range(17)]
plt.legend()

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_gp_marg_ecc["per_16_light_curve"][:1000]+map_soln_gp_marg_ecc["per_16_gp_pred"][:1000],label='shortest-P')
plt.plot(x[:1000],map_soln_gp_marg_ecc["per_1_light_curve"][:1000]+map_soln_gp_marg_ecc["per_1_gp_pred"][:1000],label='longest-P')
plt.plot(x[:1000],map_soln_gp_marg_ecc["marginalized_light_curve"][:1000]+map_soln_gp_marg_ecc["marginalized_gp_pred"][:1000],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_gp_marg_ecc["per_16_light_curve"][1000:]+map_soln_gp_marg_ecc["per_16_gp_pred"][1000:],label='shortest-P')
plt.plot(x[1000:],map_soln_gp_marg_ecc["per_1_light_curve"][1000:]+map_soln_gp_marg_ecc["per_1_gp_pred"][1000:],label='longest-P')
plt.plot(x[1000:],map_soln_gp_marg_ecc["marginalized_light_curve"][1000:]+map_soln_gp_marg_ecc["marginalized_gp_pred"][1000:],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

# %% [markdown]
# Ok, so that has gone seriously hay-wire. Not sure what on earth is causing that.

# %% [markdown]
# # Incorporating logp from eccentricity in marginalisation
#
# Currently, when we do this marginalisation, I don't think we include information from the prior (namely that high-e orbits are less likely). But I'm not 100% sure on this.
#
# I would, naively, think this should push solutions to short-period, however I guess it's possible that the long-P option is also eccentric and isn't being adequately supressed? So let's try to extract the prior on the eccentricity and

# %%
with pm.Model() as model_gp_marg_ecc_2:

    #Baseline flux is now in the GPs, so deleting this:
    #mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    #Initialising eccentricity and omega:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)

    logprobs = []
    logpriors= []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=model_gp_marg_ecc_2) as submodel:
            
            period = pm.Deterministic("period", periods[i])
            ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
            omega = xo.distributions.Angle("omega")

            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1)
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred = pm.Deterministic("gp_pred", gp.predict())
            gp_preds.append(gp.predict())
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-8/3 (occurrence rate (P^-1) * window function (P^-1) * transit probability (P^-2/3) )
            # We also need to include the log probabilities of the other marginalised variables - ecc & omega
            '''print(submodel.test_point)
            exec("submodel_ecc_int='per_"+str(i)+"_ecc_interval__'")
            print(submodel.test_point[submodel_ecc_int])
            print(submodel.ecc_interval__.logp(submodel.test_point))'''
            print("ecc_logp at p=",periods[i],submodel.ecc_interval__.logp(submodel.test_point))
            logprior = -8 * tt.log(period) / 3 + submodel.ecc_interval__.logp(submodel.test_point)
            logprobs.append(loglike + logprior)
            logpriors.append(logprior)

    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    logprior_class = pm.Deterministic("logprior_class", tt.stack(logpriors))
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve and gp prediction
    pm.Deterministic("marginalized_light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    pm.Deterministic("marginalized_gp_pred", tt.sum(tt.stack(gp_preds) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(model_gp_marg_ecc_2.test_point)
    print(model_gp_marg_ecc_2.check_test_point())
    map_soln_gp_marg_ecc_2 = xo.optimize(vars=[r, b])
    map_soln_gp_marg_ecc_2 = xo.optimize(start=map_soln_gp_marg_ecc_2, vars=[logs2])
    map_soln_gp_marg_ecc_2 = xo.optimize(start=map_soln_gp_marg_ecc_2, vars=[t0_1, t0_2])
    map_soln_gp_marg_ecc_2 = xo.optimize(start=map_soln_gp_marg_ecc_2, vars=[logs2, logpower])
    map_soln_gp_marg_ecc_2 = xo.optimize(start=map_soln_gp_marg_ecc_2, vars=[logw0])
    map_soln_gp_marg_ecc_2 = xo.optimize(start=map_soln_gp_marg_ecc_2, vars=[r,b,ecc,Rs,u])

    map_soln_gp_marg_ecc_2 = xo.optimize(map_soln_gp_marg_ecc_2)
# Out:
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# ecc_logp at p= Subtensor{int64}.0 -1.8506779495259122
# {'Rs': array(1.), 'logrho_S': array(0.), 't0_1': array(105.57), 't0_2': array(205.57), 'u_quadlimbdark__': array([-1.09861229, -0.84729786]), 'r_interval__': array(0.), 'b_impact__': array(-0.59116847), 'logs2': array(-6.65444898), 'logw0_interval__': array(-0.60183699), 'logpower_interval__': array(1.18693347), 'per_0_ecc_interval__': array(-1.11022302e-16), 'per_0_omega_angle__': array([0., 1.]), 'per_1_ecc_interval__': array(-1.11022302e-16), 'per_1_omega_angle__': array([0., 1.]), 'per_2_ecc_interval__': array(-1.11022302e-16), 'per_2_omega_angle__': array([0., 1.]), 'per_3_ecc_interval__': array(-1.11022302e-16), 'per_3_omega_angle__': array([0., 1.]), 'per_4_ecc_interval__': array(-1.11022302e-16), 'per_4_omega_angle__': array([0., 1.]), 'per_5_ecc_interval__': array(-1.11022302e-16), 'per_5_omega_angle__': array([0., 1.]), 'per_6_ecc_interval__': array(-1.11022302e-16), 'per_6_omega_angle__': array([0., 1.]), 'per_7_ecc_interval__': array(-1.11022302e-16), 'per_7_omega_angle__': array([0., 1.]), 'per_8_ecc_interval__': array(-1.11022302e-16), 'per_8_omega_angle__': array([0., 1.]), 'per_9_ecc_interval__': array(-1.11022302e-16), 'per_9_omega_angle__': array([0., 1.]), 'per_10_ecc_interval__': array(-1.11022302e-16), 'per_10_omega_angle__': array([0., 1.]), 'per_11_ecc_interval__': array(-1.11022302e-16), 'per_11_omega_angle__': array([0., 1.]), 'per_12_ecc_interval__': array(-1.11022302e-16), 'per_12_omega_angle__': array([0., 1.]), 'per_13_ecc_interval__': array(-1.11022302e-16), 'per_13_omega_angle__': array([0., 1.]), 'per_14_ecc_interval__': array(-1.11022302e-16), 'per_14_omega_angle__': array([0., 1.]), 'per_15_ecc_interval__': array(-1.11022302e-16), 'per_15_omega_angle__': array([0., 1.]), 'per_16_ecc_interval__': array(-1.11022302e-16), 'per_16_omega_angle__': array([0., 1.])}
# Rs                       0.29
# logrho_S                -0.23
# t0_1                    -0.00
# t0_2                    -0.00
# u_quadlimbdark__        -3.23
# r_interval__            -1.39
# b_impact__              -1.47
# logs2                   -0.92
# logw0_interval__        -1.48
# logpower_interval__     -1.72
# per_0_ecc_interval__    -1.85
# per_0_omega_angle__     -0.50
# per_1_ecc_interval__    -1.85
# per_1_omega_angle__     -0.50
# per_2_ecc_interval__    -1.85
# per_2_omega_angle__     -0.50
# per_3_ecc_interval__    -1.85
# per_3_omega_angle__     -0.50
# per_4_ecc_interval__    -1.85
# per_4_omega_angle__     -0.50
# per_5_ecc_interval__    -1.85
# per_5_omega_angle__     -0.50
# per_6_ecc_interval__    -1.85
# per_6_omega_angle__     -0.50
# per_7_ecc_interval__    -1.85
# per_7_omega_angle__     -0.50
# per_8_ecc_interval__    -1.85
# per_8_omega_angle__     -0.50
# per_9_ecc_interval__    -1.85
# per_9_omega_angle__     -0.50
# per_10_ecc_interval__   -1.85
# per_10_omega_angle__    -0.50
# per_11_ecc_interval__   -1.85
# per_11_omega_angle__    -0.50
# per_12_ecc_interval__   -1.85
# per_12_omega_angle__    -0.50
# per_13_ecc_interval__   -1.85
# per_13_omega_angle__    -0.50
# per_14_ecc_interval__   -1.85
# per_14_omega_angle__    -0.50
# per_15_ecc_interval__   -1.85
# per_15_omega_angle__    -0.50
# per_16_ecc_interval__   -1.85
# per_16_omega_angle__    -0.50
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [b, r, Rs]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-1.676441e+04]
# 1it [00:00, 49.27it/s, logp=-1.676441e+04]
# 2it [00:00, 65.04it/s, logp=-1.676441e+04]
# 3it [00:00, 72.87it/s, logp=-1.675514e+04]
# 4it [00:00, 77.95it/s, logp=-1.675531e+04]
# 5it [00:00, 80.56it/s, logp=-1.675478e+04]
# 6it [00:00, 81.21it/s, logp=-1.675417e+04]
# 7it [00:00, 83.35it/s, logp=-1.675353e+04]
# 8it [00:00, 85.52it/s, logp=-1.675343e+04]
# 9it [00:00, 85.24it/s, logp=-1.675342e+04]
# 10it [00:00, 93.85it/s, logp=-1.675342e+04]
# 10it [00:00, 93.85it/s, logp=-1.675342e+04]
# 11it [00:00, 93.85it/s, logp=-1.675342e+04]
# 12it [00:00, 93.85it/s, logp=-1.675342e+04]
# 13it [00:00, 93.85it/s, logp=-1.675342e+04]
# 14it [00:00, 93.85it/s, logp=-1.675342e+04]
# 15it [00:00, 93.85it/s, logp=-1.675342e+04]
# 16it [00:14,  1.11it/s, logp=-1.675342e+04]
# message: Optimization terminated successfully.
# logp: -16764.413035627633 -> -16753.416188351814
# optimizing logp for variables: [logs2]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-1.675342e+04]
# 1it [00:00, 51.40it/s, logp=-1.675342e+04]
# 2it [00:00, 69.33it/s, logp=-1.675342e+04]
# 3it [00:00, 77.59it/s, logp=-1.620587e+04]
# 4it [00:00, 79.39it/s, logp=-4.275232e+03]
# 5it [00:00, 83.77it/s, logp=-1.667420e+04]
# 6it [00:00, 87.20it/s, logp=-4.183138e+03]
# 7it [00:00, 88.12it/s, logp=-2.865252e+03]
# 8it [00:00, 88.52it/s, logp=-4.431096e+03]
# 9it [00:00, 90.20it/s, logp=-2.863269e+03]
# 10it [00:00, 99.49it/s, logp=-2.863269e+03]
# 10it [00:00, 99.49it/s, logp=-2.863213e+03]
# 11it [00:00, 99.49it/s, logp=-2.863213e+03]
# 13it [00:14,  1.09s/it, logp=-2.863213e+03]
# message: Optimization terminated successfully.
# logp: -16753.416188351814 -> -2863.21284160705
# optimizing logp for variables: [t0_2, t0_1]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-2.863213e+03]
# 1it [00:00, 44.94it/s, logp=-2.863213e+03]
# 2it [00:00, 58.88it/s, logp=-2.863213e+03]
# 3it [00:00, 66.58it/s, logp=-2.863230e+03]
# 4it [00:00, 70.62it/s, logp=-2.863213e+03]
# 5it [00:00, 71.37it/s, logp=-2.863213e+03]
# 6it [00:00, 74.25it/s, logp=-2.863213e+03]
# 7it [00:00, 76.18it/s, logp=-2.863213e+03]
# 8it [00:00, 76.48it/s, logp=-2.863213e+03]
# 9it [00:00, 85.10it/s, logp=-2.863213e+03]
# 9it [00:00, 85.10it/s, logp=-2.863213e+03]
# 10it [00:00, 85.10it/s, logp=-2.863213e+03]
# 11it [00:00, 85.10it/s, logp=-2.863213e+03]
# 12it [00:00, 85.10it/s, logp=-2.863213e+03]
# 13it [00:00, 85.10it/s, logp=-2.863213e+03]
# 14it [00:00, 85.10it/s, logp=-2.863213e+03]
# 15it [00:00, 85.10it/s, logp=-2.863213e+03]
# 16it [00:00, 85.10it/s, logp=-2.863213e+03]
# 17it [00:00, 85.10it/s, logp=-2.863213e+03]
# 18it [00:15,  1.13it/s, logp=-2.863213e+03]
# message: Optimization terminated successfully.
# logp: -2863.21284160705 -> -2863.212775567982
# optimizing logp for variables: [logpower, logs2]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-2.863213e+03]
# 1it [00:00, 49.21it/s, logp=-2.863213e+03]
# 2it [00:00, 66.27it/s, logp=-2.863213e+03]
# 3it [00:00, 74.26it/s, logp=-2.646864e+03]
# 4it [00:00, 76.11it/s, logp=-2.325725e+03]
# 5it [00:00, 79.07it/s, logp=-1.241640e+03]
# 6it [00:00, 82.79it/s, logp=3.858146e+03]
# 7it [00:00, 83.55it/s, logp=-7.246118e+06]
# 8it [00:00, 84.01it/s, logp=3.868748e+03]
# 9it [00:00, 85.45it/s, logp=-9.899827e+05]
# 10it [00:00, 94.29it/s, logp=-9.899827e+05]
# 10it [00:00, 94.29it/s, logp=7.942811e+03]
# 11it [00:00, 94.29it/s, logp=-3.646478e+04]
# 12it [00:00, 94.29it/s, logp=9.303842e+03]
# 13it [00:00, 94.29it/s, logp=-6.909715e+06]
# 14it [00:00, 94.29it/s, logp=9.304700e+03]
# 15it [00:00, 94.29it/s, logp=9.427483e+03]
# 16it [00:00, 94.29it/s, logp=9.427681e+03]
# 17it [00:00, 94.29it/s, logp=9.427731e+03]
# 18it [00:00, 94.29it/s, logp=9.427824e+03]
# 19it [00:00, 94.29it/s, logp=9.428000e+03]
# 20it [00:00, 93.00it/s, logp=9.428000e+03]
# 20it [00:00, 93.00it/s, logp=9.428335e+03]
# 21it [00:00, 93.00it/s, logp=9.428964e+03]
# 22it [00:00, 93.00it/s, logp=9.430126e+03]
# 23it [00:00, 93.00it/s, logp=9.432211e+03]
# 24it [00:00, 93.00it/s, logp=9.435807e+03]
# 25it [00:00, 93.00it/s, logp=9.441762e+03]
# 26it [00:00, 93.00it/s, logp=9.451610e+03]
# 27it [00:00, 93.00it/s, logp=9.455987e+03]
# 28it [00:00, 93.00it/s, logp=9.452489e+03]
# 29it [00:00, 91.71it/s, logp=9.452489e+03]
# 29it [00:00, 91.71it/s, logp=9.463825e+03]
# 30it [00:00, 91.71it/s, logp=-3.419397e+08]
# 31it [00:00, 91.71it/s, logp=9.463825e+03]
# 32it [00:00, 91.71it/s, logp=9.463825e+03]
# 33it [00:00, 91.71it/s, logp=-5.097182e+07]
# 34it [00:00, 91.71it/s, logp=9.467651e+03]
# 35it [00:00, 91.71it/s, logp=9.157216e+03]
# 36it [00:00, 91.71it/s, logp=9.469172e+03]
# 37it [00:00, 91.71it/s, logp=9.472171e+03]
# 38it [00:00, 90.68it/s, logp=9.472171e+03]
# 38it [00:00, 90.68it/s, logp=9.482712e+03]
# 39it [00:00, 90.68it/s, logp=9.500915e+03]
# 40it [00:00, 90.68it/s, logp=9.503577e+03]
# 41it [00:00, 90.68it/s, logp=9.503583e+03]
# 42it [00:00, 90.68it/s, logp=9.503643e+03]
# 43it [00:00, 90.68it/s, logp=9.503647e+03]
# 44it [00:00, 90.68it/s, logp=9.503647e+03]
# 46it [00:16,  2.85it/s, logp=9.503647e+03]
# message: Optimization terminated successfully.
# logp: -2863.212775567982 -> 9503.646726595482
# optimizing logp for variables: [logw0]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=9.503647e+03]
# 1it [00:00, 49.59it/s, logp=9.503647e+03]
# 2it [00:00, 60.42it/s, logp=9.503647e+03]
# 3it [00:00, 68.49it/s, logp=1.064913e+04]
# 4it [00:00, 74.16it/s, logp=1.064913e+04]
# 5it [00:00, 74.33it/s, logp=1.064913e+04]
# 6it [00:00, 76.29it/s, logp=1.064915e+04]
# 7it [00:00, 78.86it/s, logp=1.064920e+04]
# 8it [00:00, 80.46it/s, logp=1.064930e+04]
# 9it [00:00, 89.85it/s, logp=1.064930e+04]
# 9it [00:00, 89.85it/s, logp=1.064930e+04]
# 10it [00:00, 89.85it/s, logp=1.064930e+04]
# 11it [00:00, 89.85it/s, logp=1.064930e+04]
# 12it [00:00, 89.85it/s, logp=1.064930e+04]
# 13it [00:15,  1.22s/it, logp=1.064930e+04]
# message: Optimization terminated successfully.
# logp: 9503.646726595482 -> 10649.3037758379
# optimizing logp for variables: [u, Rs, per_16_ecc, b, r]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=1.064930e+04]
# 1it [00:00, 42.72it/s, logp=1.064930e+04]
# 2it [00:00, 57.94it/s, logp=1.064930e+04]
# 3it [00:00, 64.75it/s, logp=1.063083e+04]
# 4it [00:00, 67.03it/s, logp=1.065625e+04]
# 5it [00:00, 70.06it/s, logp=1.065413e+04]
# 6it [00:00, 71.79it/s, logp=1.065361e+04]
# 7it [00:00, 73.29it/s, logp=1.065664e+04]
# 8it [00:00, 74.50it/s, logp=1.065727e+04]
# 9it [00:00, 83.16it/s, logp=1.065727e+04]
# 9it [00:00, 83.16it/s, logp=1.065730e+04]
# 10it [00:00, 83.16it/s, logp=1.065760e+04]
# 11it [00:00, 83.16it/s, logp=1.065793e+04]
# 12it [00:00, 83.16it/s, logp=1.065794e+04]
# 13it [00:00, 83.16it/s, logp=1.065794e+04]
# 14it [00:00, 83.16it/s, logp=1.065794e+04]
# 15it [00:00, 83.16it/s, logp=1.065794e+04]
# 16it [00:00, 83.16it/s, logp=1.065794e+04]
# 17it [00:00, 83.16it/s, logp=1.065794e+04]
# 18it [00:00, 82.42it/s, logp=1.065794e+04]
# 18it [00:00, 82.42it/s, logp=1.065794e+04]
# 20it [00:15,  1.29it/s, logp=1.065794e+04]
# message: Optimization terminated successfully.
# logp: 10649.3037758379 -> 10657.941501939064
# optimizing logp for variables: [per_16_omega, per_16_ecc, per_15_omega, per_15_ecc, per_14_omega, per_14_ecc, per_13_omega, per_13_ecc, per_12_omega, per_12_ecc, per_11_omega, per_11_ecc, per_10_omega, per_10_ecc, per_9_omega, per_9_ecc, per_8_omega, per_8_ecc, per_7_omega, per_7_ecc, per_6_omega, per_6_ecc, per_5_omega, per_5_ecc, per_4_omega, per_4_ecc, per_3_omega, per_3_ecc, per_2_omega, per_2_ecc, per_1_omega, per_1_ecc, per_0_omega, per_0_ecc, logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=1.065794e+04]
# 1it [00:00, 34.01it/s, logp=1.065794e+04]
# 2it [00:00, 45.16it/s, logp=1.065794e+04]
# 3it [00:00, 50.66it/s, logp=1.064622e+04]
# 4it [00:00, 54.23it/s, logp=1.063364e+04]
# 5it [00:00, 56.90it/s, logp=1.064645e+04]
# 6it [00:00, 58.81it/s, logp=1.065798e+04]
# 7it [00:00, 68.09it/s, logp=1.065798e+04]
# 7it [00:00, 68.09it/s, logp=1.065813e+04]
# 8it [00:00, 68.09it/s, logp=1.065855e+04]
# 9it [00:00, 68.09it/s, logp=1.065924e+04]
# 10it [00:00, 68.09it/s, logp=1.066145e+04]
# 11it [00:00, 68.09it/s, logp=1.067013e+04]
# 12it [00:00, 68.09it/s, logp=1.070227e+04]
# 13it [00:00, 68.09it/s, logp=1.066584e+04]
# 14it [00:00, 68.62it/s, logp=1.066584e+04]
# 14it [00:00, 68.62it/s, logp=1.071579e+04]
# 15it [00:00, 68.62it/s, logp=1.073343e+04]
# 16it [00:00, 68.62it/s, logp=1.076203e+04]
# 17it [00:00, 68.62it/s, logp=1.078511e+04]
# 18it [00:00, 68.62it/s, logp=1.082795e+04]
# 19it [00:00, 68.62it/s, logp=1.090011e+04]
# 20it [00:00, 65.17it/s, logp=1.090011e+04]
# 20it [00:00, 65.17it/s, logp=-1.154189e+09]
# 21it [00:00, 65.17it/s, logp=1.090011e+04]
# 22it [00:00, 65.17it/s, logp=1.090011e+04]
# 23it [00:00, 65.17it/s, logp=-2.484358e+05]
# 24it [00:00, 65.17it/s, logp=1.091641e+04]
# 25it [00:00, 65.17it/s, logp=1.093613e+04]
# 26it [00:00, 62.68it/s, logp=1.093613e+04]
# 26it [00:00, 62.68it/s, logp=1.096907e+04]
# 27it [00:00, 62.68it/s, logp=1.103742e+04]
# 28it [00:00, 62.68it/s, logp=1.099294e+04]
# 29it [00:00, 62.68it/s, logp=1.103731e+04]
# 30it [00:00, 62.68it/s, logp=1.103965e+04]
# 31it [00:00, 62.68it/s, logp=1.104355e+04]
# 32it [00:00, 60.72it/s, logp=1.104355e+04]
# 32it [00:00, 60.72it/s, logp=1.105047e+04]
# 33it [00:00, 60.72it/s, logp=1.107270e+04]
# 34it [00:00, 60.72it/s, logp=-6.419539e+04]
# 35it [00:00, 60.72it/s, logp=1.107271e+04]
# 36it [00:00, 60.72it/s, logp=1.107326e+04]
# 37it [00:00, 60.72it/s, logp=1.104613e+04]
# 38it [00:00, 58.64it/s, logp=1.104613e+04]
# 38it [00:00, 58.64it/s, logp=1.107451e+04]
# 39it [00:00, 58.64it/s, logp=1.107808e+04]
# 40it [00:00, 58.64it/s, logp=1.106920e+04]
# 41it [00:00, 58.64it/s, logp=1.108198e+04]
# 42it [00:00, 58.64it/s, logp=1.105176e+04]
# 43it [00:00, 58.64it/s, logp=1.108343e+04]
# 44it [00:00, 58.64it/s, logp=1.108644e+04]
# 45it [00:00, 61.58it/s, logp=1.108644e+04]
# 45it [00:00, 61.58it/s, logp=1.108918e+04]
# 46it [00:00, 61.58it/s, logp=1.110139e+04]
# 47it [00:00, 61.58it/s, logp=1.103107e+04]
# 48it [00:00, 61.58it/s, logp=1.110139e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 49it [00:00, 61.58it/s, logp=1.110139e+04]
# 50it [00:00, 61.58it/s, logp=1.111179e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 51it [00:00, 61.58it/s, logp=1.094178e+04]
# 52it [00:00, 61.61it/s, logp=1.094178e+04]
# 52it [00:00, 61.61it/s, logp=1.111179e+04]
# 53it [00:00, 61.61it/s, logp=1.111179e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 54it [00:00, 61.61it/s, logp=1.094178e+04]
# 55it [00:00, 61.61it/s, logp=1.111557e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 56it [00:00, 61.61it/s, logp=1.112268e+04]
# 57it [00:00, 61.61it/s, logp=1.113529e+04]
# 58it [00:00, 60.12it/s, logp=1.113529e+04]
# 58it [00:00, 60.12it/s, logp=1.114497e+04]
# 59it [00:00, 60.12it/s, logp=1.114669e+04]
# 60it [00:00, 60.12it/s, logp=1.116234e+04]
# 61it [00:01, 60.12it/s, logp=1.116268e+04]
# 62it [00:01, 60.12it/s, logp=1.116334e+04]
# 63it [00:01, 60.12it/s, logp=1.116542e+04]
# 64it [00:01, 59.66it/s, logp=1.116542e+04]
# 64it [00:01, 59.66it/s, logp=1.116911e+04]
# 65it [00:01, 59.66it/s, logp=1.117413e+04]
# 66it [00:01, 59.66it/s, logp=1.117969e+04]
# 67it [00:01, 59.66it/s, logp=1.118417e+04]
# 68it [00:01, 59.66it/s, logp=1.118817e+04]
# 69it [00:01, 59.66it/s, logp=1.119369e+04]
# 70it [00:01, 59.66it/s, logp=1.118421e+04]
# 71it [00:01, 60.07it/s, logp=1.118421e+04]
# 71it [00:01, 60.07it/s, logp=1.119462e+04]
# 72it [00:01, 60.07it/s, logp=1.119588e+04]
# 73it [00:01, 60.07it/s, logp=1.119648e+04]
# 74it [00:01, 60.07it/s, logp=1.119739e+04]
# 75it [00:01, 60.07it/s, logp=1.119823e+04]
# 76it [00:01, 60.07it/s, logp=1.119854e+04]
# 77it [00:01, 60.07it/s, logp=1.119880e+04]
# 78it [00:01, 61.12it/s, logp=1.119880e+04]
# 78it [00:01, 61.12it/s, logp=1.119911e+04]
# 79it [00:01, 61.12it/s, logp=1.119933e+04]
# 80it [00:01, 61.12it/s, logp=1.119961e+04]
# 81it [00:01, 61.12it/s, logp=1.119989e+04]
# 82it [00:01, 61.12it/s, logp=1.120001e+04]
# 83it [00:01, 61.12it/s, logp=1.120012e+04]
# 84it [00:01, 61.12it/s, logp=1.120017e+04]
# 85it [00:01, 59.65it/s, logp=1.120017e+04]
# 85it [00:01, 59.65it/s, logp=1.120020e+04]
# 86it [00:01, 59.65it/s, logp=1.120023e+04]
# 87it [00:01, 59.65it/s, logp=1.120025e+04]
# 88it [00:01, 59.65it/s, logp=1.120028e+04]
# 89it [00:01, 59.65it/s, logp=1.120030e+04]
# 90it [00:01, 59.65it/s, logp=1.120032e+04]
# 91it [00:01, 59.65it/s, logp=1.120035e+04]
# 92it [00:01, 60.26it/s, logp=1.120035e+04]
# 92it [00:01, 60.26it/s, logp=1.120038e+04]
# 93it [00:01, 60.26it/s, logp=1.120041e+04]
# 94it [00:01, 60.26it/s, logp=1.120043e+04]
# 95it [00:01, 60.26it/s, logp=1.120045e+04]
# 96it [00:01, 60.26it/s, logp=1.120045e+04]
# 97it [00:01, 60.26it/s, logp=1.120045e+04]
# 98it [00:01, 59.89it/s, logp=1.120045e+04]
# 98it [00:01, 59.89it/s, logp=1.120046e+04]
# 99it [00:01, 59.89it/s, logp=1.120046e+04]
# 100it [00:01, 59.89it/s, logp=1.120046e+04]
# 101it [00:01, 59.89it/s, logp=1.120046e+04]
# 102it [00:01, 59.89it/s, logp=1.120046e+04]
# 103it [00:01, 59.89it/s, logp=1.120046e+04]
# 104it [00:01, 58.18it/s, logp=1.120046e+04]
# 104it [00:01, 58.18it/s, logp=1.120046e+04]
# 105it [00:01, 58.18it/s, logp=1.120046e+04]
# 106it [00:01, 58.18it/s, logp=1.120046e+04]
# 107it [00:01, 58.18it/s, logp=1.120046e+04]
# 108it [00:01, 58.18it/s, logp=1.120047e+04]
# 109it [00:01, 58.18it/s, logp=1.120047e+04]
# 110it [00:01, 58.17it/s, logp=1.120047e+04]
# 110it [00:01, 58.17it/s, logp=1.120047e+04]
# 111it [00:01, 58.17it/s, logp=1.120048e+04]
# 112it [00:01, 58.17it/s, logp=1.120048e+04]
# 113it [00:01, 58.17it/s, logp=1.120048e+04]
# 114it [00:01, 58.17it/s, logp=1.120048e+04]
# 115it [00:01, 58.17it/s, logp=1.120049e+04]
# 116it [00:01, 58.67it/s, logp=1.120049e+04]
# 116it [00:01, 58.67it/s, logp=1.120049e+04]
# 117it [00:01, 58.67it/s, logp=1.120049e+04]
# 118it [00:01, 58.67it/s, logp=1.120049e+04]
# 119it [00:01, 58.67it/s, logp=1.120049e+04]
# 120it [00:02, 58.67it/s, logp=1.120049e+04]
# 121it [00:02, 58.67it/s, logp=1.120049e+04]
# 122it [00:02, 58.67it/s, logp=1.120049e+04]
# 123it [00:02, 59.32it/s, logp=1.120049e+04]
# 123it [00:02, 59.32it/s, logp=1.120049e+04]
# 124it [00:02, 59.32it/s, logp=1.120049e+04]
# 125it [00:02, 59.32it/s, logp=1.120049e+04]
# 126it [00:02, 59.32it/s, logp=1.120049e+04]
# 127it [00:02, 59.32it/s, logp=1.120049e+04]
# 128it [00:02, 59.32it/s, logp=1.120049e+04]
# 129it [00:02, 59.32it/s, logp=1.120049e+04]
# 130it [00:02, 59.49it/s, logp=1.120049e+04]
# 130it [00:02, 59.49it/s, logp=1.120049e+04]
# 131it [00:02, 59.49it/s, logp=1.120049e+04]
# 132it [00:02, 59.49it/s, logp=1.120049e+04]
# 133it [00:02, 59.49it/s, logp=1.120049e+04]
# 134it [00:02, 59.49it/s, logp=1.120049e+04]
# 135it [00:02, 59.49it/s, logp=1.120049e+04]
# 136it [00:02, 56.82it/s, logp=1.120049e+04]
# 136it [00:02, 56.82it/s, logp=1.120049e+04]
# 137it [00:02, 56.82it/s, logp=1.120049e+04]
# 138it [00:02, 56.82it/s, logp=1.120049e+04]
# 139it [00:02, 56.82it/s, logp=1.120049e+04]
# 140it [00:02, 56.82it/s, logp=1.120049e+04]
# 141it [00:02, 56.82it/s, logp=1.120049e+04]
# 142it [00:02, 56.68it/s, logp=1.120049e+04]
# 142it [00:02, 56.68it/s, logp=1.120049e+04]
# 143it [00:02, 56.68it/s, logp=1.120049e+04]
# 144it [00:02, 56.68it/s, logp=1.120049e+04]
# 145it [00:02, 56.68it/s, logp=1.120049e+04]
# 146it [00:02, 56.68it/s, logp=1.120049e+04]
# 147it [00:02, 56.68it/s, logp=1.120049e+04]
# 148it [00:02, 56.89it/s, logp=1.120049e+04]
# 148it [00:02, 56.89it/s, logp=1.120049e+04]
# 149it [00:02, 56.89it/s, logp=1.120049e+04]
# 150it [00:02, 56.89it/s, logp=1.120049e+04]
# 151it [00:02, 56.89it/s, logp=1.120049e+04]
# 152it [00:02, 56.89it/s, logp=1.120049e+04]
# 153it [00:02, 56.89it/s, logp=1.120049e+04]
# 154it [00:02, 56.89it/s, logp=1.120049e+04]
# 155it [00:02, 57.94it/s, logp=1.120049e+04]
# 155it [00:02, 57.94it/s, logp=1.120049e+04]
# 156it [00:02, 57.94it/s, logp=1.120049e+04]
# 157it [00:02, 57.94it/s, logp=1.120049e+04]
# 158it [00:02, 57.94it/s, logp=1.120049e+04]
# 159it [00:02, 57.94it/s, logp=1.120049e+04]
# 160it [00:02, 57.94it/s, logp=1.120049e+04]
# 161it [00:02, 57.94it/s, logp=1.120049e+04]
# 162it [00:02, 58.89it/s, logp=1.120049e+04]
# 162it [00:02, 58.89it/s, logp=1.120049e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 163it [00:02, 58.89it/s, logp=1.120049e+04]
# 164it [00:02, 58.89it/s, logp=1.120049e+04]
# 165it [00:02, 58.89it/s, logp=1.120049e+04]
# 166it [00:02, 58.89it/s, logp=1.120049e+04]
# 167it [00:02, 58.89it/s, logp=1.120049e+04]
# 168it [00:02, 58.89it/s, logp=1.120049e+04]
# 169it [00:02, 60.13it/s, logp=1.120049e+04]
# 169it [00:02, 60.13it/s, logp=1.120049e+04]
# 170it [00:02, 60.13it/s, logp=1.120049e+04]
# 171it [00:02, 60.13it/s, logp=1.120049e+04]
# 172it [00:02, 60.13it/s, logp=1.120049e+04]
# 173it [00:02, 60.13it/s, logp=1.120049e+04]
# 174it [00:02, 60.13it/s, logp=1.120049e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 175it [00:15, 11.51it/s, logp=1.120049e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10657.941501939056 -> 11200.48847180062

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_gp_marg_ecc_2["periods"], map_soln_gp_marg_ecc_2["logprob_class"], "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-8/3 prior, marginalised eccentric orbit using logp")
plt.plot(map_soln_gp_marg_ecc_2["periods"],map_soln_gp_marg_ecc["logprior_class"],'-o',label='log_priors')
#[map_soln_gp_marg_ecc['per_'+str(n)+'_log_prior'] for n in range(17)]
plt.legend()

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_gp_marg_ecc_2["per_16_light_curve"][:1000]+map_soln_gp_marg_ecc_2["per_16_gp_pred"][:1000],label='shortest-P')
plt.plot(x[:1000],map_soln_gp_marg_ecc_2["per_1_light_curve"][:1000]+map_soln_gp_marg_ecc_2["per_1_gp_pred"][:1000],label='longest-P')
plt.plot(x[:1000],map_soln_gp_marg_ecc_2["marginalized_light_curve"][:1000]+map_soln_gp_marg_ecc_2["marginalized_gp_pred"][:1000],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_gp_marg_ecc_2["per_16_light_curve"][1000:]+map_soln_gp_marg_ecc_2["per_16_gp_pred"][1000:],label='shortest-P')
plt.plot(x[1000:],map_soln_gp_marg_ecc_2["per_1_light_curve"][1000:]+map_soln_gp_marg_ecc_2["per_1_gp_pred"][1000:],label='longest-P')
plt.plot(x[1000:],map_soln_gp_marg_ecc_2["marginalized_light_curve"][1000:]+map_soln_gp_marg_ecc_2["marginalized_gp_pred"][1000:],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

# %% [markdown]
# # Changing the prior
#
# Using a prior purely from period is simple, but is actually wrong for eccentric orbits as it assumes  no input from eccentricity $$p \alpha P^{2/3}$$.
#
# What we want is to maintain the period prior for occurrence rates and window function, but use computed distance during transit for the geometric prior

# %%
with pm.Model() as model_gp_marg_ecc_newprior:

    #Baseline flux is now in the GPs, so deleting this:
    #mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    #Initialising eccentricity and omega:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)

    logprobs = []
    logpriors= []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=model_gp_marg_ecc_newprior) as submodel:
            
            period = periods[i]
            ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
            omega = xo.distributions.Angle("omega")

            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1)
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred = pm.Deterministic("gp_pred", gp.predict())
            gp_preds.append(gp.predict())
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-8/3 (occurrence rate (P^-1) * window function (P^-1) * transit probability (P^-2/3) )
            d_x,d_y,d_z = orbit.get_relative_position(t0_1) #Need this to marginalise over 1/a and not just P^-5/3
            logprior = -2 * tt.log(period)-1*tt.log(tt.mean(d_z))#taking an average of the t0 
            logprobs.append(loglike + logprior)
            logpriors.append(logprior)
    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    logprior_class = pm.Deterministic("logprior_class", tt.stack(logpriors))
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve and gp prediction
    pm.Deterministic("marginalized_light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    pm.Deterministic("marginalized_gp_pred", tt.sum(tt.stack(gp_preds) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(model_gp_marg_ecc_newprior.test_point)
    print(model_gp_marg_ecc_newprior.check_test_point())
    map_soln_gp_marg_ecc_newprior = xo.optimize(vars=[r, b])
    map_soln_gp_marg_ecc_newprior = xo.optimize(start=map_soln_gp_marg_ecc_newprior, vars=[logs2])
    map_soln_gp_marg_ecc_newprior = xo.optimize(start=map_soln_gp_marg_ecc_newprior, vars=[t0_1, t0_2])
    map_soln_gp_marg_ecc_newprior = xo.optimize(start=map_soln_gp_marg_ecc_newprior, vars=[logs2, logpower])
    map_soln_gp_marg_ecc_newprior = xo.optimize(start=map_soln_gp_marg_ecc_newprior, vars=[logw0])
    map_soln_gp_marg_ecc_newprior = xo.optimize(start=map_soln_gp_marg_ecc_newprior, vars=[r,b,ecc,Rs,u])

    map_soln_gp_marg_ecc_newprior = xo.optimize(map_soln_gp_marg_ecc_newprior)
# Out:
# {'Rs': array(1.), 'logrho_S': array(0.), 't0_1': array(105.57), 't0_2': array(205.57), 'u_quadlimbdark__': array([-1.09861229, -0.84729786]), 'r_interval__': array(0.), 'b_impact__': array(-0.59116847), 'logs2': array(-6.65444898), 'logw0_interval__': array(-0.60183699), 'logpower_interval__': array(1.18693347), 'per_0_ecc_interval__': array(-1.11022302e-16), 'per_0_omega_angle__': array([0., 1.]), 'per_1_ecc_interval__': array(-1.11022302e-16), 'per_1_omega_angle__': array([0., 1.]), 'per_2_ecc_interval__': array(-1.11022302e-16), 'per_2_omega_angle__': array([0., 1.]), 'per_3_ecc_interval__': array(-1.11022302e-16), 'per_3_omega_angle__': array([0., 1.]), 'per_4_ecc_interval__': array(-1.11022302e-16), 'per_4_omega_angle__': array([0., 1.]), 'per_5_ecc_interval__': array(-1.11022302e-16), 'per_5_omega_angle__': array([0., 1.]), 'per_6_ecc_interval__': array(-1.11022302e-16), 'per_6_omega_angle__': array([0., 1.]), 'per_7_ecc_interval__': array(-1.11022302e-16), 'per_7_omega_angle__': array([0., 1.]), 'per_8_ecc_interval__': array(-1.11022302e-16), 'per_8_omega_angle__': array([0., 1.]), 'per_9_ecc_interval__': array(-1.11022302e-16), 'per_9_omega_angle__': array([0., 1.]), 'per_10_ecc_interval__': array(-1.11022302e-16), 'per_10_omega_angle__': array([0., 1.]), 'per_11_ecc_interval__': array(-1.11022302e-16), 'per_11_omega_angle__': array([0., 1.]), 'per_12_ecc_interval__': array(-1.11022302e-16), 'per_12_omega_angle__': array([0., 1.]), 'per_13_ecc_interval__': array(-1.11022302e-16), 'per_13_omega_angle__': array([0., 1.]), 'per_14_ecc_interval__': array(-1.11022302e-16), 'per_14_omega_angle__': array([0., 1.]), 'per_15_ecc_interval__': array(-1.11022302e-16), 'per_15_omega_angle__': array([0., 1.]), 'per_16_ecc_interval__': array(-1.11022302e-16), 'per_16_omega_angle__': array([0., 1.])}
# Rs                       0.29
# logrho_S                -0.23
# t0_1                    -0.00
# t0_2                    -0.00
# u_quadlimbdark__        -3.23
# r_interval__            -1.39
# b_impact__              -1.47
# logs2                   -0.92
# logw0_interval__        -1.48
# logpower_interval__     -1.72
# per_0_ecc_interval__    -1.85
# per_0_omega_angle__     -0.50
# per_1_ecc_interval__    -1.85
# per_1_omega_angle__     -0.50
# per_2_ecc_interval__    -1.85
# per_2_omega_angle__     -0.50
# per_3_ecc_interval__    -1.85
# per_3_omega_angle__     -0.50
# per_4_ecc_interval__    -1.85
# per_4_omega_angle__     -0.50
# per_5_ecc_interval__    -1.85
# per_5_omega_angle__     -0.50
# per_6_ecc_interval__    -1.85
# per_6_omega_angle__     -0.50
# per_7_ecc_interval__    -1.85
# per_7_omega_angle__     -0.50
# per_8_ecc_interval__    -1.85
# per_8_omega_angle__     -0.50
# per_9_ecc_interval__    -1.85
# per_9_omega_angle__     -0.50
# per_10_ecc_interval__   -1.85
# per_10_omega_angle__    -0.50
# per_11_ecc_interval__   -1.85
# per_11_omega_angle__    -0.50
# per_12_ecc_interval__   -1.85
# per_12_omega_angle__    -0.50
# per_13_ecc_interval__   -1.85
# per_13_omega_angle__    -0.50
# per_14_ecc_interval__   -1.85
# per_14_omega_angle__    -0.50
# per_15_ecc_interval__   -1.85
# per_15_omega_angle__    -0.50
# per_16_ecc_interval__   -1.85
# per_16_omega_angle__    -0.50
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [b, r, Rs]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-1.676371e+04]
# 1it [00:00, 46.69it/s, logp=-1.676371e+04]
# 2it [00:00, 63.10it/s, logp=-1.676371e+04]
# 3it [00:00, 70.35it/s, logp=-1.675443e+04]
# 4it [00:00, 75.53it/s, logp=-1.675461e+04]
# 5it [00:00, 78.90it/s, logp=-1.675407e+04]
# 6it [00:00, 81.65it/s, logp=-1.675347e+04]
# 7it [00:00, 83.38it/s, logp=-1.675282e+04]
# 8it [00:00, 85.26it/s, logp=-1.675272e+04]
# 9it [00:00, 86.60it/s, logp=-1.675272e+04]
# 10it [00:00, 95.55it/s, logp=-1.675272e+04]
# 10it [00:00, 95.55it/s, logp=-1.675271e+04]
# 11it [00:00, 95.55it/s, logp=-1.675271e+04]
# 12it [00:00, 95.55it/s, logp=-1.675271e+04]
# 13it [00:00, 95.55it/s, logp=-1.675271e+04]
# 14it [00:00, 95.55it/s, logp=-1.675271e+04]
# 16it [00:16,  1.05s/it, logp=-1.675271e+04]
# message: Optimization terminated successfully.
# logp: -16763.711025581597 -> -16752.71357974665
# optimizing logp for variables: [logs2]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-1.675271e+04]
# 1it [00:00, 55.39it/s, logp=-1.675271e+04]
# 2it [00:00, 73.98it/s, logp=-1.675271e+04]
# 3it [00:00, 85.32it/s, logp=-1.620516e+04]
# 4it [00:00, 92.00it/s, logp=-4.274529e+03]
# 5it [00:00, 97.03it/s, logp=-1.667350e+04]
# 6it [00:00, 99.76it/s, logp=-4.182435e+03]
# 7it [00:00, 102.09it/s, logp=-2.864549e+03]
# 8it [00:00, 104.05it/s, logp=-4.430393e+03]
# 9it [00:00, 105.39it/s, logp=-2.862567e+03]
# 10it [00:00, 106.81it/s, logp=-2.862510e+03]
# 11it [00:00, 108.16it/s, logp=-2.862510e+03]
# 12it [00:00, 117.25it/s, logp=-2.862510e+03]
# 13it [00:17,  1.35s/it, logp=-2.862510e+03]
# message: Optimization terminated successfully.
# logp: -16752.71357974665 -> -2862.5102398126314
# optimizing logp for variables: [t0_2, t0_1]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-2.862510e+03]
# 1it [00:00, 48.93it/s, logp=-2.862510e+03]
# 2it [00:00, 64.85it/s, logp=-2.862510e+03]
# 3it [00:00, 71.72it/s, logp=-2.862528e+03]
# 4it [00:00, 74.13it/s, logp=-2.862510e+03]
# 5it [00:00, 76.93it/s, logp=-2.862510e+03]
# 6it [00:00, 78.20it/s, logp=-2.862511e+03]
# 7it [00:00, 80.07it/s, logp=-2.862510e+03]
# 8it [00:00, 81.09it/s, logp=-2.862510e+03]
# 9it [00:00, 82.28it/s, logp=-2.862510e+03]
# 10it [00:00, 90.82it/s, logp=-2.862510e+03]
# 10it [00:00, 90.82it/s, logp=-2.862510e+03]
# 11it [00:00, 90.82it/s, logp=-2.862510e+03]
# 12it [00:00, 90.82it/s, logp=-2.862510e+03]
# 13it [00:00, 90.82it/s, logp=-2.862510e+03]
# 14it [00:00, 90.82it/s, logp=-2.862510e+03]
# 15it [00:00, 90.82it/s, logp=-2.862510e+03]
# 17it [00:13,  1.28it/s, logp=-2.862510e+03]
# message: Optimization terminated successfully.
# logp: -2862.5102398126314 -> -2862.5101735218664
# optimizing logp for variables: [logpower, logs2]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=-2.862510e+03]
# 1it [00:00, 42.75it/s, logp=-2.862510e+03]
# 2it [00:00, 56.05it/s, logp=-2.862510e+03]
# 3it [00:00, 62.54it/s, logp=-2.646161e+03]
# 4it [00:00, 67.80it/s, logp=-2.325023e+03]
# 5it [00:00, 70.94it/s, logp=-1.240938e+03]
# 6it [00:00, 73.50it/s, logp=3.858848e+03]
# 7it [00:00, 75.97it/s, logp=-7.246128e+06]
# 8it [00:00, 78.32it/s, logp=3.869450e+03]
# 9it [00:00, 87.27it/s, logp=3.869450e+03]
# 9it [00:00, 87.27it/s, logp=-9.899770e+05]
# 10it [00:00, 87.27it/s, logp=7.943511e+03]
# 11it [00:00, 87.27it/s, logp=-3.646354e+04]
# 12it [00:00, 87.27it/s, logp=9.304549e+03]
# 13it [00:00, 87.27it/s, logp=-6.909857e+06]
# 14it [00:00, 87.27it/s, logp=9.305407e+03]
# 15it [00:00, 87.27it/s, logp=9.428192e+03]
# 16it [00:00, 87.27it/s, logp=9.428391e+03]
# 17it [00:00, 87.27it/s, logp=9.428441e+03]
# 18it [00:00, 87.27it/s, logp=9.428534e+03]
# 19it [00:00, 87.27it/s, logp=9.428710e+03]
# 20it [00:00, 91.58it/s, logp=9.428710e+03]
# 20it [00:00, 91.58it/s, logp=9.429045e+03]
# 21it [00:00, 91.58it/s, logp=9.429673e+03]
# 22it [00:00, 91.58it/s, logp=9.430835e+03]
# 23it [00:00, 91.58it/s, logp=9.432920e+03]
# 24it [00:00, 91.58it/s, logp=9.436515e+03]
# 25it [00:00, 91.58it/s, logp=9.442470e+03]
# 26it [00:00, 91.58it/s, logp=9.452318e+03]
# 27it [00:00, 91.58it/s, logp=9.456788e+03]
# 28it [00:00, 91.58it/s, logp=9.453204e+03]
# 29it [00:00, 91.58it/s, logp=9.464539e+03]
# 30it [00:00, 91.58it/s, logp=-3.419422e+08]
# 31it [00:00, 96.05it/s, logp=-3.419422e+08]
# 31it [00:00, 96.05it/s, logp=9.464539e+03]
# 32it [00:00, 96.05it/s, logp=-3.390242e+08]
# 33it [00:00, 96.05it/s, logp=9.464539e+03]
# 34it [00:00, 96.05it/s, logp=9.464539e+03]
# 35it [00:00, 96.05it/s, logp=9.382053e+03]
# 36it [00:00, 96.05it/s, logp=9.467183e+03]
# 37it [00:00, 96.05it/s, logp=9.466244e+03]
# 38it [00:00, 96.05it/s, logp=9.468714e+03]
# 39it [00:00, 96.05it/s, logp=9.401602e+03]
# 40it [00:00, 96.05it/s, logp=9.470500e+03]
# 41it [00:00, 96.05it/s, logp=9.474004e+03]
# 42it [00:00, 97.67it/s, logp=9.474004e+03]
# 42it [00:00, 97.67it/s, logp=9.485990e+03]
# 43it [00:00, 97.67it/s, logp=9.503815e+03]
# 44it [00:00, 97.67it/s, logp=9.504348e+03]
# 45it [00:00, 97.67it/s, logp=9.504354e+03]
# 46it [00:00, 97.67it/s, logp=9.504356e+03]
# 47it [00:00, 97.67it/s, logp=9.504356e+03]
# 48it [00:00, 97.67it/s, logp=9.504356e+03]
# 50it [00:18,  2.78it/s, logp=9.504356e+03]
# message: Optimization terminated successfully.
# logp: -2862.5101735218664 -> 9504.356410098415
# optimizing logp for variables: [logw0]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=9.504356e+03]
# 1it [00:00, 49.31it/s, logp=9.504356e+03]
# 2it [00:00, 66.31it/s, logp=9.504356e+03]
# 3it [00:00, 73.05it/s, logp=1.064984e+04]
# 4it [00:00, 73.96it/s, logp=1.064984e+04]
# 5it [00:00, 77.82it/s, logp=1.064984e+04]
# 6it [00:00, 80.19it/s, logp=1.064986e+04]
# 7it [00:00, 82.26it/s, logp=1.064991e+04]
# 8it [00:00, 83.82it/s, logp=1.065001e+04]
# 9it [00:00, 85.51it/s, logp=1.065001e+04]
# 10it [00:00, 94.30it/s, logp=1.065001e+04]
# 10it [00:00, 94.30it/s, logp=1.065001e+04]
# 11it [00:00, 94.30it/s, logp=1.065001e+04]
# 12it [00:00, 94.30it/s, logp=1.065001e+04]
# 13it [00:14,  1.11s/it, logp=1.065001e+04]
# message: Optimization terminated successfully.
# logp: 9504.356410098415 -> 10650.013470587748
# optimizing logp for variables: [u, Rs, per_16_ecc, b, r]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=1.065001e+04]
# 1it [00:00, 46.65it/s, logp=1.065001e+04]
# 2it [00:00, 62.30it/s, logp=1.065001e+04]
# 3it [00:00, 70.86it/s, logp=1.063162e+04]
# 4it [00:00, 75.66it/s, logp=1.065695e+04]
# 5it [00:00, 79.46it/s, logp=1.065503e+04]
# 6it [00:00, 82.71it/s, logp=1.065421e+04]
# 7it [00:00, 84.76it/s, logp=1.065734e+04]
# 8it [00:00, 86.28it/s, logp=1.065795e+04]
# 9it [00:00, 87.79it/s, logp=1.065804e+04]
# 10it [00:00, 96.83it/s, logp=1.065804e+04]
# 10it [00:00, 96.83it/s, logp=1.065821e+04]
# 11it [00:00, 96.83it/s, logp=1.065847e+04]
# 12it [00:00, 96.83it/s, logp=1.065864e+04]
# 13it [00:00, 96.83it/s, logp=1.065864e+04]
# 14it [00:00, 96.83it/s, logp=1.065864e+04]
# 15it [00:00, 96.83it/s, logp=1.065864e+04]
# 16it [00:00, 96.83it/s, logp=1.065864e+04]
# 17it [00:00, 96.83it/s, logp=1.065864e+04]
# 18it [00:00, 96.83it/s, logp=1.065864e+04]
# 19it [00:00, 96.83it/s, logp=1.065864e+04]
# 20it [00:00, 96.95it/s, logp=1.065864e+04]
# 20it [00:18,  1.10it/s, logp=1.065864e+04]
# message: Optimization terminated successfully.
# logp: 10650.013470587748 -> 10658.641117998099
# optimizing logp for variables: [per_16_omega, per_16_ecc, per_15_omega, per_15_ecc, per_14_omega, per_14_ecc, per_13_omega, per_13_ecc, per_12_omega, per_12_ecc, per_11_omega, per_11_ecc, per_10_omega, per_10_ecc, per_9_omega, per_9_ecc, per_8_omega, per_8_ecc, per_7_omega, per_7_ecc, per_6_omega, per_6_ecc, per_5_omega, per_5_ecc, per_4_omega, per_4_ecc, per_3_omega, per_3_ecc, per_2_omega, per_2_ecc, per_1_omega, per_1_ecc, per_0_omega, per_0_ecc, logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s, logp=1.065864e+04]
# 1it [00:00, 33.65it/s, logp=1.065864e+04]
# 2it [00:00, 45.45it/s, logp=1.065864e+04]
# 3it [00:00, 51.31it/s, logp=1.064445e+04]
# 4it [00:00, 54.39it/s, logp=1.064321e+04]
# 5it [00:00, 56.64it/s, logp=1.065818e+04]
# 6it [00:00, 58.51it/s, logp=1.065883e+04]
# 7it [00:00, 67.77it/s, logp=1.065883e+04]
# 7it [00:00, 67.77it/s, logp=1.065923e+04]
# 8it [00:00, 67.77it/s, logp=1.066020e+04]
# 9it [00:00, 67.77it/s, logp=1.066295e+04]
# 10it [00:00, 67.77it/s, logp=1.067370e+04]
# 11it [00:00, 67.77it/s, logp=1.071269e+04]
# 12it [00:00, 67.77it/s, logp=1.067081e+04]
# 13it [00:00, 67.77it/s, logp=1.072890e+04]
# 14it [00:00, 67.77it/s, logp=1.074797e+04]
# 15it [00:00, 68.36it/s, logp=1.074797e+04]
# 15it [00:00, 68.36it/s, logp=1.077165e+04]
# 16it [00:00, 68.36it/s, logp=1.080346e+04]
# 17it [00:00, 68.36it/s, logp=1.086086e+04]
# 18it [00:00, 68.36it/s, logp=1.091519e+04]
# 19it [00:00, 68.36it/s, logp=1.097409e+04]
# 20it [00:00, 68.36it/s, logp=1.096872e+04]
# 21it [00:00, 68.36it/s, logp=1.098615e+04]
# 22it [00:00, 68.36it/s, logp=1.099976e+04]
# 23it [00:00, 69.10it/s, logp=1.099976e+04]
# 23it [00:00, 69.10it/s, logp=1.101857e+04]
# 24it [00:00, 69.10it/s, logp=1.084570e+04]
# 25it [00:00, 69.10it/s, logp=1.103600e+04]
# 26it [00:00, 69.10it/s, logp=1.104960e+04]
# 27it [00:00, 69.10it/s, logp=1.104854e+04]
# 28it [00:00, 69.10it/s, logp=1.105128e+04]
# 29it [00:00, 69.10it/s, logp=5.173764e+03]
# 30it [00:00, 68.84it/s, logp=5.173764e+03]
# 30it [00:00, 68.84it/s, logp=1.105217e+04]
# 31it [00:00, 68.84it/s, logp=1.105441e+04]
# 32it [00:00, 68.84it/s, logp=1.105974e+04]
# 33it [00:00, 68.84it/s, logp=1.106891e+04]
# 34it [00:00, 68.84it/s, logp=1.107937e+04]
# 35it [00:00, 68.84it/s, logp=1.109743e+04]
# 36it [00:00, 68.84it/s, logp=1.112422e+04]
# 37it [00:00, 67.74it/s, logp=1.112422e+04]
# 37it [00:00, 67.74it/s, logp=1.114984e+04]
# 38it [00:00, 67.74it/s, logp=1.116341e+04]
# 39it [00:00, 67.74it/s, logp=1.117636e+04]
# 40it [00:00, 67.74it/s, logp=1.118219e+04]
# 41it [00:00, 67.74it/s, logp=1.118870e+04]
# 42it [00:00, 67.74it/s, logp=1.119099e+04]
# 43it [00:00, 67.74it/s, logp=1.119305e+04]
# 44it [00:00, 67.18it/s, logp=1.119305e+04]
# 44it [00:00, 67.18it/s, logp=1.119363e+04]
# 45it [00:00, 67.18it/s, logp=1.119468e+04]
# 46it [00:00, 67.18it/s, logp=1.119631e+04]
# 47it [00:00, 67.18it/s, logp=1.119709e+04]
# 48it [00:00, 67.18it/s, logp=1.119794e+04]
# 49it [00:00, 67.18it/s, logp=1.119829e+04]
# 50it [00:00, 63.57it/s, logp=1.119829e+04]
# 50it [00:00, 63.57it/s, logp=1.119869e+04]
# 51it [00:00, 63.57it/s, logp=1.119913e+04]
# 52it [00:00, 63.57it/s, logp=1.119937e+04]
# 53it [00:00, 63.57it/s, logp=1.119976e+04]
# 54it [00:00, 63.57it/s, logp=1.120011e+04]
# 55it [00:00, 63.57it/s, logp=1.119995e+04]
# 56it [00:00, 59.02it/s, logp=1.119995e+04]
# 56it [00:00, 59.02it/s, logp=1.120022e+04]
# 57it [00:00, 59.02it/s, logp=1.120031e+04]
# 58it [00:00, 59.02it/s, logp=1.120043e+04]
# 59it [00:00, 59.02it/s, logp=1.120053e+04]
# 60it [00:00, 59.02it/s, logp=1.120063e+04]
# 61it [00:00, 59.02it/s, logp=1.120073e+04]
# 62it [00:00, 59.02it/s, logp=1.120079e+04]
# 63it [00:00, 59.59it/s, logp=1.120079e+04]
# 63it [00:01, 59.59it/s, logp=1.120081e+04]
# 64it [00:01, 59.59it/s, logp=1.120082e+04]
# 65it [00:01, 59.59it/s, logp=1.120082e+04]
# 66it [00:01, 59.59it/s, logp=1.120082e+04]
# 67it [00:01, 59.59it/s, logp=1.120083e+04]
# 68it [00:01, 59.59it/s, logp=1.120084e+04]
# 69it [00:01, 58.63it/s, logp=1.120084e+04]
# 69it [00:01, 58.63it/s, logp=1.120085e+04]
# 70it [00:01, 58.63it/s, logp=1.120087e+04]
# 71it [00:01, 58.63it/s, logp=1.120088e+04]
# 72it [00:01, 58.63it/s, logp=1.120089e+04]
# 73it [00:01, 58.63it/s, logp=1.120089e+04]
# 74it [00:01, 58.63it/s, logp=1.120090e+04]
# 75it [00:01, 56.20it/s, logp=1.120090e+04]
# 75it [00:01, 56.20it/s, logp=1.120090e+04]
# 76it [00:01, 56.20it/s, logp=1.120090e+04]
# 77it [00:01, 56.20it/s, logp=1.120090e+04]
# 78it [00:01, 56.20it/s, logp=1.120090e+04]
# 79it [00:01, 56.20it/s, logp=1.120090e+04]
# 80it [00:01, 56.20it/s, logp=1.120090e+04]
# 81it [00:01, 54.25it/s, logp=1.120090e+04]
# 81it [00:01, 54.25it/s, logp=1.120090e+04]
# 82it [00:01, 54.25it/s, logp=1.120090e+04]
# 83it [00:01, 54.25it/s, logp=1.120090e+04]
# 84it [00:01, 54.25it/s, logp=1.120090e+04]
# 85it [00:01, 54.25it/s, logp=1.120091e+04]
# 86it [00:01, 54.25it/s, logp=1.120091e+04]
# 87it [00:01, 52.92it/s, logp=1.120091e+04]
# 87it [00:01, 52.92it/s, logp=1.120091e+04]
# 88it [00:01, 52.92it/s, logp=1.120091e+04]
# 89it [00:01, 52.92it/s, logp=1.120089e+04]
# 90it [00:01, 52.92it/s, logp=1.120092e+04]
# 91it [00:01, 52.92it/s, logp=1.120088e+04]
# 92it [00:01, 52.92it/s, logp=1.120092e+04]
# 93it [00:01, 54.34it/s, logp=1.120092e+04]
# 93it [00:01, 54.34it/s, logp=1.120093e+04]
# 94it [00:01, 54.34it/s, logp=1.120094e+04]
# 95it [00:01, 54.34it/s, logp=1.120096e+04]
# 96it [00:01, 54.34it/s, logp=1.120096e+04]
# 97it [00:01, 54.34it/s, logp=1.120097e+04]
# 98it [00:01, 54.34it/s, logp=1.120097e+04]
# 99it [00:01, 55.12it/s, logp=1.120097e+04]
# 99it [00:01, 55.12it/s, logp=1.120098e+04]
# 100it [00:01, 55.12it/s, logp=1.120098e+04]
# 101it [00:01, 55.12it/s, logp=1.120098e+04]
# 102it [00:01, 55.12it/s, logp=1.120099e+04]
# 103it [00:01, 55.12it/s, logp=1.120099e+04]
# 104it [00:01, 55.12it/s, logp=1.120099e+04]
# 105it [00:01, 51.45it/s, logp=1.120099e+04]
# 105it [00:01, 51.45it/s, logp=1.120099e+04]
# 106it [00:01, 51.45it/s, logp=1.120099e+04]
# 107it [00:01, 51.45it/s, logp=1.120099e+04]
# 108it [00:01, 51.45it/s, logp=1.120099e+04]
# 109it [00:01, 51.45it/s, logp=1.120099e+04]
# 110it [00:01, 51.45it/s, logp=1.120099e+04]
# 111it [00:01, 48.32it/s, logp=1.120099e+04]
# 111it [00:01, 48.32it/s, logp=1.120099e+04]
# 112it [00:01, 48.32it/s, logp=1.120099e+04]
# 113it [00:02, 48.32it/s, logp=1.120099e+04]
# 114it [00:02, 48.32it/s, logp=1.120099e+04]
# 115it [00:02, 48.32it/s, logp=1.120099e+04]
# 116it [00:02, 46.04it/s, logp=1.120099e+04]
# 116it [00:02, 46.04it/s, logp=1.120099e+04]
# 117it [00:02, 46.04it/s, logp=1.120099e+04]
# 118it [00:02, 46.04it/s, logp=1.120099e+04]
# 119it [00:02, 46.04it/s, logp=1.120099e+04]
# 120it [00:02, 46.04it/s, logp=1.120099e+04]
# 121it [00:02, 46.00it/s, logp=1.120099e+04]
# 121it [00:02, 46.00it/s, logp=1.120099e+04]
# 122it [00:02, 46.00it/s, logp=1.120099e+04]
# 123it [00:02, 46.00it/s, logp=1.120099e+04]
# 124it [00:02, 46.00it/s, logp=1.120099e+04]
# 125it [00:02, 46.00it/s, logp=1.120099e+04]
# 126it [00:02, 45.27it/s, logp=1.120099e+04]
# 126it [00:02, 45.27it/s, logp=1.120099e+04]
# 127it [00:02, 45.27it/s, logp=1.120099e+04]
# 128it [00:02, 45.27it/s, logp=1.120099e+04]
# 129it [00:02, 45.27it/s, logp=1.120099e+04]
# 130it [00:02, 45.27it/s, logp=1.120099e+04]
# 131it [00:02, 44.54it/s, logp=1.120099e+04]
# 131it [00:02, 44.54it/s, logp=1.120099e+04]
# 132it [00:02, 44.54it/s, logp=1.120099e+04]
# 133it [00:02, 44.54it/s, logp=1.120099e+04]
# 134it [00:02, 44.54it/s, logp=1.120099e+04]
# 135it [00:02, 44.54it/s, logp=1.120099e+04]
# 136it [00:02, 44.47it/s, logp=1.120099e+04]
# 136it [00:02, 44.47it/s, logp=1.120099e+04]
# 137it [00:02, 44.47it/s, logp=1.120099e+04]
# 138it [00:02, 44.47it/s, logp=1.120099e+04]
# 139it [00:02, 44.47it/s, logp=1.120099e+04]
# 140it [00:02, 44.47it/s, logp=1.120099e+04]
# 141it [00:02, 44.16it/s, logp=1.120099e+04]
# 141it [00:02, 44.16it/s, logp=1.120099e+04]
# 142it [00:02, 44.16it/s, logp=1.120099e+04]
# 143it [00:02, 44.16it/s, logp=1.120099e+04]
# 144it [00:02, 44.16it/s, logp=1.120099e+04]
# 145it [00:02, 44.16it/s, logp=1.120099e+04]
# 146it [00:02, 44.16it/s, logp=1.120099e+04]
# 147it [00:02, 46.62it/s, logp=1.120099e+04]
# 147it [00:02, 46.62it/s, logp=1.120099e+04]
# 148it [00:02, 46.62it/s, logp=1.120099e+04]
# 149it [00:02, 46.62it/s, logp=1.120099e+04]
# 150it [00:02, 46.62it/s, logp=1.120099e+04]
# 151it [00:02, 46.62it/s, logp=1.120099e+04]
# 152it [00:02, 46.62it/s, logp=1.120099e+04]
# 153it [00:02, 49.23it/s, logp=1.120099e+04]
# 153it [00:02, 49.23it/s, logp=1.120099e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 154it [00:02, 49.23it/s, logp=1.120099e+04]
# 155it [00:02, 49.23it/s, logp=1.120099e+04]
# 156it [00:02, 49.23it/s, logp=1.120099e+04]
# 157it [00:02, 49.23it/s, logp=1.120099e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 158it [00:02, 49.23it/s, logp=1.120099e+04]
# 159it [00:02, 49.23it/s, logp=1.120099e+04]
# 160it [00:02, 52.49it/s, logp=1.120099e+04]
# 160it [00:02, 52.49it/s, logp=1.120099e+04]
# 161it [00:02, 52.49it/s, logp=1.120099e+04]
# 162it [00:03, 52.49it/s, logp=1.120099e+04]
# 163it [00:03, 52.49it/s, logp=1.120099e+04]
# 164it [00:03, 52.49it/s, logp=1.120099e+04]
# 165it [00:03, 52.49it/s, logp=1.120099e+04]
# 166it [00:03, 52.49it/s, logp=1.120099e+04]
# 167it [00:03, 55.78it/s, logp=1.120099e+04]
# 167it [00:03, 55.78it/s, logp=1.120099e+04]
# 168it [00:03, 55.78it/s, logp=1.120099e+04]
# 169it [00:03, 55.78it/s, logp=1.120099e+04]
# 170it [00:03, 55.78it/s, logp=1.120099e+04]
# 171it [00:03, 55.78it/s, logp=1.120099e+04]
# 172it [00:03, 55.78it/s, logp=1.120099e+04]
# 173it [00:03, 55.78it/s, logp=1.120099e+04]
# 174it [00:03, 58.50it/s, logp=1.120099e+04]
# 174it [00:03, 58.50it/s, logp=1.120099e+04]
# 175it [00:03, 58.50it/s, logp=1.120099e+04]
# 176it [00:03, 58.50it/s, logp=1.120099e+04]
# 177it [00:03, 58.50it/s, logp=1.120099e+04]
# 178it [00:03, 58.50it/s, logp=1.120099e+04]
# 179it [00:03, 58.50it/s, logp=1.120099e+04]
# 180it [00:03, 58.50it/s, logp=1.120099e+04]
# 181it [00:03, 60.88it/s, logp=1.120099e+04]
# 181it [00:03, 60.88it/s, logp=1.120099e+04]
# 182it [00:03, 60.88it/s, logp=1.120099e+04]
# 183it [00:03, 60.88it/s, logp=1.120099e+04]
# 184it [00:03, 60.88it/s, logp=1.120099e+04]
# 185it [00:03, 60.88it/s, logp=1.120099e+04]
# 186it [00:03, 60.88it/s, logp=1.120099e+04]
# 187it [00:03, 60.88it/s, logp=1.120099e+04]
# 188it [00:03, 58.87it/s, logp=1.120099e+04]
# 188it [00:03, 58.87it/s, logp=1.120099e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 189it [00:03, 58.87it/s, logp=1.120099e+04]
# 190it [00:03, 58.87it/s, logp=1.120099e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 191it [00:03, 58.87it/s, logp=1.120099e+04]
# 192it [00:03, 58.87it/s, logp=1.120099e+04]
# 193it [00:03, 58.87it/s, logp=1.120099e+04]
# 194it [00:03, 57.86it/s, logp=1.120099e+04]
# 194it [00:03, 57.86it/s, logp=1.120099e+04]
# 195it [00:03, 57.86it/s, logp=1.120099e+04]
# 196it [00:03, 57.86it/s, logp=1.120099e+04]
# 197it [00:03, 57.86it/s, logp=1.120099e+04]
# 198it [00:03, 57.86it/s, logp=1.120099e+04]
# 199it [00:03, 57.86it/s, logp=1.120099e+04]
# 200it [00:03, 57.86it/s, logp=1.120099e+04]
# 201it [00:03, 59.30it/s, logp=1.120099e+04]
# 201it [00:03, 59.30it/s, logp=1.120099e+04]
# 202it [00:03, 59.30it/s, logp=1.120099e+04]
# 203it [00:03, 59.30it/s, logp=1.120099e+04]
# 204it [00:03, 59.30it/s, logp=1.120099e+04]
# 205it [00:03, 59.30it/s, logp=1.120099e+04]
# 206it [00:03, 59.30it/s, logp=1.120099e+04]
# 207it [00:03, 59.30it/s, logp=1.120099e+04]
# 208it [00:03, 60.33it/s, logp=1.120099e+04]
# 208it [00:03, 60.33it/s, logp=1.120099e+04]
# 209it [00:03, 60.33it/s, logp=1.120099e+04]
# 210it [00:03, 60.33it/s, logp=1.120099e+04]
# 211it [00:03, 60.33it/s, logp=1.120099e+04]
# 212it [00:03, 60.33it/s, logp=1.120099e+04]
# 213it [00:03, 60.33it/s, logp=1.120099e+04]
# 214it [00:03, 60.33it/s, logp=1.120099e+04]
# 215it [00:03, 59.82it/s, logp=1.120099e+04]
# 215it [00:03, 59.82it/s, logp=1.120099e+04]
# 216it [00:03, 59.82it/s, logp=1.120099e+04]
# 217it [00:03, 59.82it/s, logp=1.120099e+04]
# 218it [00:03, 59.82it/s, logp=1.120099e+04]
# 219it [00:03, 59.82it/s, logp=1.120099e+04]
# 220it [00:03, 59.82it/s, logp=1.120099e+04]
# 221it [00:03, 59.82it/s, logp=1.120099e+04]
# 222it [00:03, 61.46it/s, logp=1.120099e+04]
# 222it [00:03, 61.46it/s, logp=1.120099e+04]
# 223it [00:03, 61.46it/s, logp=1.120099e+04]
# 224it [00:04, 61.46it/s, logp=1.120099e+04]
# 225it [00:04, 61.46it/s, logp=1.120099e+04]
# 226it [00:04, 61.46it/s, logp=1.120099e+04]
# 227it [00:04, 61.46it/s, logp=1.120099e+04]
# 228it [00:04, 61.46it/s, logp=1.120099e+04]
# 229it [00:04, 61.88it/s, logp=1.120099e+04]
# 229it [00:04, 61.88it/s, logp=1.120099e+04]
# 230it [00:04, 61.88it/s, logp=1.120099e+04]
# 231it [00:04, 61.88it/s, logp=1.120099e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 232it [00:04, 61.88it/s, logp=1.120099e+04]
# 233it [00:04, 61.88it/s, logp=1.120099e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 234it [00:04, 61.88it/s, logp=1.120099e+04]
# 235it [00:04, 61.88it/s, logp=1.120099e+04]
# 236it [00:04, 56.20it/s, logp=1.120099e+04]
# 236it [00:04, 56.20it/s, logp=1.120099e+04]
# 237it [00:04, 56.20it/s, logp=1.120099e+04]
# 238it [00:04, 56.20it/s, logp=1.120099e+04]
# 239it [00:04, 56.20it/s, logp=1.120099e+04]
# 240it [00:04, 56.20it/s, logp=1.120099e+04]
# 241it [00:04, 56.20it/s, logp=1.120099e+04]
# 242it [00:04, 54.33it/s, logp=1.120099e+04]
# 242it [00:04, 54.33it/s, logp=1.120099e+04]
# 243it [00:04, 54.33it/s, logp=1.120099e+04]
# 244it [00:04, 54.33it/s, logp=1.120099e+04]
# 245it [00:04, 54.33it/s, logp=1.120099e+04]
# 246it [00:04, 54.33it/s, logp=1.120099e+04]
# 247it [00:04, 54.33it/s, logp=1.120099e+04]
# 248it [00:04, 54.33it/s, logp=1.120099e+04]
# 249it [00:04, 56.57it/s, logp=1.120099e+04]
# 249it [00:04, 56.57it/s, logp=1.120099e+04]
# 250it [00:04, 56.57it/s, logp=1.120099e+04]
# 251it [00:04, 56.57it/s, logp=1.120099e+04]
# 252it [00:04, 56.57it/s, logp=1.120099e+04]
# 253it [00:04, 56.57it/s, logp=1.120099e+04]
# 254it [00:04, 56.57it/s, logp=1.120099e+04]
# 255it [00:04, 56.57it/s, logp=1.120099e+04]
# 256it [00:04, 59.02it/s, logp=1.120099e+04]
# 256it [00:04, 59.02it/s, logp=1.120099e+04]
# 257it [00:04, 59.02it/s, logp=1.120099e+04]
# 258it [00:04, 59.02it/s, logp=1.120099e+04]
# 259it [00:04, 59.02it/s, logp=1.120099e+04]
# 260it [00:04, 59.02it/s, logp=1.120099e+04]
# 261it [00:04, 59.02it/s, logp=1.120099e+04]
# 262it [00:04, 59.30it/s, logp=1.120099e+04]
# 262it [00:04, 59.30it/s, logp=1.120099e+04]
# 263it [00:04, 59.30it/s, logp=1.120099e+04]
# 264it [00:04, 59.30it/s, logp=1.120099e+04]
# 265it [00:04, 59.30it/s, logp=1.120099e+04]
# 266it [00:04, 59.30it/s, logp=1.120099e+04]
# 267it [00:04, 59.30it/s, logp=1.120099e+04]
# 268it [00:04, 59.30it/s, logp=1.120099e+04]
# 269it [00:04, 59.49it/s, logp=1.120099e+04]
# 269it [00:04, 59.49it/s, logp=1.120099e+04]
# 270it [00:04, 59.49it/s, logp=1.120099e+04]
# 271it [00:04, 59.49it/s, logp=1.120099e+04]
# 272it [00:04, 59.49it/s, logp=1.120099e+04]
# 273it [00:04, 59.49it/s, logp=1.120099e+04]
# 274it [00:04, 59.49it/s, logp=1.120099e+04]
# 275it [00:04, 58.07it/s, logp=1.120099e+04]
# 275it [00:04, 58.07it/s, logp=1.120099e+04]
# 276it [00:04, 58.07it/s, logp=1.120099e+04]
# 277it [00:04, 58.07it/s, logp=1.120099e+04]
# 278it [00:04, 58.07it/s, logp=1.120099e+04]
# 279it [00:04, 58.07it/s, logp=1.120099e+04]
# 280it [00:04, 58.07it/s, logp=1.120099e+04]
# 281it [00:04, 58.32it/s, logp=1.120099e+04]
# 281it [00:05, 58.32it/s, logp=1.120099e+04]
# 282it [00:05, 58.32it/s, logp=1.120099e+04]
# 283it [00:05, 58.32it/s, logp=1.120099e+04]
# 284it [00:05, 58.32it/s, logp=1.120099e+04]
# 285it [00:05, 58.32it/s, logp=1.120099e+04]
# 286it [00:05, 58.32it/s, logp=1.120099e+04]
# 287it [00:05, 57.71it/s, logp=1.120099e+04]
# 287it [00:05, 57.71it/s, logp=1.120099e+04]
# 288it [00:05, 57.71it/s, logp=1.120099e+04]
# 289it [00:05, 57.71it/s, logp=1.120099e+04]
# 290it [00:05, 57.71it/s, logp=1.120099e+04]
# 291it [00:05, 57.71it/s, logp=1.120099e+04]
# 292it [00:05, 57.71it/s, logp=1.120099e+04]
# 293it [00:05, 58.33it/s, logp=1.120099e+04]
# 293it [00:05, 58.33it/s, logp=1.120099e+04]
# 294it [00:05, 58.33it/s, logp=1.120099e+04]
# 295it [00:05, 58.33it/s, logp=1.120099e+04]
# 296it [00:05, 58.33it/s, logp=1.120099e+04]
# 297it [00:05, 58.33it/s, logp=1.120099e+04]
# 298it [00:05, 58.33it/s, logp=1.120099e+04]
# 299it [00:05, 58.33it/s, logp=1.120099e+04]
# 300it [00:05, 59.57it/s, logp=1.120099e+04]
# 300it [00:05, 59.57it/s, logp=1.120099e+04]
# 301it [00:05, 59.57it/s, logp=1.120099e+04]
# 302it [00:05, 59.57it/s, logp=1.120099e+04]
# 303it [00:05, 59.57it/s, logp=1.120099e+04]
# 304it [00:05, 59.57it/s, logp=1.120099e+04]
# 305it [00:05, 59.57it/s, logp=1.120099e+04]
# 306it [00:05, 59.57it/s, logp=1.120099e+04]
# 307it [00:05, 59.89it/s, logp=1.120099e+04]
# 307it [00:05, 59.89it/s, logp=1.120099e+04]
# 308it [00:05, 59.89it/s, logp=1.120099e+04]
# 309it [00:05, 59.89it/s, logp=1.120099e+04]
# 310it [00:05, 59.89it/s, logp=1.120099e+04]
# 311it [00:05, 59.89it/s, logp=1.120099e+04]
# 312it [00:05, 59.89it/s, logp=1.120099e+04]
# 313it [00:05, 59.89it/s, logp=1.120099e+04]
# 314it [00:05, 60.44it/s, logp=1.120099e+04]
# 314it [00:05, 60.44it/s, logp=1.120099e+04]
# 315it [00:05, 60.44it/s, logp=1.120099e+04]
# 316it [00:05, 60.44it/s, logp=1.120099e+04]
# 317it [00:05, 60.44it/s, logp=1.120099e+04]
# 318it [00:05, 60.44it/s, logp=1.120099e+04]
# 319it [00:05, 60.44it/s, logp=1.120099e+04]
# 320it [00:05, 60.44it/s, logp=1.120099e+04]
# 321it [00:05, 56.36it/s, logp=1.120099e+04]
# 321it [00:05, 56.36it/s, logp=1.120099e+04]
# 322it [00:05, 56.36it/s, logp=1.120099e+04]
# 323it [00:05, 56.36it/s, logp=1.120099e+04]
# 324it [00:05, 56.36it/s, logp=1.120099e+04]
# 325it [00:05, 56.36it/s, logp=1.120099e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#
# 326it [00:05, 56.36it/s, logp=1.120099e+04]
# 327it [00:05, 55.57it/s, logp=1.120099e+04]
# 327it [00:05, 55.57it/s, logp=1.120099e+04]
# 328it [00:05, 55.57it/s, logp=1.120099e+04]
# 329it [00:05, 55.57it/s, logp=1.120099e+04]
# 330it [00:05, 55.57it/s, logp=1.120099e+04]
# 331it [00:05, 55.57it/s, logp=1.120099e+04]
# 332it [00:05, 55.57it/s, logp=1.120099e+04]
# 333it [00:05, 54.88it/s, logp=1.120099e+04]
# 333it [00:05, 54.88it/s, logp=1.120099e+04]
# 334it [00:05, 54.88it/s, logp=1.120099e+04]
# 335it [00:05, 54.88it/s, logp=1.120099e+04]
# 336it [00:05, 54.88it/s, logp=1.120099e+04]
# 337it [00:05, 54.88it/s, logp=1.120099e+04]/Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 338it [00:19, 17.63it/s, logp=1.120099e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10658.641117998099 -> 11200.9938306356

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_gp_marg_ecc_newprior["periods"], map_soln_gp_marg_ecc_newprior["logprob_class"], "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-5/3 * d_z^-1 prior, marginalised eccentric orbit")
plt.plot(map_soln_gp_marg_ecc_newprior["periods"],map_soln_gp_marg_ecc_newprior["logprior_class"],'-o',label='log_priors')
#[map_soln_gp_marg_ecc['per_'+str(n)+'_log_prior'] for n in range(17)]
plt.legend()

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_gp_marg_ecc_newprior["per_16_light_curve"][:1000]+map_soln_gp_marg_ecc_newprior["per_16_gp_pred"][:1000],label='shortest-P')
plt.plot(x[:1000],map_soln_gp_marg_ecc_newprior["per_1_light_curve"][:1000]+map_soln_gp_marg_ecc_newprior["per_1_gp_pred"][:1000],label='longest-P')
plt.plot(x[:1000],map_soln_gp_marg_ecc_newprior["marginalized_light_curve"][:1000]+map_soln_gp_marg_ecc_newprior["marginalized_gp_pred"][:1000],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_gp_marg_ecc_newprior["per_16_light_curve"][1000:]+map_soln_gp_marg_ecc_newprior["per_16_gp_pred"][1000:],label='shortest-P')
plt.plot(x[1000:],map_soln_gp_marg_ecc_newprior["per_1_light_curve"][1000:]+map_soln_gp_marg_ecc_newprior["per_1_gp_pred"][1000:],label='longest-P')
plt.plot(x[1000:],map_soln_gp_marg_ecc_newprior["marginalized_light_curve"][1000:]+map_soln_gp_marg_ecc_newprior["marginalized_gp_pred"][1000:],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

# %% [markdown]
# # Sampling with Pymc3:

# %%
np.random.seed(42)
with model_gp_marg_ecc_newprior:
    trace_gp_marg_ecc_newprior = pm.sample(
        tune=2000,
        draws=2000,
        start=map_soln_gp_marg_ecc_newprior,
        chains=2,
        step=xo.get_dense_nuts_step(target_accept=0.9),
    )
# Out:
# /Library/Python/3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [per_16_omega, per_16_ecc, per_15_omega, per_15_ecc, per_14_omega, per_14_ecc, per_13_omega, per_13_ecc, per_12_omega, per_12_ecc, per_11_omega, per_11_ecc, per_10_omega, per_10_ecc, per_9_omega, per_9_ecc, per_8_omega, per_8_ecc, per_7_omega, per_7_ecc, per_6_omega, per_6_ecc, per_5_omega, per_5_ecc, per_4_omega, per_4_ecc, per_3_omega, per_3_ecc, per_2_omega, per_2_ecc, per_1_omega, per_1_ecc, per_0_omega, per_0_ecc, logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs]
#
# Sampling 2 chains, 0 divergences:   0%|          | 0/8000 [00:00<?, ?draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 4/8000 [00:00<03:30, 38.05draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 6/8000 [00:01<38:43,  3.44draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 7/8000 [00:02<42:19,  3.15draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 8/8000 [00:03<1:25:37,  1.56draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 9/8000 [00:04<1:15:07,  1.77draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 10/8000 [00:05<1:49:21,  1.22draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 11/8000 [00:05<1:31:41,  1.45draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 12/8000 [00:07<1:59:55,  1.11draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 13/8000 [00:07<1:39:25,  1.34draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 14/8000 [00:09<2:08:42,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 15/8000 [00:09<1:45:47,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 16/8000 [00:10<2:12:06,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 17/8000 [00:11<1:47:54,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 18/8000 [00:12<2:11:07,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 19/8000 [00:13<1:46:54,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 20/8000 [00:14<2:11:20,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 21/8000 [00:14<1:47:35,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 22/8000 [00:16<2:10:51,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 23/8000 [00:16<1:46:40,  1.25draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 24/8000 [00:18<2:12:17,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 25/8000 [00:18<1:48:18,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 26/8000 [00:19<2:12:37,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 27/8000 [00:20<1:49:12,  1.22draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 28/8000 [00:21<2:12:25,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 29/8000 [00:22<1:48:14,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 30/8000 [00:23<2:11:52,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 31/8000 [00:24<1:48:38,  1.22draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 32/8000 [00:25<2:12:04,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 33/8000 [00:25<1:47:10,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 34/8000 [00:27<2:11:17,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 35/8000 [00:27<1:47:16,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 36/8000 [00:29<2:12:09,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 37/8000 [00:29<1:48:57,  1.22draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 38/8000 [00:30<2:12:00,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 39/8000 [00:31<1:47:45,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   0%|          | 40/8000 [00:32<2:10:19,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 41/8000 [00:33<1:47:10,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 42/8000 [00:34<2:11:45,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 43/8000 [00:34<1:47:54,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 44/8000 [00:36<2:11:23,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 45/8000 [00:36<1:47:12,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 46/8000 [00:38<2:10:42,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 47/8000 [00:38<1:47:31,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 48/8000 [00:39<2:13:14,  1.01s/draws]
# Sampling 2 chains, 0 divergences:   1%|          | 49/8000 [00:40<1:47:57,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 50/8000 [00:41<2:10:29,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 51/8000 [00:42<1:47:40,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 52/8000 [00:43<2:11:06,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 53/8000 [00:43<1:48:02,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 54/8000 [00:45<2:11:01,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 55/8000 [00:45<1:47:31,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 56/8000 [00:47<2:10:09,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 57/8000 [00:47<1:47:16,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 58/8000 [00:48<2:09:46,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 59/8000 [00:49<1:46:42,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 60/8000 [00:50<2:09:23,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 61/8000 [00:51<1:47:42,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 62/8000 [00:52<2:10:16,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 63/8000 [00:52<1:47:15,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 64/8000 [00:54<2:11:36,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 65/8000 [00:54<1:46:59,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 66/8000 [00:56<2:11:38,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 67/8000 [00:56<1:47:45,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 68/8000 [00:57<2:10:37,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 69/8000 [00:58<1:45:45,  1.25draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 70/8000 [00:59<2:10:22,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 71/8000 [01:00<1:46:51,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 72/8000 [01:01<2:09:51,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 73/8000 [01:01<1:46:14,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 74/8000 [01:03<2:11:29,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 75/8000 [01:03<1:46:43,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 76/8000 [01:05<2:11:21,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 77/8000 [01:05<1:47:35,  1.23draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 78/8000 [01:06<2:10:59,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 79/8000 [01:07<1:46:41,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 80/8000 [01:08<2:10:01,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 81/8000 [01:09<1:46:49,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 82/8000 [01:10<2:11:46,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 83/8000 [01:10<1:46:49,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 84/8000 [01:12<2:11:31,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 85/8000 [01:12<1:45:51,  1.25draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 86/8000 [01:14<2:10:50,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 87/8000 [01:14<1:46:17,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 88/8000 [01:15<2:10:10,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 89/8000 [01:16<1:45:34,  1.25draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 90/8000 [01:17<2:10:16,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 91/8000 [01:17<1:45:08,  1.25draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 92/8000 [01:19<2:09:45,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 93/8000 [01:19<1:45:10,  1.25draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 94/8000 [01:21<2:09:40,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 95/8000 [01:21<1:44:40,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 96/8000 [01:22<2:08:49,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 97/8000 [01:23<1:44:41,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 98/8000 [01:24<2:11:02,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   1%|          | 99/8000 [01:25<1:45:31,  1.25draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 100/8000 [01:26<2:09:00,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 101/8000 [01:26<1:43:11,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 102/8000 [01:28<2:07:41,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 103/8000 [01:28<1:43:34,  1.27draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 104/8000 [01:30<2:08:29,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 105/8000 [01:30<1:44:08,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 106/8000 [01:31<2:07:45,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 107/8000 [01:32<1:43:24,  1.27draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 108/8000 [01:33<2:07:43,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 109/8000 [01:33<1:43:33,  1.27draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 110/8000 [01:35<2:06:04,  1.04draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 111/8000 [01:35<1:42:51,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 112/8000 [01:36<2:06:26,  1.04draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 113/8000 [01:37<1:41:48,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 114/8000 [01:38<2:05:38,  1.05draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 115/8000 [01:39<1:43:16,  1.27draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 116/8000 [01:40<2:07:55,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 117/8000 [01:40<1:43:28,  1.27draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 118/8000 [01:42<2:06:27,  1.04draws/s]
# Sampling 2 chains, 0 divergences:   1%|▏         | 119/8000 [01:42<1:42:33,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 120/8000 [01:43<2:07:00,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 121/8000 [01:44<1:42:01,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 122/8000 [01:45<2:06:03,  1.04draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 123/8000 [01:46<1:41:43,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 124/8000 [01:47<2:05:56,  1.04draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 125/8000 [01:47<1:41:44,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 126/8000 [01:49<2:06:42,  1.04draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 127/8000 [01:49<1:41:50,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 128/8000 [01:50<2:07:30,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 129/8000 [01:51<1:41:32,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 130/8000 [01:52<2:05:20,  1.05draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 131/8000 [01:52<1:41:18,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 132/8000 [01:54<2:09:50,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 133/8000 [01:54<1:43:35,  1.27draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 134/8000 [01:56<2:10:58,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 135/8000 [01:56<1:44:00,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 136/8000 [01:58<2:08:22,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 137/8000 [01:58<1:42:06,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 138/8000 [01:59<2:07:12,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 139/8000 [02:00<1:41:28,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 140/8000 [02:01<2:06:58,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 141/8000 [02:01<1:40:05,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 142/8000 [02:03<2:06:50,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 143/8000 [02:03<1:40:33,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 144/8000 [02:04<2:08:19,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 145/8000 [02:05<1:41:25,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 146/8000 [02:06<2:07:55,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 147/8000 [02:07<1:40:43,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 148/8000 [02:08<2:08:06,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 149/8000 [02:08<1:39:59,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 150/8000 [02:10<2:09:25,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 151/8000 [02:10<1:41:32,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 152/8000 [02:12<2:09:09,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 153/8000 [02:12<1:40:51,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 154/8000 [02:13<2:08:51,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 155/8000 [02:14<1:40:48,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 156/8000 [02:15<2:08:25,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 157/8000 [02:15<1:40:46,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 158/8000 [02:17<2:07:10,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 159/8000 [02:17<1:39:45,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 160/8000 [02:19<2:07:55,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 161/8000 [02:19<1:39:47,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 162/8000 [02:20<2:08:24,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 163/8000 [02:21<1:40:06,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 164/8000 [02:22<2:08:39,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 165/8000 [02:22<1:40:01,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 166/8000 [02:24<2:09:49,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 167/8000 [02:24<1:40:28,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 168/8000 [02:26<2:08:58,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 169/8000 [02:26<1:39:53,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 170/8000 [02:27<2:06:50,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 171/8000 [02:28<1:39:09,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 172/8000 [02:29<2:09:43,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 173/8000 [02:29<1:40:13,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 174/8000 [02:31<2:08:40,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 175/8000 [02:31<1:39:33,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 176/8000 [02:33<2:07:52,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 177/8000 [02:33<1:39:37,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 178/8000 [02:34<2:07:51,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 179/8000 [02:35<1:39:26,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 180/8000 [02:36<2:06:31,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 181/8000 [02:36<1:38:14,  1.33draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 182/8000 [02:38<2:07:36,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 183/8000 [02:38<1:40:09,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 184/8000 [02:40<2:10:22,  1.00s/draws]
# Sampling 2 chains, 0 divergences:   2%|▏         | 185/8000 [02:40<1:40:53,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 186/8000 [02:41<2:08:48,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 187/8000 [02:42<1:39:43,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 188/8000 [02:43<2:08:10,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 189/8000 [02:43<1:39:30,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 190/8000 [02:45<2:06:40,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 191/8000 [02:45<1:39:22,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 192/8000 [02:46<2:07:12,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 193/8000 [02:47<1:38:57,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 194/8000 [02:48<2:07:42,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 195/8000 [02:49<1:40:29,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 196/8000 [02:50<2:08:24,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 197/8000 [02:50<1:40:25,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 198/8000 [02:52<2:07:33,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   2%|▏         | 199/8000 [02:52<1:39:43,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   2%|▎         | 200/8000 [02:54<2:08:44,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 201/8000 [02:54<1:39:48,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 202/8000 [02:55<2:09:44,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 203/8000 [02:56<1:41:37,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 204/8000 [02:57<2:08:48,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 205/8000 [02:57<1:40:01,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 206/8000 [02:59<2:08:42,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 207/8000 [02:59<1:40:00,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 208/8000 [03:01<2:08:06,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 209/8000 [03:01<1:39:57,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 210/8000 [03:02<2:06:09,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 211/8000 [03:03<1:38:38,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 212/8000 [03:04<2:07:56,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 213/8000 [03:04<1:38:44,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 214/8000 [03:06<2:09:27,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 215/8000 [03:06<1:39:29,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 216/8000 [03:08<2:14:38,  1.04s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 217/8000 [03:08<1:55:12,  1.13draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 218/8000 [03:10<2:46:26,  1.28s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 219/8000 [03:11<2:07:22,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 220/8000 [03:13<2:43:49,  1.26s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 221/8000 [03:13<2:06:31,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 222/8000 [03:15<2:31:37,  1.17s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 223/8000 [03:15<1:54:50,  1.13draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 224/8000 [03:16<2:19:29,  1.08s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 225/8000 [03:17<1:46:22,  1.22draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 226/8000 [03:18<2:13:51,  1.03s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 227/8000 [03:18<1:42:48,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 228/8000 [03:20<2:11:30,  1.02s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 229/8000 [03:20<1:40:25,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 230/8000 [03:22<2:11:28,  1.02s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 231/8000 [03:22<1:40:28,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 232/8000 [03:23<2:11:08,  1.01s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 233/8000 [03:24<1:41:05,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 234/8000 [03:25<2:11:07,  1.01s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 235/8000 [03:25<1:40:50,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 236/8000 [03:27<2:10:16,  1.01s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 237/8000 [03:27<1:39:05,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 238/8000 [03:29<2:08:37,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 239/8000 [03:29<1:38:57,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 240/8000 [03:31<2:08:38,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 241/8000 [03:31<1:37:42,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 242/8000 [03:32<2:08:45,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 243/8000 [03:32<1:37:33,  1.33draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 244/8000 [03:34<2:10:08,  1.01s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 245/8000 [03:34<1:38:54,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 246/8000 [03:36<2:09:05,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 247/8000 [03:36<1:38:04,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 248/8000 [03:38<2:13:04,  1.03s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 249/8000 [03:38<1:42:11,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 250/8000 [03:39<2:13:20,  1.03s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 251/8000 [03:40<1:41:13,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 252/8000 [03:41<2:11:09,  1.02s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 253/8000 [03:41<1:40:02,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 254/8000 [03:43<2:10:09,  1.01s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 255/8000 [03:43<1:39:12,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 256/8000 [03:45<2:09:05,  1.00s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 257/8000 [03:45<1:38:56,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 258/8000 [03:46<2:07:09,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 259/8000 [03:47<1:37:13,  1.33draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 260/8000 [03:48<2:06:58,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 261/8000 [03:48<1:38:23,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 262/8000 [03:50<2:07:42,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 263/8000 [03:50<1:38:41,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 264/8000 [03:52<2:08:44,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 265/8000 [03:52<1:39:06,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 266/8000 [03:54<2:11:59,  1.02s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 267/8000 [03:54<1:42:08,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 268/8000 [03:55<2:08:56,  1.00s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 269/8000 [03:56<1:41:31,  1.27draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 270/8000 [03:57<2:08:29,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 271/8000 [03:57<1:39:24,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 272/8000 [03:59<2:08:40,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 273/8000 [03:59<1:40:04,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 274/8000 [04:01<2:07:55,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 275/8000 [04:01<1:40:06,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 276/8000 [04:02<2:08:54,  1.00s/draws]
# Sampling 2 chains, 0 divergences:   3%|▎         | 277/8000 [04:03<1:39:21,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 278/8000 [04:04<2:08:01,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   3%|▎         | 279/8000 [04:04<1:39:48,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 280/8000 [04:06<2:07:12,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 281/8000 [04:06<1:38:11,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 282/8000 [04:08<2:07:39,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 283/8000 [04:08<1:38:54,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 284/8000 [04:10<2:11:00,  1.02s/draws]
# Sampling 2 chains, 0 divergences:   4%|▎         | 285/8000 [04:10<1:41:26,  1.27draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 286/8000 [04:11<2:08:43,  1.00s/draws]
# Sampling 2 chains, 0 divergences:   4%|▎         | 287/8000 [04:12<1:38:54,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 288/8000 [04:13<2:07:32,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 289/8000 [04:13<1:38:03,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 290/8000 [04:15<2:07:30,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 291/8000 [04:15<1:38:56,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 292/8000 [04:17<2:07:03,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 293/8000 [04:17<1:37:46,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 294/8000 [04:18<2:06:30,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 295/8000 [04:19<1:38:23,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 296/8000 [04:20<2:06:23,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 297/8000 [04:20<1:37:47,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 298/8000 [04:22<2:04:50,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   4%|▎         | 299/8000 [04:22<1:37:32,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 300/8000 [04:24<2:06:45,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 301/8000 [04:24<1:38:13,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 302/8000 [04:25<2:05:55,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 303/8000 [04:26<1:37:49,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 304/8000 [04:27<2:05:21,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 305/8000 [04:27<1:37:32,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 306/8000 [04:29<2:05:46,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 307/8000 [04:29<1:37:29,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 308/8000 [04:30<2:04:58,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 309/8000 [04:31<1:36:23,  1.33draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 310/8000 [04:32<2:05:18,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 311/8000 [04:32<1:37:14,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 312/8000 [04:34<2:06:45,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 313/8000 [04:34<1:37:22,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 314/8000 [04:36<2:07:01,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 315/8000 [04:36<1:37:52,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 316/8000 [04:38<2:07:54,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 317/8000 [04:38<1:38:18,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 318/8000 [04:39<2:08:04,  1.00s/draws]
# Sampling 2 chains, 0 divergences:   4%|▍         | 319/8000 [04:40<1:38:13,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 320/8000 [04:41<2:07:07,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 321/8000 [04:41<1:37:19,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 322/8000 [04:43<2:06:14,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 323/8000 [04:43<1:37:00,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 324/8000 [04:45<2:06:43,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 325/8000 [04:45<1:38:13,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 326/8000 [04:46<2:05:25,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 327/8000 [04:47<1:37:03,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 328/8000 [04:48<2:04:58,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 329/8000 [04:48<1:36:21,  1.33draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 330/8000 [04:50<2:19:55,  1.09s/draws]
# Sampling 2 chains, 0 divergences:   4%|▍         | 331/8000 [04:50<1:48:32,  1.18draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 332/8000 [04:52<2:13:33,  1.05s/draws]
# Sampling 2 chains, 0 divergences:   4%|▍         | 333/8000 [04:52<1:43:11,  1.24draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 334/8000 [04:54<2:10:45,  1.02s/draws]
# Sampling 2 chains, 0 divergences:   4%|▍         | 335/8000 [04:54<1:41:35,  1.26draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 336/8000 [04:55<2:08:57,  1.01s/draws]
# Sampling 2 chains, 0 divergences:   4%|▍         | 337/8000 [04:56<1:39:25,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 338/8000 [04:57<2:07:18,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 339/8000 [04:57<1:39:05,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 340/8000 [04:59<2:07:31,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 341/8000 [04:59<1:38:33,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 342/8000 [05:01<2:07:54,  1.00s/draws]
# Sampling 2 chains, 0 divergences:   4%|▍         | 343/8000 [05:01<1:39:28,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 344/8000 [05:03<2:07:31,  1.00draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 345/8000 [05:03<1:39:02,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 346/8000 [05:04<2:05:56,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 347/8000 [05:05<1:37:32,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 348/8000 [05:06<2:04:35,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 349/8000 [05:06<1:36:30,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 350/8000 [05:08<2:05:42,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 351/8000 [05:08<1:38:31,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 352/8000 [05:10<2:07:39,  1.00s/draws]
# Sampling 2 chains, 0 divergences:   4%|▍         | 353/8000 [05:10<1:38:59,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 354/8000 [05:11<2:06:02,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 355/8000 [05:12<1:37:53,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 356/8000 [05:13<2:05:23,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 357/8000 [05:13<1:37:32,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 358/8000 [05:15<2:04:29,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 359/8000 [05:15<1:38:13,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   4%|▍         | 360/8000 [05:17<2:05:28,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 361/8000 [05:17<1:37:40,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 362/8000 [05:18<2:04:59,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 363/8000 [05:19<1:37:20,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 364/8000 [05:20<2:04:41,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 365/8000 [05:20<1:37:18,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 366/8000 [05:22<2:04:13,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 367/8000 [05:22<1:36:41,  1.32draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 368/8000 [05:24<2:05:04,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 369/8000 [05:24<1:37:14,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 370/8000 [05:25<2:04:51,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 371/8000 [05:26<1:38:01,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 372/8000 [05:27<2:04:47,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 373/8000 [05:27<1:36:59,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 374/8000 [05:29<2:05:34,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 375/8000 [05:29<1:37:32,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 376/8000 [05:31<2:05:26,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 377/8000 [05:31<1:37:25,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 378/8000 [05:32<2:02:54,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 379/8000 [05:32<1:36:49,  1.31draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 380/8000 [05:34<2:05:23,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 381/8000 [05:34<1:37:45,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 382/8000 [05:36<2:05:09,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 383/8000 [05:36<1:38:30,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 384/8000 [05:38<2:05:15,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 385/8000 [05:38<1:38:40,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 386/8000 [05:39<2:05:21,  1.01draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 387/8000 [05:40<1:38:37,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 388/8000 [05:41<2:04:09,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 389/8000 [05:41<1:37:15,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 390/8000 [05:43<2:03:17,  1.03draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 391/8000 [05:43<1:37:48,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 392/8000 [05:45<2:04:48,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 393/8000 [05:45<1:37:56,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 394/8000 [05:46<2:03:47,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 395/8000 [05:47<1:37:36,  1.30draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 396/8000 [05:48<2:04:19,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 397/8000 [05:48<1:38:27,  1.29draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 398/8000 [05:50<2:03:52,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▍         | 399/8000 [05:50<1:38:42,  1.28draws/s]
# Sampling 2 chains, 0 divergences:   5%|▌         | 400/8000 [05:52<2:04:28,  1.02draws/s]
# Sampling 2 chains, 0 divergences:   5%|▌         | 401/8000 [05:57<5:03:28,  2.40s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 402/8000 [05:59<4:28:45,  2.12s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 403/8000 [06:04<6:40:17,  3.16s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 404/8000 [06:06<5:34:34,  2.64s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 405/8000 [06:11<7:22:29,  3.50s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 406/8000 [06:13<6:03:27,  2.87s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 407/8000 [06:18<7:42:33,  3.66s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 408/8000 [06:20<6:18:02,  2.99s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 409/8000 [06:25<7:53:04,  3.74s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 410/8000 [06:26<6:23:58,  3.04s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 411/8000 [06:32<7:57:45,  3.78s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 412/8000 [06:33<6:27:33,  3.06s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 413/8000 [06:39<8:00:35,  3.80s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 414/8000 [06:40<6:29:33,  3.08s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 415/8000 [06:46<8:00:54,  3.80s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 416/8000 [06:47<6:29:10,  3.08s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 417/8000 [06:53<8:00:08,  3.80s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 418/8000 [06:54<6:30:25,  3.09s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 419/8000 [07:00<8:03:32,  3.83s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 420/8000 [07:01<6:31:10,  3.10s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 421/8000 [07:07<8:03:16,  3.83s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 422/8000 [07:08<6:32:04,  3.10s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 423/8000 [07:13<8:03:14,  3.83s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 424/8000 [07:15<6:31:00,  3.10s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 425/8000 [07:20<8:00:56,  3.81s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 426/8000 [07:22<6:29:52,  3.09s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 427/8000 [07:27<8:02:45,  3.82s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 428/8000 [07:29<6:30:42,  3.10s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 429/8000 [07:34<8:04:25,  3.84s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 430/8000 [07:36<6:30:54,  3.10s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 431/8000 [07:41<8:05:16,  3.85s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 432/8000 [07:43<6:31:43,  3.11s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 433/8000 [07:48<8:02:44,  3.83s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 434/8000 [07:50<6:30:54,  3.10s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 435/8000 [07:55<8:09:39,  3.88s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 436/8000 [07:57<6:36:44,  3.15s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 437/8000 [08:00<6:49:44,  3.25s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 438/8000 [08:02<6:06:27,  2.91s/draws]
# Sampling 2 chains, 0 divergences:   5%|▌         | 439/8000 [08:07<7:19:38,  3.49s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 440/8000 [08:10<6:40:21,  3.18s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 441/8000 [08:14<7:32:47,  3.59s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 442/8000 [08:16<6:32:31,  3.12s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 443/8000 [08:21<7:27:40,  3.55s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 444/8000 [08:23<6:30:05,  3.10s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 445/8000 [08:27<7:23:35,  3.52s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 446/8000 [08:29<6:27:17,  3.08s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 447/8000 [08:34<7:19:45,  3.49s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 448/8000 [08:36<6:23:43,  3.05s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 449/8000 [08:41<7:38:39,  3.64s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 450/8000 [08:43<6:37:52,  3.16s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 451/8000 [08:47<7:29:34,  3.57s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 452/8000 [08:49<6:30:41,  3.11s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 453/8000 [08:54<7:22:48,  3.52s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 454/8000 [08:56<6:26:10,  3.07s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 455/8000 [09:00<7:18:07,  3.48s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 456/8000 [09:02<6:21:47,  3.04s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 457/8000 [09:07<7:16:14,  3.47s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 458/8000 [09:09<6:23:17,  3.05s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 459/8000 [09:14<7:32:16,  3.60s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 460/8000 [11:54<106:01:45, 50.62s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 461/8000 [12:01<78:39:30, 37.56s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 462/8000 [12:04<56:36:35, 27.04s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 463/8000 [12:09<42:55:37, 20.50s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 464/8000 [12:12<31:41:22, 15.14s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 465/8000 [12:13<23:05:38, 11.03s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 466/8000 [12:21<21:07:01, 10.09s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 467/8000 [12:23<16:02:37,  7.67s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 468/8000 [12:32<16:43:35,  7.99s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 469/8000 [12:34<12:55:39,  6.18s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 470/8000 [12:39<12:13:15,  5.84s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 471/8000 [12:42<10:23:18,  4.97s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 472/8000 [12:48<11:14:01,  5.37s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 473/8000 [12:51<10:01:04,  4.79s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 474/8000 [12:59<11:34:48,  5.54s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 475/8000 [13:02<10:02:38,  4.81s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 476/8000 [13:07<10:18:34,  4.93s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 477/8000 [13:09<8:25:21,  4.03s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 478/8000 [13:17<11:12:08,  5.36s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 479/8000 [13:19<9:02:50,  4.33s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 480/8000 [13:28<11:37:01,  5.56s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 481/8000 [13:30<9:21:13,  4.48s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 482/8000 [13:38<11:52:36,  5.69s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 483/8000 [13:40<9:31:57,  4.57s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 484/8000 [13:43<8:43:35,  4.18s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 485/8000 [13:48<8:58:33,  4.30s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 486/8000 [13:54<9:56:14,  4.76s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 487/8000 [13:58<9:24:55,  4.51s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 488/8000 [14:03<9:47:28,  4.69s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 489/8000 [14:07<9:20:18,  4.48s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 490/8000 [14:07<6:52:28,  3.30s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 491/8000 [14:14<8:43:41,  4.18s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 492/8000 [14:14<6:26:30,  3.09s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 493/8000 [14:23<9:48:36,  4.70s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 494/8000 [14:23<7:11:47,  3.45s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 495/8000 [14:32<10:19:47,  4.95s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 496/8000 [14:32<7:33:45,  3.63s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 497/8000 [14:41<10:36:56,  5.09s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 498/8000 [14:41<7:45:47,  3.73s/draws]
# Sampling 2 chains, 0 divergences:   6%|▌         | 499/8000 [14:45<7:53:56,  3.79s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 500/8000 [14:49<7:38:52,  3.67s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 501/8000 [14:50<6:23:37,  3.07s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 502/8000 [14:55<7:19:04,  3.51s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 503/8000 [14:58<6:51:22,  3.29s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 504/8000 [15:04<8:41:05,  4.17s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 505/8000 [15:07<7:49:49,  3.76s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 506/8000 [15:11<8:19:10,  4.00s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 507/8000 [15:13<6:51:44,  3.30s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 508/8000 [15:17<7:38:07,  3.67s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 509/8000 [15:18<5:41:28,  2.74s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 510/8000 [15:22<6:46:45,  3.26s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 511/8000 [15:26<7:12:03,  3.46s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 512/8000 [15:31<8:11:00,  3.93s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 513/8000 [15:35<8:12:33,  3.95s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 514/8000 [15:40<8:32:48,  4.11s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 515/8000 [15:40<6:19:54,  3.05s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 516/8000 [15:47<8:49:49,  4.25s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 517/8000 [15:49<7:11:29,  3.46s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 518/8000 [15:56<9:37:59,  4.64s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 519/8000 [15:58<7:45:26,  3.73s/draws]
# Sampling 2 chains, 0 divergences:   6%|▋         | 520/8000 [16:02<8:12:43,  3.95s/draws]
# Sampling 2 chains, 0 divergences:   7%|▋         | 521/8000 [16:05<7:32:41,  3.63s/draws]
# Sampling 2 chains, 0 divergences:   7%|▋         | 522/8000 [16:11<9:06:07,  4.38s/draws]
# Sampling 2 chains, 0 divergences:   7%|▋         | 523/8000 [16:14<8:08:18,  3.92s/draws]
# Sampling 2 chains, 0 divergences:   7%|▋         | 524/8000 [16:20<9:32:32,  4.60s/draws]
# Sampling 2 chains, 0 divergences:   7%|▋         | 525/8000 [16:23<8:26:37,  4.07s/draws]
# Sampling 2 chains, 0 divergences:   7%|▋         | 526/8000 [16:25<6:56:45,  3.35s/draws]
# Sampling 2 chains, 0 divergences:   7%|▋         | 527/8000 [16:28<6:38:04,  3.20s/draws]
# ...
# Sampling 2 chains, 3 divergences:  98%|█████████▊| 7824/8000 [1:55:03<02:08,  1.37draws/s]
# Sampling 2 chains, 3 divergences:  98%|█████████▊| 7826/8000 [1:55:04<01:51,  1.57draws/s]
# Sampling 2 chains, 3 divergences:  98%|█████████▊| 7828/8000 [1:55:04<01:39,  1.74draws/s]
# Sampling 2 chains, 3 divergences:  98%|█████████▊| 7829/8000 [1:55:05<01:50,  1.55draws/s]
# Sampling 2 chains, 3 divergences:  98%|█████████▊| 7831/8000 [1:55:06<01:37,  1.74draws/s]
# Sampling 2 chains, 3 divergences:  98%|█████████▊| 7832/8000 [1:55:07<01:52,  1.49draws/s]
# Sampling 2 chains, 3 divergences:  98%|█████████▊| 7833/8000 [1:55:08<01:56,  1.43draws/s]
# Sampling 2 chains, 3 divergences:  98%|█████████▊| 7835/8000 [1:55:09<02:01,  1.36draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7836/8000 [1:55:10<02:00,  1.36draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7837/8000 [1:55:10<01:32,  1.76draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7838/8000 [1:55:11<02:10,  1.24draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7839/8000 [1:55:11<01:44,  1.54draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7840/8000 [1:55:12<01:39,  1.61draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7841/8000 [1:55:13<01:48,  1.47draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7842/8000 [1:55:13<01:27,  1.80draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7843/8000 [1:55:14<01:29,  1.75draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7844/8000 [1:55:14<01:15,  2.07draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7845/8000 [1:55:15<01:33,  1.66draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7846/8000 [1:55:15<01:32,  1.66draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7847/8000 [1:55:16<01:16,  1.99draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7848/8000 [1:55:16<01:18,  1.93draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7849/8000 [1:55:16<01:07,  2.25draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7850/8000 [1:55:17<01:23,  1.81draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7851/8000 [1:55:18<01:22,  1.80draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7852/8000 [1:55:18<01:09,  2.13draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7853/8000 [1:55:19<01:13,  2.01draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7854/8000 [1:55:19<01:02,  2.33draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7855/8000 [1:55:20<01:09,  2.08draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7856/8000 [1:55:20<01:00,  2.40draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7857/8000 [1:55:21<01:39,  1.43draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7858/8000 [1:55:21<01:20,  1.75draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7859/8000 [1:55:22<01:19,  1.77draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7860/8000 [1:55:23<01:41,  1.38draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7861/8000 [1:55:24<01:35,  1.46draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7862/8000 [1:55:25<01:52,  1.23draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7863/8000 [1:55:25<01:41,  1.35draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7864/8000 [1:55:26<01:22,  1.66draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7865/8000 [1:55:27<01:52,  1.20draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7866/8000 [1:55:27<01:28,  1.51draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7867/8000 [1:55:28<01:34,  1.41draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7868/8000 [1:55:29<01:28,  1.49draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7869/8000 [1:55:30<01:44,  1.25draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7870/8000 [1:55:31<02:06,  1.03draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7871/8000 [1:55:31<01:38,  1.31draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7872/8000 [1:55:33<02:01,  1.06draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7873/8000 [1:55:33<01:34,  1.34draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7874/8000 [1:55:35<01:59,  1.05draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7875/8000 [1:55:35<01:33,  1.34draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7876/8000 [1:55:36<01:35,  1.30draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7877/8000 [1:55:36<01:26,  1.42draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7878/8000 [1:55:37<01:29,  1.36draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7879/8000 [1:55:37<01:13,  1.65draws/s]
# Sampling 2 chains, 4 divergences:  98%|█████████▊| 7880/8000 [1:55:39<01:36,  1.25draws/s]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7881/8000 [1:55:40<02:01,  1.02s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7882/8000 [1:55:41<01:50,  1.07draws/s]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7883/8000 [1:55:42<02:09,  1.11s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7884/8000 [1:55:44<02:22,  1.23s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7885/8000 [1:55:45<02:05,  1.09s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7886/8000 [1:55:45<01:54,  1.00s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7887/8000 [1:55:47<02:09,  1.14s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7888/8000 [1:55:48<01:55,  1.03s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7889/8000 [1:55:48<01:45,  1.06draws/s]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7890/8000 [1:55:49<01:37,  1.13draws/s]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7891/8000 [1:55:51<01:57,  1.08s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7892/8000 [1:55:52<02:10,  1.21s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7893/8000 [1:55:53<01:55,  1.08s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7894/8000 [1:55:54<01:45,  1.00draws/s]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7895/8000 [1:55:55<01:38,  1.07draws/s]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7896/8000 [1:55:57<02:17,  1.32s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7897/8000 [1:55:57<01:58,  1.15s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7898/8000 [1:55:58<01:44,  1.02s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▊| 7899/8000 [1:55:59<01:34,  1.07draws/s]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7900/8000 [1:56:00<01:50,  1.11s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7901/8000 [1:56:02<02:01,  1.23s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7902/8000 [1:56:04<02:10,  1.33s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7903/8000 [1:56:05<02:17,  1.42s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7904/8000 [1:56:06<01:57,  1.23s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7905/8000 [1:56:07<02:04,  1.31s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7906/8000 [1:56:10<02:51,  1.82s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7907/8000 [1:56:13<03:01,  1.95s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7908/8000 [1:56:16<03:32,  2.31s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7909/8000 [1:56:17<02:47,  1.84s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7910/8000 [1:56:18<02:36,  1.73s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7911/8000 [1:56:19<02:08,  1.45s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7912/8000 [1:56:20<02:09,  1.47s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7913/8000 [1:56:21<01:49,  1.26s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7914/8000 [1:56:23<01:55,  1.34s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7915/8000 [1:56:23<01:39,  1.17s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7916/8000 [1:56:25<01:47,  1.28s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7917/8000 [1:56:26<01:32,  1.12s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7918/8000 [1:56:27<01:41,  1.23s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7919/8000 [1:56:29<01:46,  1.32s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7920/8000 [1:56:30<01:33,  1.17s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7921/8000 [1:56:30<01:22,  1.04s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7922/8000 [1:56:31<01:15,  1.03draws/s]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7923/8000 [1:56:33<01:26,  1.13s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7924/8000 [1:56:34<01:35,  1.25s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7925/8000 [1:56:36<01:39,  1.33s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7926/8000 [1:56:37<01:41,  1.38s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7927/8000 [1:56:39<01:44,  1.44s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7928/8000 [1:56:40<01:45,  1.47s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7929/8000 [1:56:41<01:29,  1.25s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7930/8000 [1:56:43<01:50,  1.58s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7931/8000 [1:56:45<01:47,  1.55s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7932/8000 [1:56:46<01:44,  1.54s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7933/8000 [1:56:49<02:12,  1.98s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7934/8000 [1:56:50<01:46,  1.61s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7935/8000 [1:56:52<01:43,  1.59s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7936/8000 [1:56:52<01:25,  1.34s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7937/8000 [1:56:54<01:28,  1.41s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7938/8000 [1:56:56<01:29,  1.45s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7939/8000 [1:56:57<01:30,  1.48s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7940/8000 [1:56:58<01:15,  1.26s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7941/8000 [1:56:59<01:19,  1.35s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7942/8000 [1:57:01<01:20,  1.39s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7943/8000 [1:57:02<01:21,  1.43s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7944/8000 [1:57:04<01:21,  1.46s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7945/8000 [1:57:05<01:21,  1.47s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7946/8000 [1:57:07<01:19,  1.48s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7947/8000 [1:57:08<01:18,  1.48s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7948/8000 [1:57:10<01:17,  1.49s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7949/8000 [1:57:11<01:16,  1.49s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7950/8000 [1:57:13<01:14,  1.50s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7951/8000 [1:57:15<01:14,  1.52s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7952/8000 [1:57:16<01:13,  1.52s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7953/8000 [1:57:18<01:11,  1.51s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7954/8000 [1:57:18<00:59,  1.28s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7955/8000 [1:57:19<00:50,  1.12s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7956/8000 [1:57:20<00:44,  1.02s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7957/8000 [1:57:21<00:49,  1.16s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7958/8000 [1:57:23<00:52,  1.26s/draws]
# Sampling 2 chains, 4 divergences:  99%|█████████▉| 7959/8000 [1:57:24<00:55,  1.35s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7960/8000 [1:57:26<00:55,  1.39s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7961/8000 [1:57:27<00:55,  1.42s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7962/8000 [1:57:28<00:46,  1.22s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7963/8000 [1:57:30<00:48,  1.31s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7964/8000 [1:57:30<00:41,  1.15s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7965/8000 [1:57:32<00:43,  1.25s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7966/8000 [1:57:33<00:45,  1.34s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7967/8000 [1:57:35<00:45,  1.39s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7968/8000 [1:57:36<00:45,  1.42s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7969/8000 [1:57:38<00:44,  1.44s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7970/8000 [1:57:39<00:44,  1.48s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7971/8000 [1:57:40<00:36,  1.26s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7972/8000 [1:57:41<00:30,  1.11s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7973/8000 [1:57:42<00:33,  1.22s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7974/8000 [1:57:44<00:34,  1.33s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7975/8000 [1:57:46<00:35,  1.40s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7976/8000 [1:57:47<00:35,  1.49s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7977/8000 [1:57:49<00:34,  1.50s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7978/8000 [1:57:50<00:33,  1.51s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7979/8000 [1:57:52<00:31,  1.51s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7980/8000 [1:57:53<00:30,  1.52s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7981/8000 [1:57:55<00:28,  1.52s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7982/8000 [1:57:56<00:27,  1.52s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7983/8000 [1:57:58<00:25,  1.50s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7984/8000 [1:58:00<00:27,  1.74s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7985/8000 [1:58:01<00:21,  1.45s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7986/8000 [1:58:02<00:17,  1.24s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7987/8000 [1:58:03<00:14,  1.11s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7988/8000 [1:58:04<00:14,  1.24s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7989/8000 [1:58:06<00:14,  1.31s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7990/8000 [1:58:06<00:11,  1.15s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7991/8000 [1:58:09<00:15,  1.70s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7992/8000 [1:58:11<00:13,  1.64s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7993/8000 [1:58:12<00:09,  1.38s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7994/8000 [1:58:13<00:08,  1.42s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7995/8000 [1:58:15<00:07,  1.47s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7996/8000 [1:58:16<00:06,  1.52s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7997/8000 [1:58:17<00:03,  1.29s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7998/8000 [1:58:19<00:02,  1.41s/draws]
# Sampling 2 chains, 4 divergences: 100%|█████████▉| 7999/8000 [1:58:20<00:01,  1.44s/draws]
# Sampling 2 chains, 4 divergences: 100%|██████████| 8000/8000 [1:58:21<00:00,  1.13draws/s]
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 25% for some parameters.

# %%
samples = pm.trace_to_dataframe(trace_gp_marg_ecc_newprior, varnames=["t0_1", "t0_2", "r", "b"])
corner.corner(samples, labels=["t1", "t2", "r", "b"], truths=np.concatenate((t0s, [np.sqrt(0.00325), 0.3])));

# %% [markdown]
# That looks good (although b is poorly constrained). Maybe I should marginalise over b, as it is likely to also vary given the period?
#
# We have marginalised parameters for each period, with a sample/corner plot possible for each.

# %%
i=16
#Plotting corner for period[i]:
f=corner.corner(pm.trace_to_dataframe(trace_gp_marg_ecc_newprior,varnames=["per_"+str(i)+"_ecc","per_"+str(i)+"_omega"]), 
              labels=["per_"+str(i)+"_ecc","per_"+str(i)+"_omega"],truths=[0.025,0.72])

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_gp_marg_ecc_newprior["periods"], np.median(trace_gp_marg_ecc_newprior["logprob_class"],axis=0), "o-",label='log_probs')
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-5/3 * d_z^-1 prior, marginalised eccentric orbit AFTER sampling")
plt.plot(map_soln_gp_marg_ecc_newprior["periods"],np.median(trace_gp_marg_ecc_newprior["logprior_class"],axis=0),'-o',label='log_priors')
#[map_soln_gp_marg_ecc['per_'+str(n)+'_log_prior'] for n in range(17)]
plt.legend()

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],np.median(trace_gp_marg_ecc_newprior["per_16_light_curve"],axis=0)[:1000]+np.median(trace_gp_marg_ecc_newprior["per_16_gp_pred"],axis=0)[:1000],label='shortest-P')
plt.plot(x[:1000],np.median(trace_gp_marg_ecc_newprior["per_1_light_curve"],axis=0)[:1000]+np.median(trace_gp_marg_ecc_newprior["per_1_gp_pred"],axis=0)[:1000],label='longest-P')
plt.plot(x[:1000],np.median(trace_gp_marg_ecc_newprior["marginalized_light_curve"],axis=0)[:1000]+np.median(trace_gp_marg_ecc_newprior["marginalized_gp_pred"],axis=0)[:1000],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],np.median(trace_gp_marg_ecc_newprior["per_16_light_curve"],axis=0)[1000:]+np.median(trace_gp_marg_ecc_newprior["per_16_gp_pred"],axis=0)[1000:],label='shortest-P')
plt.plot(x[1000:],np.median(trace_gp_marg_ecc_newprior["per_1_light_curve"],axis=0)[1000:]+np.median(trace_gp_marg_ecc_newprior["per_1_gp_pred"],axis=0)[1000:],label='longest-P')
plt.plot(x[1000:],np.median(trace_gp_marg_ecc_newprior["marginalized_light_curve"],axis=0)[1000:]+np.median(trace_gp_marg_ecc_newprior["marginalized_gp_pred"],axis=0)[1000:],'--',alpha=0.75,linewidth=2.0,label='marginalized')
plt.legend()

# %% [markdown]
# Ok, after sampling and doing simple medians of the logprobs, that actually seems like it has worked reasonably well - the period matches that from the input!
#
# However, when I do the weighted histogram suggested by Dan, it seems to give the opposite result:

# %%
period_samps = trace_gp_marg_ecc_newprior["periods"].flatten()
weight_samps = np.exp(trace_gp_marg_ecc_newprior["logprob_class"].flatten())

plt.hist(period_samps, 500, weights=weight_samps, density=True, histtype="step")
plt.yscale("log")
plt.xlabel("period")
plt.ylabel("p(period)")
plt.ylim(1e-5,1)
# Out:
# (1e-05, 1)

# %% [markdown]
# ### Putting everything on a corner plot, with ecc, omega & period.
#
# This is a little bit hacky, but let's use the marginalised probability to select samples.
#
# Although, in this case, 99.985\% of samples come from the "correct" period of 50d. Which is crazy! Maybe we should try with more noise.

# %%
samples = pm.trace_to_dataframe(trace_gp_marg_ecc_newprior, varnames=["t0_1", "t0_2", "r", "b"])
#Artificially boosting this by a factor 3:
samples = samples.append(pm.trace_to_dataframe(trace_gp_marg_ecc_newprior, varnames=["t0_1", "t0_2", "r", "b"]))
samples = samples.append(pm.trace_to_dataframe(trace_gp_marg_ecc_newprior, varnames=["t0_1", "t0_2", "r", "b"]))

samples['ecc']=np.tile(np.nan,len(samples))
samples['period']=np.tile(np.nan,len(samples))
samples['omega']=np.tile(np.nan,len(samples))

#getting probabilities in form of cumsum:
probs=np.exp(np.median(trace_gp_marg_ecc_newprior["logprob_class"],axis=0))
probs/=np.sum(probs) #normalise to 1
cumprobs=np.hstack((0,np.cumsum(probs)))
sampix=np.arange(len(samples));lensamp=len(trace_gp_marg_ecc_newprior['Rs'])
#Looping through each period and selecting samples:
for n_ci in range(len(cumprobs)-1):
    wh=(sampix>=len(samples)*cumprobs[n_ci])&(sampix<len(samples)*cumprobs[n_ci+1])
    if np.sum(wh)>0:
        #Here we actually have some samples to take:
        samp_ix=np.random.choice(lensamp,np.sum(wh))
        samples.loc[wh,'period']=trace_gp_marg_ecc_newprior["periods"][samp_ix,n_ci]
        samples.loc[wh,'ecc']=trace_gp_marg_ecc_newprior["per_"+str(n_ci)+'_ecc'][samp_ix]
        samples.loc[wh,'omega']=trace_gp_marg_ecc_newprior["per_"+str(n_ci)+'_omega'][samp_ix]

# %%
probs=np.exp(np.median(trace_gp_marg_ecc_newprior["logprob_class"],axis=0))
probs/=np.sum(probs) #normalise to 1

# %%
probs
# Out:
# array([8.76671880e-09, 9.99855054e-01, 1.44937014e-04, 1.16778565e-11,
#        8.95080528e-17, 4.15470613e-21, 8.30768498e-25, 7.09979612e-28,
#        8.68603420e-30, 6.41389996e-33, 3.59301655e-34, 6.46577053e-35,
#        1.60756102e-36, 9.77422043e-38, 8.29507661e-39, 1.19380034e-39,
#        3.60876874e-41])

# %%
corner.corner(samples, labels=["t1", "t2", "r", "b","ecc","omega","period"], truths=np.concatenate((t0s, [np.sqrt(0.00325), 0.3,0.025,0.72,50.0])));

# %%
samples
# Out:
#             t0_1        t0_2         r         b       ecc     period  \
# 0     105.562282  205.569505  0.062675  0.617278       NaN        NaN
# 1     105.567833  205.564831  0.057432  0.406426  0.047007  50.002938
# 2     105.571557  205.570282  0.059844  0.554174  0.299230  50.002938
# 3     105.562127  205.581111  0.054035  0.069083  0.066044  50.002938
# 4     105.561395  205.568710  0.048045  0.013610  0.017251  50.002938
# ...          ...         ...       ...       ...       ...        ...
# 3995  105.559568  205.570502  0.052573  0.279612  0.297907  50.002938
# 3996  105.560727  205.566573  0.054338  0.427126  0.083402  50.002938
# 3997  105.554948  205.566655  0.053123  0.020267  0.002425  50.002938
# 3998  105.561624  205.562916  0.052130  0.041752  0.067396  50.002938
# 3999  105.560412  205.565433  0.055813  0.565830  0.431217  33.335292
#
#          omega
# 0          NaN
# 1    -2.884959
# 2     1.333654
# 3    -0.673188
# 4     0.706726
# ...        ...
# 3995 -0.740829
# 3996  2.892830
# 3997  1.802279
# 3998  0.469320
# 3999 -2.637069
#
# [12000 rows x 7 columns]

# %%
plt.plot(map_soln_gp_marg_ecc_newprior["periods"],)

# %%
# Out:
# array([100.00587501,  50.0029375 ,  33.33529167,  25.00146875,
#         20.001175  ,  16.66764583,  14.28655357,  12.50073438,
#         11.11176389,  10.0005875 ,   9.09144318,   8.33382292,
#          7.69275962,   7.14327679,   6.66705833,   6.25036719,
#          5.88269853])

# %%
trace_gp_marg_ecc_newprior.varnames
# Out:
# ['Rs',
#  'logrho_S',
#  't0_1',
#  't0_2',
#  'u_quadlimbdark__',
#  'r_interval__',
#  'b_impact__',
#  'logs2',
#  'logw0_interval__',
#  'logpower_interval__',
#  'per_0_ecc_interval__',
#  'per_0_omega_angle__',
#  'per_1_ecc_interval__',
#  'per_1_omega_angle__',
#  'per_2_ecc_interval__',
#  'per_2_omega_angle__',
#  'per_3_ecc_interval__',
#  'per_3_omega_angle__',
#  'per_4_ecc_interval__',
#  'per_4_omega_angle__',
#  'per_5_ecc_interval__',
#  'per_5_omega_angle__',
#  'per_6_ecc_interval__',
#  'per_6_omega_angle__',
#  'per_7_ecc_interval__',
#  'per_7_omega_angle__',
#  'per_8_ecc_interval__',
#  'per_8_omega_angle__',
#  'per_9_ecc_interval__',
#  'per_9_omega_angle__',
#  'per_10_ecc_interval__',
#  'per_10_omega_angle__',
#  'per_11_ecc_interval__',
#  'per_11_omega_angle__',
#  'per_12_ecc_interval__',
#  'per_12_omega_angle__',
#  'per_13_ecc_interval__',
#  'per_13_omega_angle__',
#  'per_14_ecc_interval__',
#  'per_14_omega_angle__',
#  'per_15_ecc_interval__',
#  'per_15_omega_angle__',
#  'per_16_ecc_interval__',
#  'per_16_omega_angle__',
#  'rho_S',
#  'u',
#  'r',
#  'ror',
#  'b',
#  'periods',
#  'logw0',
#  'logpower',
#  'logS0',
#  'per_0_ecc',
#  'per_0_omega',
#  'per_0_vrel',
#  'per_0_tdur',
#  'per_0_light_curve',
#  'per_0_gp_pred',
#  'per_1_ecc',
#  'per_1_omega',
#  'per_1_vrel',
#  'per_1_tdur',
#  'per_1_light_curve',
#  'per_1_gp_pred',
#  'per_2_ecc',
#  'per_2_omega',
#  'per_2_vrel',
#  'per_2_tdur',
#  'per_2_light_curve',
#  'per_2_gp_pred',
#  'per_3_ecc',
#  'per_3_omega',
#  'per_3_vrel',
#  'per_3_tdur',
#  'per_3_light_curve',
#  'per_3_gp_pred',
#  'per_4_ecc',
#  'per_4_omega',
#  'per_4_vrel',
#  'per_4_tdur',
#  'per_4_light_curve',
#  'per_4_gp_pred',
#  'per_5_ecc',
#  'per_5_omega',
#  'per_5_vrel',
#  'per_5_tdur',
#  'per_5_light_curve',
#  'per_5_gp_pred',
#  'per_6_ecc',
#  'per_6_omega',
#  'per_6_vrel',
#  'per_6_tdur',
#  'per_6_light_curve',
#  'per_6_gp_pred',
#  'per_7_ecc',
#  'per_7_omega',
#  'per_7_vrel',
#  'per_7_tdur',
#  'per_7_light_curve',
#  'per_7_gp_pred',
#  'per_8_ecc',
#  'per_8_omega',
#  'per_8_vrel',
#  'per_8_tdur',
#  'per_8_light_curve',
#  'per_8_gp_pred',
#  'per_9_ecc',
#  'per_9_omega',
#  'per_9_vrel',
#  'per_9_tdur',
#  'per_9_light_curve',
#  'per_9_gp_pred',
#  'per_10_ecc',
#  'per_10_omega',
#  'per_10_vrel',
#  'per_10_tdur',
#  'per_10_light_curve',
#  'per_10_gp_pred',
#  'per_11_ecc',
#  'per_11_omega',
#  'per_11_vrel',
#  'per_11_tdur',
#  'per_11_light_curve',
#  'per_11_gp_pred',
#  'per_12_ecc',
#  'per_12_omega',
#  'per_12_vrel',
#  'per_12_tdur',
#  'per_12_light_curve',
#  'per_12_gp_pred',
#  'per_13_ecc',
#  'per_13_omega',
#  'per_13_vrel',
#  'per_13_tdur',
#  'per_13_light_curve',
#  'per_13_gp_pred',
#  'per_14_ecc',
#  'per_14_omega',
#  'per_14_vrel',
#  'per_14_tdur',
#  'per_14_light_curve',
#  'per_14_gp_pred',
#  'per_15_ecc',
#  'per_15_omega',
#  'per_15_vrel',
#  'per_15_tdur',
#  'per_15_light_curve',
#  'per_15_gp_pred',
#  'per_16_ecc',
#  'per_16_omega',
#  'per_16_vrel',
#  'per_16_tdur',
#  'per_16_light_curve',
#  'per_16_gp_pred',
#  'logprob_class',
#  'logprior_class',
#  'marginalized_light_curve',
#  'marginalized_gp_pred']

# %%
samples = pm.trace_to_dataframe(gp_trace_oldprior, varnames=["t0_1", "t0_2", "r", "b","ecc","omega"])
samples[]

# %%
samples = pm.trace_to_dataframe(gp_trace_oldprior, varnames=["t0_1", "t0_2", "r", "b","ecc","omega"])
corner.corner(samples, labels=["t1", "t2", "r", "b","ecc","omega"], truths=np.concatenate((t0s, [np.sqrt(0.00325), 0.3,0.025,0.72])));

# %%
period_samps = gp_trace_oldprior["periods"].flatten()
weight_samps = np.exp(gp_trace_oldprior["logprob_class"].flatten())

plt.hist(period_samps, 1000, weights=weight_samps, density=True, histtype="step")
plt.yscale("log")
plt.xlabel("period")
plt.ylabel("p(period)");

# %% [markdown]
# # Eccentric orbit but marginalising over ecc/omega?

# %%
with pm.Model() as gp_model_oldprior_margecc:

    # The baseline flux
    mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    #Needed for eccentricity:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)

    logprobs = []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=gp_model_oldprior_margecc) as submodel:
            
            period = periods[i]
            
            #Initialising eccentricity and omega *for each specific period*
            ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
            omega = xo.distributions.Angle("omega")

            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1) + mean
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred=pm.Deterministic("gp_pred", gp.predict())
            gp_preds+=[gp.predict()]
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-8/3 (occurrence rate (P^-1) * window function (P^-1) * transit probability (P^-2/3) )
            logprior = -8 * tt.log(period) / 3
            logprobs.append(loglike + logprior)
    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve
    pm.Deterministic("light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(gp_model_oldprior_margecc.test_point)
    print(gp_model_oldprior_margecc.check_test_point())
    map_soln_gp_oldprior_margecc = xo.optimize(vars=[r, b, ecc,omega])
    map_soln_gp_oldprior_margecc = xo.optimize(start=map_soln_gp_oldprior_margecc, vars=[logs2])
    map_soln_gp_oldprior_margecc = xo.optimize(start=map_soln_gp_oldprior_margecc, vars=[t0_1, t0_2])
    map_soln_gp_oldprior_margecc = xo.optimize(start=map_soln_gp_oldprior_margecc, vars=[logs2, logpower])
    map_soln_gp_oldprior_margecc = xo.optimize(start=map_soln_gp_oldprior_margecc, vars=[logw0])
    map_soln_gp_oldprior_margecc = xo.optimize(start=map_soln_gp_oldprior_margecc, vars=[r,b,ecc,Rs,u])
    
    #For some reason, these causes errors at "func = get_theano_function_for_var([nlp] + grad, model=gp_model)"
    #map_soln_gp = xo.optimize(start=map_soln_gp, vars=[omega])
    map_soln_gp_oldprior_margecc = xo.optimize(map_soln_gp_oldprior_margecc)
# Out:
# {'mean': array(1.), 'Rs': array(1.), 'logrho_S': array(0.), 't0_1': array(105.57), 't0_2': array(205.57), 'u_quadlimbdark__': array([-1.09861229, -0.84729786]), 'r_interval__': array(0.), 'b_impact__': array(-0.59116847), 'logs2': array(-6.63860096), 'logw0_interval__': array(-0.60183699), 'logpower_interval__': array(1.18627699), 'per_0_ecc_interval__': array(-1.11022302e-16), 'per_0_omega_angle__': array([0., 1.]), 'per_1_ecc_interval__': array(-1.11022302e-16), 'per_1_omega_angle__': array([0., 1.]), 'per_2_ecc_interval__': array(-1.11022302e-16), 'per_2_omega_angle__': array([0., 1.]), 'per_3_ecc_interval__': array(-1.11022302e-16), 'per_3_omega_angle__': array([0., 1.]), 'per_4_ecc_interval__': array(-1.11022302e-16), 'per_4_omega_angle__': array([0., 1.]), 'per_5_ecc_interval__': array(-1.11022302e-16), 'per_5_omega_angle__': array([0., 1.]), 'per_6_ecc_interval__': array(-1.11022302e-16), 'per_6_omega_angle__': array([0., 1.]), 'per_7_ecc_interval__': array(-1.11022302e-16), 'per_7_omega_angle__': array([0., 1.]), 'per_8_ecc_interval__': array(-1.11022302e-16), 'per_8_omega_angle__': array([0., 1.]), 'per_9_ecc_interval__': array(-1.11022302e-16), 'per_9_omega_angle__': array([0., 1.]), 'per_10_ecc_interval__': array(-1.11022302e-16), 'per_10_omega_angle__': array([0., 1.]), 'per_11_ecc_interval__': array(-1.11022302e-16), 'per_11_omega_angle__': array([0., 1.]), 'per_12_ecc_interval__': array(-1.11022302e-16), 'per_12_omega_angle__': array([0., 1.]), 'per_13_ecc_interval__': array(-1.11022302e-16), 'per_13_omega_angle__': array([0., 1.]), 'per_14_ecc_interval__': array(-1.11022302e-16), 'per_14_omega_angle__': array([0., 1.]), 'per_15_ecc_interval__': array(-1.11022302e-16), 'per_15_omega_angle__': array([0., 1.]), 'per_16_ecc_interval__': array(-1.11022302e-16), 'per_16_omega_angle__': array([0., 1.])}
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# mean                    -0.92
# Rs                       0.29
# logrho_S                -0.23
# t0_1                    -0.00
# t0_2                    -0.00
# u_quadlimbdark__        -3.23
# r_interval__            -1.39
# b_impact__              -1.47
# logs2                   -0.92
# logw0_interval__        -1.48
# logpower_interval__     -1.72
# per_0_ecc_interval__    -1.85
# per_0_omega_angle__     -0.50
# per_1_ecc_interval__    -1.85
# per_1_omega_angle__     -0.50
# per_2_ecc_interval__    -1.85
# per_2_omega_angle__     -0.50
# per_3_ecc_interval__    -1.85
# per_3_omega_angle__     -0.50
# per_4_ecc_interval__    -1.85
# per_4_omega_angle__     -0.50
# per_5_ecc_interval__    -1.85
# per_5_omega_angle__     -0.50
# per_6_ecc_interval__    -1.85
# per_6_omega_angle__     -0.50
# per_7_ecc_interval__    -1.85
# per_7_omega_angle__     -0.50
# per_8_ecc_interval__    -1.85
# per_8_omega_angle__     -0.50
# per_9_ecc_interval__    -1.85
# per_9_omega_angle__     -0.50
# per_10_ecc_interval__   -1.85
# per_10_omega_angle__    -0.50
# per_11_ecc_interval__   -1.85
# per_11_omega_angle__    -0.50
# per_12_ecc_interval__   -1.85
# per_12_omega_angle__    -0.50
# per_13_ecc_interval__   -1.85
# per_13_omega_angle__    -0.50
# per_14_ecc_interval__   -1.85
# per_14_omega_angle__    -0.50
# per_15_ecc_interval__   -1.85
# per_15_omega_angle__    -0.50
# per_16_ecc_interval__   -1.85
# per_16_omega_angle__    -0.50
# Name: Log-probability of test_point, dtype: float64
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [per_16_omega, per_16_ecc, b, r, Rs]
# 0it [00:00, ?it/s]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 9it [00:00, 66.16it/s, logp=nan]         /Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 22it [00:20, 58.86it/s, logp=nan]         /Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 22it [00:23,  1.08s/it, logp=nan]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 4727.046855569266 -> 4746.115153133758
# optimizing logp for variables: [logs2]
# 15it [00:19,  1.32s/it, logp=1.082070e+04]
# message: Optimization terminated successfully.
# logp: 4746.115153133758 -> 10820.704306596735
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [t0_2, t0_1]
# 74it [00:00, 75.62it/s, logp=1.082207e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 87it [00:20, 76.36it/s, logp=1.082207e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 87it [00:21,  4.02it/s, logp=1.082207e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10820.704306596735 -> 10822.067504694485
# optimizing logp for variables: [logpower, logs2]
# 12it [00:20,  1.67s/it, logp=1.086748e+04]
# message: Optimization terminated successfully.
# logp: 10822.067504694485 -> 10867.484898664066
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [logw0]
# 0it [00:00, ?it/s]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 55it [00:00, 96.43it/s, logp=1.086856e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 68it [00:20, 82.54it/s, logp=1.086856e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 68it [00:21,  3.15it/s, logp=1.086856e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10867.484898664066 -> 10868.56270887288
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [u, Rs, per_16_ecc, b, r]
# 0it [00:00, ?it/s]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 30it [00:00, 74.49it/s, logp=1.091234e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 43it [00:20, 73.86it/s, logp=1.091234e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 43it [00:22,  1.93it/s, logp=1.091234e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10868.56270887288 -> 10912.342164699014
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [per_16_omega, per_16_ecc, per_15_omega, per_15_ecc, per_14_omega, per_14_ecc, per_13_omega, per_13_ecc, per_12_omega, per_12_ecc, per_11_omega, per_11_ecc, per_10_omega, per_10_ecc, per_9_omega, per_9_ecc, per_8_omega, per_8_ecc, per_7_omega, per_7_ecc, per_6_omega, per_6_ecc, per_5_omega, per_5_ecc, per_4_omega, per_4_ecc, per_3_omega, per_3_ecc, per_2_omega, per_2_ecc, per_1_omega, per_1_ecc, per_0_omega, per_0_ecc, logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs, mean]
# 0it [00:00, ?it/s]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 147it [00:02, 62.61it/s, logp=1.127477e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 159it [00:02, 62.07it/s, logp=1.127477e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 160it [00:20,  8.00it/s, logp=1.127477e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10912.342164699014 -> 11274.77244347377

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_gp_oldprior_margecc["periods"], map_soln_gp_oldprior_margecc["logprob_class"], "o-")
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-8/3 prior, eccentric orbit, marginalising eccentricity")
#plt.plot(map_soln_gp_oldprior_margecc["periods"],[map_soln_gp_oldprior_margecc['per_'+str(n)+'_log_prior'] for n in range(17)],'-o',label='log_prior')

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_gp_oldprior_margecc["per_16_light_curve"][:1000]+map_soln_gp_oldprior_margecc["per_16_gp_pred"][:1000])
plt.plot(x[:1000],map_soln_gp_oldprior_margecc["per_1_light_curve"][:1000]+map_soln_gp_oldprior_margecc["per_1_gp_pred"][:1000])
plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_gp_oldprior_margecc["per_16_light_curve"][1000:]+map_soln_gp_oldprior_margecc["per_16_gp_pred"][1000:])
plt.plot(x[1000:],map_soln_gp_oldprior_margecc["per_1_light_curve"][1000:]+map_soln_gp_oldprior_margecc["per_1_gp_pred"][1000:])

# %%
plt.plot(map_soln_gp_oldprior_margecc["periods"],[map_soln_gp_oldprior_margecc["per_"+str(n)+"_ecc"] for n in range(len(map_soln_gp_oldprior_margecc["periods"]))],'-o')
plt.plot(map_soln_gp_oldprior_margecc["periods"],[map_soln_gp_oldprior_margecc["per_"+str(n)+"_omega"] for n in range(len(map_soln_gp_oldprior_margecc["periods"]))],'-o')

# %% [markdown]
# # Updating prior to include distance during transit

# %%
with pm.Model() as gp_model_newprior_margecc:

    # The baseline flux
    mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    #Needed for eccentricity:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)

    logprobs = []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=gp_model_newprior_margecc) as submodel:
            
            period = periods[i]
            
            #Initialising eccentricity and omega *for each specific period*
            ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
            omega = xo.distributions.Angle("omega")

            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1) + mean
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred=pm.Deterministic("gp_pred", gp.predict())
            gp_preds+=[gp.predict()]
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-8/3 (occurrence rate (P^-1) * window function (P^-1) * transit probability (P^-2/3) )
            d_x,d_y,d_z = orbit.get_relative_position(t0_1) #Need this to marginalise over 1/a and not just P^-5/3
            logprior = -2 * tt.log(period)-1*tt.log(d_z)
            logprobs.append(loglike + logprior)
    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve
    pm.Deterministic("light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(gp_model_newprior_margecc.test_point)
    print(gp_model_newprior_margecc.check_test_point())
    map_soln_gp_newprior_margecc = xo.optimize(vars=[r, b])
    map_soln_gp_newprior_margecc = xo.optimize(start=map_soln_gp_newprior_margecc, vars=[logs2])
    map_soln_gp_newprior_margecc = xo.optimize(start=map_soln_gp_newprior_margecc, vars=[t0_1, t0_2])
    map_soln_gp_newprior_margecc = xo.optimize(start=map_soln_gp_newprior_margecc, vars=[logs2, logpower])
    map_soln_gp_newprior_margecc = xo.optimize(start=map_soln_gp_newprior_margecc, vars=[logw0])
    map_soln_gp_newprior_margecc = xo.optimize(start=map_soln_gp_newprior_margecc, vars=[r,b,ecc,omega,period,Rs,u])
    
    #For some reason, these causes errors at "func = get_theano_function_for_var([nlp] + grad, model=gp_model)"
    #map_soln_gp = xo.optimize(start=map_soln_gp, vars=[omega])
    map_soln_gp_newprior_margecc = xo.optimize(map_soln_gp_newprior_margecc)
# Out:
# /Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# {'mean': array(1.), 'Rs': array(1.), 'logrho_S': array(0.), 't0_1': array(105.57), 't0_2': array(205.57), 'u_quadlimbdark__': array([-1.09861229, -0.84729786]), 'r_interval__': array(0.), 'b_impact__': array(-0.59116847), 'logs2': array(-6.63860096), 'logw0_interval__': array(-0.60183699), 'logpower_interval__': array(1.18627699), 'per_0_ecc_interval__': array(-1.11022302e-16), 'per_0_omega_angle__': array([0., 1.]), 'per_1_ecc_interval__': array(-1.11022302e-16), 'per_1_omega_angle__': array([0., 1.]), 'per_2_ecc_interval__': array(-1.11022302e-16), 'per_2_omega_angle__': array([0., 1.]), 'per_3_ecc_interval__': array(-1.11022302e-16), 'per_3_omega_angle__': array([0., 1.]), 'per_4_ecc_interval__': array(-1.11022302e-16), 'per_4_omega_angle__': array([0., 1.]), 'per_5_ecc_interval__': array(-1.11022302e-16), 'per_5_omega_angle__': array([0., 1.]), 'per_6_ecc_interval__': array(-1.11022302e-16), 'per_6_omega_angle__': array([0., 1.]), 'per_7_ecc_interval__': array(-1.11022302e-16), 'per_7_omega_angle__': array([0., 1.]), 'per_8_ecc_interval__': array(-1.11022302e-16), 'per_8_omega_angle__': array([0., 1.]), 'per_9_ecc_interval__': array(-1.11022302e-16), 'per_9_omega_angle__': array([0., 1.]), 'per_10_ecc_interval__': array(-1.11022302e-16), 'per_10_omega_angle__': array([0., 1.]), 'per_11_ecc_interval__': array(-1.11022302e-16), 'per_11_omega_angle__': array([0., 1.]), 'per_12_ecc_interval__': array(-1.11022302e-16), 'per_12_omega_angle__': array([0., 1.]), 'per_13_ecc_interval__': array(-1.11022302e-16), 'per_13_omega_angle__': array([0., 1.]), 'per_14_ecc_interval__': array(-1.11022302e-16), 'per_14_omega_angle__': array([0., 1.]), 'per_15_ecc_interval__': array(-1.11022302e-16), 'per_15_omega_angle__': array([0., 1.]), 'per_16_ecc_interval__': array(-1.11022302e-16), 'per_16_omega_angle__': array([0., 1.])}
# mean                    -0.92
# Rs                       0.29
# logrho_S                -0.23
# t0_1                    -0.00
# t0_2                    -0.00
# u_quadlimbdark__        -3.23
# r_interval__            -1.39
# b_impact__              -1.47
# logs2                   -0.92
# logw0_interval__        -1.48
# logpower_interval__     -1.72
# per_0_ecc_interval__    -1.85
# per_0_omega_angle__     -0.50
# per_1_ecc_interval__    -1.85
# per_1_omega_angle__     -0.50
# per_2_ecc_interval__    -1.85
# per_2_omega_angle__     -0.50
# per_3_ecc_interval__    -1.85
# per_3_omega_angle__     -0.50
# per_4_ecc_interval__    -1.85
# per_4_omega_angle__     -0.50
# per_5_ecc_interval__    -1.85
# per_5_omega_angle__     -0.50
# per_6_ecc_interval__    -1.85
# per_6_omega_angle__     -0.50
# per_7_ecc_interval__    -1.85
# per_7_omega_angle__     -0.50
# per_8_ecc_interval__    -1.85
# per_8_omega_angle__     -0.50
# per_9_ecc_interval__    -1.85
# per_9_omega_angle__     -0.50
# per_10_ecc_interval__   -1.85
# per_10_omega_angle__    -0.50
# per_11_ecc_interval__   -1.85
# per_11_omega_angle__    -0.50
# per_12_ecc_interval__   -1.85
# per_12_omega_angle__    -0.50
# per_13_ecc_interval__   -1.85
# per_13_omega_angle__    -0.50
# per_14_ecc_interval__   -1.85
# per_14_omega_angle__    -0.50
# per_15_ecc_interval__   -1.85
# per_15_omega_angle__    -0.50
# per_16_ecc_interval__   -1.85
# per_16_omega_angle__    -0.50
# Name: Log-probability of test_point, dtype: float64
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [per_16_omega, per_16_ecc, b, r, Rs]
# 0it [00:00, ?it/s]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 61it [00:18,  3.25it/s, logp=4.749943e+03]
# message: Optimization terminated successfully.
# logp: 4725.898124622477 -> 4749.942811517919
# optimizing logp for variables: [logs2]
# 13it [00:19,  1.50s/it, logp=1.074982e+04]
# message: Optimization terminated successfully.
# logp: 4749.942811517919 -> 10749.82354851381
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [t0_2, t0_1]
# 0it [00:00, ?it/s]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 14it [00:18,  1.29s/it, logp=1.075118e+04]
# message: Optimization terminated successfully.
# logp: 10749.82354851381 -> 10751.177351256198
# optimizing logp for variables: [logpower, logs2]
# 9it [00:19,  2.22s/it, logp=1.075138e+04]
# message: Optimization terminated successfully.
# logp: 10751.177351256198 -> 10751.383341648443
# optimizing logp for variables: [logw0]
# 13it [00:17,  1.37s/it, logp=1.076515e+04]
# message: Optimization terminated successfully.
# logp: 10751.383341648443 -> 10765.147774188956
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [u, Rs, per_16_ecc, b, r]
# 0it [00:00, ?it/s]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 26it [00:15,  1.66it/s, logp=1.086437e+04]
# message: Optimization terminated successfully.
# logp: 10765.147774188956 -> 10864.369512783827
# INFO (theano.gof.compilelock): Refreshing lock /Users/hosborn/.theano/compiledir_Darwin-19.0.0-x86_64-i386-64bit-i386-3.7.4-64/lock_dir/lock
# optimizing logp for variables: [per_16_omega, per_16_ecc, per_15_omega, per_15_ecc, per_14_omega, per_14_ecc, per_13_omega, per_13_ecc, per_12_omega, per_12_ecc, per_11_omega, per_11_ecc, per_10_omega, per_10_ecc, per_9_omega, per_9_ecc, per_8_omega, per_8_ecc, per_7_omega, per_7_ecc, per_6_omega, per_6_ecc, per_5_omega, per_5_ecc, per_4_omega, per_4_ecc, per_3_omega, per_3_ecc, per_2_omega, per_2_ecc, per_1_omega, per_1_ecc, per_0_omega, per_0_ecc, logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs, mean]
# 0it [00:00, ?it/s]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 175it [00:02, 63.82it/s, logp=1.127445e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 188it [00:20, 62.69it/s, logp=1.127445e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 188it [00:22,  8.22it/s, logp=1.127445e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10864.369512783827 -> 11274.447652690938

# %%
plt.figure(figsize=(15,12))
plt.subplot(311)
plt.plot(map_soln_gp_newprior_margecc["periods"], map_soln_gp_newprior_margecc["logprob_class"], "o-")
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-2 d_z^-1 prior, eccentric orbit, marginalising eccentricity")
#plt.plot(map_soln_gp_oldprior_margecc["periods"],[map_soln_gp_oldprior_margecc['per_'+str(n)+'_log_prior'] for n in range(17)],'-o',label='log_prior')

plt.subplot(312)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],map_soln_gp_newprior_margecc["per_16_light_curve"][:1000]+map_soln_gp_newprior_margecc["per_16_gp_pred"][:1000])
plt.plot(x[:1000],map_soln_gp_newprior_margecc["per_5_light_curve"][:1000]+map_soln_gp_newprior_margecc["per_5_gp_pred"][:1000])
plt.subplot(313)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],map_soln_gp_newprior_margecc["per_16_light_curve"][1000:]+map_soln_gp_newprior_margecc["per_16_gp_pred"][1000:])
plt.plot(x[1000:],map_soln_gp_newprior_margecc["per_5_light_curve"][1000:]+map_soln_gp_newprior_margecc["per_5_gp_pred"][1000:])

# %%
plt.plot(map_soln_gp_newprior_margecc["periods"], map_soln_gp_newprior_margecc["logprob_class"], "o-")
plt.plot(map_soln_gp_newprior_margecc["periods"], map_soln_gp_newprior_margecc["logprob_class"], "o-")

# %%
plt.plot(map_soln_gp_newprior_margecc["periods"],[map_soln_gp_newprior_margecc['per_'+str(n)+'_ecc'] for n in range(17)],'-o',label='ecc')
plt.plot(map_soln_gp_newprior_margecc["periods"],[map_soln_gp_newprior_margecc['per_'+str(n)+'_omega'] for n in range(17)],'-o',label='omega')
plt.legend()

# %%
np.random.seed(42)
with gp_model_newprior_margecc:
    gp_trace_newprior_margecc = pm.sample(
        tune=200,
        draws=500,
        start=map_soln_gp_newprior_margecc,
        chains=4,
        step=xo.get_dense_nuts_step(target_accept=0.9),
    )
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [per_16_omega, per_16_ecc, per_15_omega, per_15_ecc, per_14_omega, per_14_ecc, per_13_omega, per_13_ecc, per_12_omega, per_12_ecc, per_11_omega, per_11_ecc, per_10_omega, per_10_ecc, per_9_omega, per_9_ecc, per_8_omega, per_8_ecc, per_7_omega, per_7_ecc, per_6_omega, per_6_ecc, per_5_omega, per_5_ecc, per_4_omega, per_4_ecc, per_3_omega, per_3_ecc, per_2_omega, per_2_ecc, per_1_omega, per_1_ecc, per_0_omega, per_0_ecc, logpower, logw0, logs2, b, r, u, t0_2, t0_1, logrho_S, Rs, mean]
# Sampling 4 chains:  20%|█▉        | 551/2800 [08:59<36:40,  1.02draws/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, **kwargs)
#     968             with sampler:
# --> 969                 for draw in sampler:
#     970                     trace = traces[draw.chain - chain]
#
# ~/anaconda3/lib/python3.7/site-packages/pymc3/parallel_sampling.py in __iter__(self)
#     392         while self._active:
# --> 393             draw = ProcessAdapter.recv_draw(self._active)
#     394             proc, is_last, draw, tuning, stats, warns = draw
#
# ~/anaconda3/lib/python3.7/site-packages/pymc3/parallel_sampling.py in recv_draw(processes, timeout)
#     283         pipes = [proc._msg_pipe for proc in processes]
# --> 284         ready = multiprocessing.connection.wait(pipes)
#     285         if not ready:
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     919             while True:
# --> 920                 ready = selector.select(timeout)
#     921                 if ready:
#
# ~/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-f18a94c63afd> in <module>
#       6         start=map_soln_gp_newprior_margecc,
#       7         chains=4,
# ----> 8         step=xo.get_dense_nuts_step(target_accept=0.9),
#       9     )
#
# ~/anaconda3/lib/python3.7/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, **kwargs)
#     435             _print_step_hierarchy(step)
#     436             try:
# --> 437                 trace = _mp_sample(**sample_args)
#     438             except pickle.PickleError:
#     439                 _log.warning("Could not pickle model, sampling singlethreaded.")
#
# ~/anaconda3/lib/python3.7/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, **kwargs)
#     989         return MultiTrace(traces)
#     990     except KeyboardInterrupt:
# --> 991         traces, length = _choose_chains(traces, tune)
#     992         return MultiTrace(traces)[:length]
#     993     finally:
#
# ~/anaconda3/lib/python3.7/site-packages/pymc3/sampling.py in _choose_chains(traces, tune)
#    1005     lengths = [max(0, len(trace) - tune) for trace in traces]
#    1006     if not sum(lengths):
# -> 1007         raise ValueError('Not enough samples to build a trace.')
#    1008
#    1009     idxs = np.argsort(lengths)[::-1]
#
# ValueError: Not enough samples to build a trace.

# %%
gp_trace_oldprior["per_1_light_curve"][:,1000:]+gp_trace_oldprior["per_1_gp_pred"][:,1000:]
# Out:
# array([[0.99799233, 0.9979933 , 0.99799428, ..., 0.99836014, 0.99836009,
#         0.99836005],
#        [0.99795696, 0.99795828, 0.99795961, ..., 0.99833467, 0.99833432,
#         0.99833397],
#        [0.99798533, 0.9979864 , 0.99798747, ..., 0.99834406, 0.99834383,
#         0.9983436 ],
#        ...,
#        [0.99796446, 0.99796556, 0.99796666, ..., 0.99830425, 0.99830372,
#         0.9983032 ],
#        [0.99793646, 0.99793791, 0.99793937, ..., 0.99831815, 0.99831774,
#         0.99831733],
#        [0.997965  , 0.99796601, 0.99796703, ..., 0.99832188, 0.99832165,
#         0.99832141]])

# %%
plt.figure(figsize=(15,10))
plt.subplot(211)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],np.median(gp_trace_oldprior["per_16_light_curve"][:,:1000]+gp_trace_oldprior["per_16_gp_pred"][:,:1000],axis=0))
plt.plot(x[:1000],np.median(gp_trace_oldprior["per_1_light_curve"][:,:1000]+gp_trace_oldprior["per_1_gp_pred"][:,:1000],axis=0))
plt.subplot(212)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],np.median(gp_trace_oldprior["per_16_light_curve"][:,1000:]+gp_trace_oldprior["per_16_gp_pred"][:,1000:],axis=0))
plt.plot(x[1000:],np.median(gp_trace_oldprior["per_1_light_curve"][:,1000:]+gp_trace_oldprior["per_1_gp_pred"][:,1000:],axis=0))

# %%
plt.hist(period_samps, 100, weights=weight_samps, density=True, range=(99.95, 100.05), histtype="step")
plt.xlabel("period")
plt.ylabel("p(period)");

# %% [markdown]
# ## With the new prior ($P^{-2} a_z^{-1}$), this fails:

# %%
with pm.Model() as gp_model:

    # The baseline flux
    mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    #Initialising eccentricity and omega:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)
    ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
    omega = xo.distributions.Angle("omega")
    
    logprobs = []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=gp_model) as submodel:
            
            period = periods[i]
            
            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1) + mean
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred=pm.Deterministic("gp_pred", gp.predict())
            gp_preds+=[gp.predict()]
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-2 (occurrence rate (P^-1) * window function (P^-1) * transit probability (z^-1) )
            d_x,d_y,d_z = orbit.get_relative_position(t0_1) #Need this to marginalise over 1/a and not just P^-5/3
            logprior = -2*tt.log(period)+-1*tt.sum(tt.log(d_z)
            logprobs.append(loglike + logprior)
            log_prior=pm.Deterministic("log_prior", logprior)
    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve
    pm.Deterministic("light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(gp_model.test_point)
    print(gp_model.check_test_point())
    map_soln_gp = xo.optimize(vars=[r, b, ecc])
    map_soln_gp = xo.optimize(start=map_soln_gp, vars=[logs2])
    map_soln_gp = xo.optimize(start=map_soln_gp, vars=[t0_1, t0_2])
    map_soln_gp = xo.optimize(start=map_soln_gp, vars=[logs2, logpower])
    map_soln_gp = xo.optimize(start=map_soln_gp, vars=[logw0])
    map_soln_gp = xo.optimize(start=map_soln_gp, vars=[r,b,ecc,Rs,u])
    
    #For some reason, these causes errors at "func = get_theano_function_for_var([nlp] + grad, model=gp_model)"
    #map_soln_gp = xo.optimize(start=map_soln_gp, vars=[omega])
    #map_soln_gp = xo.optimize(map_soln_gp)
# Out:
# {'mean': array(1.), 'Rs': array(1.), 'logrho_S': array(0.), 't0_1': array(105.57), 't0_2': array(205.57), 'u_quadlimbdark__': array([-1.09861229, -0.84729786]), 'r_interval__': array(0.), 'b_impact__': array(-0.59116847), 'logs2': array(-6.63860096), 'logw0_interval__': array(-0.60183699), 'logpower_interval__': array(1.18627699), 'ecc_interval__': array(-1.11022302e-16), 'omega_angle__': array([0., 1.])}
# mean                  -0.92
# Rs                     0.29
# logrho_S              -0.23
# t0_1                  -0.00
# t0_2                  -0.00
# u_quadlimbdark__      -3.23
# r_interval__          -1.39
# b_impact__            -1.47
# logs2                 -0.92
# logw0_interval__      -1.48
# logpower_interval__   -1.72
# ecc_interval__        -1.85
# omega_angle__         -0.50
# Name: Log-probability of test_point, dtype: float64
# optimizing logp for variables: [ecc, b, r, Rs]
# 14it [00:18,  1.34s/it, logp=4.766874e+03]
# message: Optimization terminated successfully.
# logp: 4763.508971814892 -> 4766.874278574631
# optimizing logp for variables: [logs2]
# 13it [00:19,  1.53s/it, logp=1.077567e+04]
# message: Optimization terminated successfully.
# logp: 4766.874278574631 -> 10775.673372388188
# optimizing logp for variables: [t0_2, t0_1]
# 17it [00:18,  1.11s/it, logp=1.077793e+04]
# message: Optimization terminated successfully.
# logp: 10775.673372388188 -> 10777.93063807828
# optimizing logp for variables: [logpower, logs2]
# 77it [00:00, 111.15it/s, logp=1.077796e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 90it [00:14, 109.99it/s, logp=1.077796e+04]/Users/hosborn/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# 90it [00:21,  4.11it/s, logp=1.077796e+04]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10777.93063807828 -> 10777.957254939909
# optimizing logp for variables: [logw0]
# 14it [00:22,  1.58s/it, logp=1.079344e+04]
# message: Optimization terminated successfully.
# logp: 10777.957254939909 -> 10793.444955404737
# optimizing logp for variables: [u, Rs, ecc, b, r]
# 27it [00:17,  1.57it/s, logp=1.087798e+04]
# message: Optimization terminated successfully.
# logp: 10793.444955404737 -> 10877.976201935984

# %%
plt.plot(map_soln_gp["periods"], map_soln_gp["logprob_class"], "o-")
plt.xlabel("period")
plt.ylabel("log(prob)")
plt.title("Optimized GP model period probability, with P^-2 a_z^-1 prior")
# Out:
# Text(0.5, 1.0, 'Optimized GP model period probability')

# %%
plt.plot(map_soln_gp_circ["periods"],[map_soln_gp_circ['per_'+str(n)+'_log_prior'] for n in range(17)],'-o',label='log_prior')

# %% [markdown]
# #### This look a bit dodgy because it failed to globally optimise all parameters:

# %%
plt.hist(period_samps, 100, weights=weight_samps, density=True, range=(49.95, 50.05), histtype="step")
plt.xlabel("period")
plt.ylabel("p(period)");

# %%
plt.hist(period_samps, 100, weights=weight_samps, density=True, range=(100 / 3.0 - 0.05, 100 / 3.0 + 0.05), histtype="step")
plt.xlabel("period")
plt.ylabel("p(period)");

# %%
plt.figure(figsize=(15,10))
plt.subplot(211)
plt.plot(x[:1000],y[:1000],'.')
plt.plot(x[:1000],np.nanmedian(trace["per_2_light_curve"],axis=0)[:1000]+np.nanmedian(trace["per_2_gp_pred"],axis=0)[:1000])
plt.plot(x[:1000],np.nanmedian(trace["per_1_light_curve"],axis=0)[:1000]+np.nanmedian(trace["per_1_gp_pred"],axis=0)[:1000])
plt.subplot(212)
plt.plot(x[1000:],y[1000:],'.')
plt.plot(x[1000:],np.nanmedian(trace["per_2_light_curve"],axis=0)[1000:]+np.nanmedian(trace["per_2_gp_pred"],axis=0)[1000:])
plt.plot(x[1000:],np.nanmedian(trace["per_1_light_curve"],axis=0)[1000:]+np.nanmedian(trace["per_1_gp_pred"],axis=0)[1000:])

# %%
with pm.Model() as model:

    # The baseline flux
    mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.1)
    b = xo.distributions.ImpactParameter("b", ror=r/Rs, testval=0.41)

    periods = pm.Deterministic("periods", t0_2 - t0_1 / period_index)

    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    
    logw0_guess = np.log(2*np.pi/10)

    lcrange=x[-1]-x[0]

    #freqs bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))

    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)
    ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
    omega = xo.distributions.Angle("omega")
    
    logprobs = []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=model) as submodel:
            
            period = periods[i]
            
            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            vx, vy, vz = orbit.get_relative_velocity(t0_1)
            _, _, z = orbit.get_relative_position #Need this to marginalise over 1/a and not just P^-5/3
            Rs=1
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1) + mean
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred=pm.Deterministic("gp_pred", gp.predict())
            gp_preds+=[gp.predict()]
            
            all_lcs.append(lc)

            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            #Here we'll use P^-2 (occurrence rate (P^-1) * window function (P^-1) * transit probability (z^-1) )
            logprior = -2*tt.log(period) + -1*z
            logprobs.append(loglike + logprior)
    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve
    pm.Deterministic("light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
        
    print(model.test_point)
    print(model.check_test_point())
    map_soln_newprior = xo.optimize(vars=[r, b])
    map_soln_newprior = xo.optimize(start=map_soln, vars=[logs2])
    map_soln = xo.optimize(start=map_soln, vars=[t0_1, t0_2])
    map_soln = xo.optimize(start=map_soln, vars=[logs2, logpower])
    map_soln = xo.optimize(start=map_soln, vars=[logw0])
    map_soln = xo.optimize(map_soln)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-45e93be229ec> in <module>
#      60                     ecc=ecc,omega=omega)
#      61             vx, vy, vz = orbit.get_relative_velocity(t0_1)
# ---> 62             _, _, z = orbit.get_relative_position #Need this to marginalise over 1/a and not just P^-5/3
#      63             Rs=1
#      64             vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
#
# TypeError: cannot unpack non-iterable method object

# %%
'''

with pm.Model() as gp_model_oldprior:

    # The baseline flux
    #mean = pm.Normal("mean", mu=1.0, sd=1.0)

    Rs = pm.Normal("Rs", mu=1.0, sd=0.3)
    logrho_S = pm.Normal("logrho_S", mu=0.0, sd=0.5)
    rho_S = pm.Deterministic("rho_S",tt.exp(logrho_S))
             
    # The time of a reference time for each transit
    t0_1 = pm.Normal("t0_1", mu=t0s[0], sd=0.4)
    t0_2 = pm.Normal("t0_2", mu=t0s[1], sd=0.4)

    # The Kipping (2013) parameterization for quadratic limb darkening paramters
    u = xo.distributions.QuadLimbDark("u", testval=np.array([0.3, 0.2]))

    r = pm.Uniform("r", lower=0.001, upper=0.3)
    ror=pm.Deterministic("ror", r/Rs)
    b = xo.distributions.ImpactParameter("b", ror=ror, testval=0.41)

    periods = pm.Deterministic("periods", (t0_2 - t0_1)/period_index)
    
    #Jitter term. Initialised with the std of y
    logs2 = pm.Normal("logs2", mu=np.log(np.std(y)),sd=1.0,testval=np.log(np.std(y)))
    
    #Guess P_var=10d to begin:
    logw0_guess = np.log(2*np.pi/10)

    #freq bounded from 2pi/minimum_cadence to to 2pi/(4x lc length)
    min_cad=np.nanmedian(np.diff(x))#Limiting to <1 cadence
    lcrange=x[-1]-x[0]
    logw0 = pm.Uniform("logw0",lower=np.log((2*np.pi)/(4*lcrange)), 
                       upper=np.log((2*np.pi)/min_cad),testval=logw0_guess)

    # S_0 directly because this removes some of the degeneracies between
    # S_0 and omega_0 prior=(-0.25*lclen)*exp(logS0)
    logpower = pm.Uniform("logpower",lower=-20,upper=np.log(np.nanmedian(abs(np.diff(y)))),testval=-10)
    logS0 = pm.Deterministic("logS0", logpower - 4 * logw0)

    # Initialising GP model for the light curve
    kernel = xo.gp.terms.SHOTerm(log_S0=logS0, log_w0=logw0, Q=1/np.sqrt(2))
    gp = xo.gp.GP(kernel, x, tt.exp(logs2) + tt.zeros(len(x)), J=2)
    
    #Initialising eccentricity and omega:
    BoundedBeta = pm.Bound(pm.Beta, lower=1e-5, upper=1-1e-5)
    ecc = BoundedBeta("ecc", alpha=0.867, beta=3.03)
    omega = xo.distributions.Angle("omega")
    
    logprobs = []
    all_lcs = []
    gp_preds = []
    for i, index in enumerate(period_index):

        with pm.Model(name="per_{0}".format(i), model=gp_model_oldprior) as submodel:
            
            period = periods[i]
            
            # Set up a Keplerian orbit for the planets
            orbit = xo.orbits.KeplerianOrbit(
                    period=period, t0=t0_1, b=b,
                    ecc=ecc,omega=omega)
            
            #Adding deterministic tdur
            vx, vy, vz = orbit.get_relative_velocity(t0_1) #To calculate Tdur
            vrel=pm.Deterministic("vrel",tt.sqrt(vx**2 + vy**2)/Rs)
            tdur=pm.Deterministic("tdur",(2*tt.sqrt(1-b**2))/vrel)

            # Compute the model light curve using starry
            light_curves = xo.LimbDarkLightCurve(u).get_light_curve(orbit=orbit, r=r, t=x)
            lc=pm.math.sum(light_curves, axis=-1) + mean
            light_curve = pm.Deterministic("light_curve",lc) 
            
            # Compute the log prob
            #loglike = tt.sum(pm.Normal.dist(mu=light_curve, sd=yerr).logp(y))
            loglike = tt.sum(gp.log_likelihood(y - light_curve))
            gp_pred=pm.Deterministic("gp_pred", gp.predict())
            gp_preds+=[gp.predict()]
            
            all_lcs.append(lc)

            #Computing log prior.
            #Here we'll use P^-8/3 (occurrence rate (P^-1) * window function (P^-1) * transit probability (P^-2/3) )
            logprior = -8 * tt.log(period) / 3
            logprobs.append(loglike + logprior)
    
    # Compute the marginalized probability and the posterior probability for each period
    logprobs = tt.stack(logprobs)
    logprob_marg = pm.math.logsumexp(logprobs)
    logprob_class = pm.Deterministic("logprob_class", logprobs - logprob_marg)
    
    gp_preds_all = tt.stack(gp_preds)
    
    pm.Potential("logprob", logprob_marg)
    
    # Compute the marginalized light curve
    pm.Deterministic("light_curve", tt.sum(tt.stack(all_lcs) * tt.exp(logprob_class)[:, None], axis=0))
    
    #Optimising:
    print(gp_model_oldprior.test_point)
    print(gp_model_oldprior.check_test_point())
    map_soln_gp_oldprior = xo.optimize(vars=[r, b, ecc,omega])
    map_soln_gp_oldprior = xo.optimize(start=map_soln_gp, vars=[logs2])
    map_soln_gp_oldprior = xo.optimize(start=map_soln_gp, vars=[t0_1, t0_2])
    map_soln_gp_oldprior = xo.optimize(start=map_soln_gp, vars=[logs2, logpower])
    map_soln_gp_oldprior = xo.optimize(start=map_soln_gp, vars=[logw0])
    map_soln_gp_oldprior = xo.optimize(start=map_soln_gp, vars=[r,b,ecc,Rs,u])
    
    #For some reason, these causes errors at "func = get_theano_function_for_var([nlp] + grad, model=gp_model)"
    #map_soln_gp = xo.optimize(start=map_soln_gp, vars=[omega])
    map_soln_gp = xo.optimize(map_soln_gp)
    '''
