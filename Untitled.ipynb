# %%
# %load_ext autoreload
# %autoreload 2
import pickle
from MonoTools import MonoSearch as mono
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Traceback (most recent call last):
#
#   File "/Users/hosborn/transits/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-0adad81802cf>", line 4, in <module>
#     from MonoTools import MonoSearch as mono
#
#   File "/Users/hosborn/Postdoc/MonoTools/MonoTools/MonoSearch.py", line 57, in <module>
#     from . import MonoFit
#
#   File "/Users/hosborn/Postdoc/MonoTools/MonoTools/MonoFit.py", line 59
#     if MonoData_savepath=="/Users/hosborn/python/MonoToolsData" or MonoData_savepath=="/Volumes/LUVOIR/MonoToolsData:
#                                                                                                                      ^
# ...

# %%
mod=pickle.load(open("/Users/hosborn/python/MonoToolsData/TIC00207425167/TIC00207425167_model.pickle","rb"))

# %%
from MonoTools import tools
lc,h=tools.openLightCurve(207425167,'tess')
# Out:
# https://heasarc.gsfc.nasa.gov/cgi-bin/tess/webtess/wtv.py?Entry=<SkyCoord (ICRS): (ra, dec) in deg
#     (242.747875, 58.29455278)>
# [15, 16, 22, 23, 24] <class 'list'>
# TESS file
# 2343 points masked in lc of 19579
# TESS file
# 5481 points masked in lc of 19279
# # Loading QLP lightcurves
# 207425167 <class 'int'>
# 3 points masked in lc of 599
# 6 points masked in lc of 562
# 6 points masked in lc of 559
# 2 points masked in lc of 624
# 4 points masked in lc of 598
# 0 points masked in lc of 602
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(lc['time'][lc['mask']],lc['flux'][lc['mask']],'.')

# %%
mod.PlotPeriods(log=True,pmax=500)
# Out:
# probs?
# 7.280413063217628e-26

# %%
for ngap in range(len(mod.planets['00']['per_gaps'])):
    plt.scatter(mod.trace['mono_periods_00'][:,ngap],mod.trace['logprob_marg_00'][:,ngap],s=1,alpha=0.4)
#plt.xscale('log')
plt.xlim(0,500)
#plt.ylim(-0.01,0.01)
# Out:
# (0.0, 500.0)

# %%
mod.trace.varnames
# Out:
# ['logrho_S',
#  'Rs',
#  'mono_uniform_index_00_logodds__',
#  'mono_t0s_00_interval__',
#  'mono_logrors_00_interval__',
#  'mono_bs_00_impact__',
#  'mono_eccs_00_interval__',
#  'mono_omegas_00_angle__',
#  'multi_periods',
#  'multi_t0s_interval__',
#  'multi_logrors_interval__',
#  'multi_bs_impact__',
#  'multi_eccs_interval__',
#  'multi_omegas_angle__',
#  'u_star_tess_interval__',
#  'mean',
#  'logs2',
#  'w0_interval__',
#  'power_interval__',
#  'rho_S',
#  'Ms',
#  'mono_uniform_index_00',
#  'mono_periods_00',
#  'mono_t0s_00',
#  'mono_logrors_00',
#  'mono_bs_00',
#  'mono_eccs_00',
#  'mono_omegas_00',
#  'multi_t0s',
#  'multi_logrors',
#  'multi_bs',
#  'multi_eccs',
#  'multi_omegas',
#  'u_star_tess',
#  'w0',
#  'power',
#  'S0',
#  'multi_mask_light_curves',
#  'multi_tdurs',
#  'mono_tdurs_00',
#  'mono_priors_00',
#  'mono_liks_00',
#  'logprob_marg_00',
#  'period_marg_00',
#  'tdur_marg_00',
#  'marg_light_curve_00',
#  'marg_all_light_curve',
#  'llk_gp',
# ...

# %%
mod.PlotPeriods(log=True,pmax=400,nbins=50)

# %%
from scipy import special
total_prob=special.logsumexp(mod.trace['logprob_marg_00'].ravel())

# %%
import seaborn as sns
import numpy as np
ngap=3
pl='00'
weights = np.exp(mod.trace['logprob_marg_00'][:,ngap]-total_prob)
plt.hist(mod.trace['mono_periods_'+pl][:,ngap],bins=20,weights=weights,color=sns.color_palette()[0],
         edgecolor=sns.color_palette()[0],histtype="stepfilled")
#sns.distplot(mod.trace["mono_periods_00"][:,ngap], hist=True, kde=True,norm_hist=False,
#             hist_kws={'edgecolor':'None','log':True, 'weights':weights},
#             kde_kws={'weights':weights,'clip':mod.planets['00']['per_gaps'][ngap,:2]})
plt.xlim(0,300)
plt.ylim(1e-5,500.0)
plt.yscale('log')

# %%
import seaborn as sns
import numpy as np
ngap=3
weights = np.exp(mod.trace['logprob_marg_00'][:,ngap]-total_prob)
plt.hist(mod.trace['mono_periods_'+pl][:,ngap],bins=20,weights=weights,color=sns.color_palette()[0])
#sns.distplot(mod.trace["mono_periods_00"][:,ngap], hist=True, kde=True,norm_hist=False,
#             hist_kws={'edgecolor':'None','log':True, 'weights':weights},
#             kde_kws={'weights':weights,'clip':mod.planets['00']['per_gaps'][ngap,:2]})
#plt.xlim(60,80)
plt.yscale('log')
plt.ylim(1e-5,500.0)
# Out:
# (1e-05, 500.0)

# %%
import os
os.environ['MONOTOOLSPATH'] = "/Volumes/LUVOIR/MonoToolsData"
# %load_ext autoreload
# %autoreload 2
import pickle
from MonoTools import MonoSearch as mono
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
outs=mono.MonoVetting(207425167,overwrite='multis,vet',mission='tess',use_GP=False,do_fit=False)
# Out:
# multis,vet {'starpars': False, 'lc': False, 'monos': False, 'multis': True, 'vet': True, 'fit': True, 'model_plots': True}
# /Volumes/LUVOIR/MonoToolsData/TIC00207425167 {'use_GP': False}
# loading from  /Volumes/LUVOIR/MonoToolsData/TIC00207425167/TIC00207425167_starpars.csv
# [0.738692, 0.0615643, 0.04429] [5059.36, 130.356, 162.105] [4.62542, 0.0771543, 0.121136] [2.092533917727483, 0.014755875724249846, 0.01309839676471445]
# Using TLS on ID=207425167 to search for multi-transiting planets
# transit mask: <class 'numpy.ndarray'> 40939 1 <class 'numpy.ndarray'> 40939 True
# after flattening: 34557
# Transit Least Squares TLS 1.0.24 (21 November 2019)
# Creating model cache for 63 durations
# Searching 5659 data points, 23837 periods from 1.1 to 82.912 days
# Using 1 of 12 CPU threads
# 0.0002593764945967754 0.15 39.76062396688645 [39.025356 39.028625 39.04619  39.04946  39.06702  39.0696   39.087852
#  39.09043  39.10869  39.11196  39.12952  39.132793 39.150352 39.153625
# ...

# %%
outs=mono.MonoVetting(207425167,mission='tess',use_GP=False)
# Out:
# /Volumes/LUVOIR/MonoToolsData/TIC00207425167 {'use_GP': False}
# loading from  /Volumes/LUVOIR/MonoToolsData/TIC00207425167/TIC00207425167_starpars.csv
# [0.738692, 0.0615643, 0.04429] [5059.36, 130.356, 162.105] [4.62542, 0.0771543, 0.121136] [2.092533917727483, 0.014755875724249846, 0.01309839676471445]
# ...
