# %%
# %load_ext autoreload
# %autoreload 2
import pickle
from MonoTools import MonoSearch as mono
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
mod=pickle.load(open("/Users/hosborn/python/MonoToolsData/TIC00207425167/TIC00207425167_model.pickle","rb"))

# %%
from MonoTools import tools
lc,h=tools.openLightCurve(207425167,'tess')
# Out:
# https://heasarc.gsfc.nasa.gov/cgi-bin/tess/webtess/wtv.py?Entry=<SkyCoord (ICRS): (ra, dec) in deg
#     (242.747875, 58.29455278)>
# [15, 16, 22, 23, 24] <class 'list'>
# TESS file
# 2343 points masked in lc of 19579
# TESS file
# 5481 points masked in lc of 19279
# # Loading QLP lightcurves
# 207425167 <class 'int'>
# 3 points masked in lc of 599
# 6 points masked in lc of 562
# 6 points masked in lc of 559
# 2 points masked in lc of 624
# 4 points masked in lc of 598
# 0 points masked in lc of 602
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(lc['time'][lc['mask']],lc['flux'][lc['mask']],'.')

# %%
mod.PlotPeriods(log=True,pmax=500)
# Out:
# probs?
# 7.280413063217628e-26

# %%
for ngap in range(len(mod.planets['00']['per_gaps'])):
    plt.scatter(mod.trace['mono_periods_00'][:,ngap],mod.trace['logprob_marg_00'][:,ngap],s=1,alpha=0.4)
#plt.xscale('log')
plt.xlim(0,500)
#plt.ylim(-0.01,0.01)
# Out:
# (0.0, 500.0)

# %%
mod.trace.varnames
# Out:
# ['logrho_S',
#  'Rs',
#  'mono_uniform_index_00_logodds__',
#  'mono_t0s_00_interval__',
#  'mono_logrors_00_interval__',
#  'mono_bs_00_impact__',
#  'mono_eccs_00_interval__',
#  'mono_omegas_00_angle__',
#  'multi_periods',
#  'multi_t0s_interval__',
#  'multi_logrors_interval__',
#  'multi_bs_impact__',
#  'multi_eccs_interval__',
#  'multi_omegas_angle__',
#  'u_star_tess_interval__',
#  'mean',
#  'logs2',
#  'w0_interval__',
#  'power_interval__',
#  'rho_S',
#  'Ms',
#  'mono_uniform_index_00',
#  'mono_periods_00',
#  'mono_t0s_00',
#  'mono_logrors_00',
#  'mono_bs_00',
#  'mono_eccs_00',
#  'mono_omegas_00',
#  'multi_t0s',
#  'multi_logrors',
#  'multi_bs',
#  'multi_eccs',
#  'multi_omegas',
#  'u_star_tess',
#  'w0',
#  'power',
#  'S0',
#  'multi_mask_light_curves',
#  'multi_tdurs',
#  'mono_tdurs_00',
#  'mono_priors_00',
#  'mono_liks_00',
#  'logprob_marg_00',
#  'period_marg_00',
#  'tdur_marg_00',
#  'marg_light_curve_00',
#  'marg_all_light_curve',
#  'llk_gp',
#  'gp_pred']

# %%
mod.PlotPeriods(log=True,pmax=400,nbins=50)

# %%
from scipy import special
total_prob=special.logsumexp(mod.trace['logprob_marg_00'].ravel())

# %%
import seaborn as sns
import numpy as np
ngap=3
pl='00'
weights = np.exp(mod.trace['logprob_marg_00'][:,ngap]-total_prob)
plt.hist(mod.trace['mono_periods_'+pl][:,ngap],bins=20,weights=weights,color=sns.color_palette()[0],
         edgecolor=sns.color_palette()[0],histtype="stepfilled")
#sns.distplot(mod.trace["mono_periods_00"][:,ngap], hist=True, kde=True,norm_hist=False,
#             hist_kws={'edgecolor':'None','log':True, 'weights':weights},
#             kde_kws={'weights':weights,'clip':mod.planets['00']['per_gaps'][ngap,:2]})
plt.xlim(0,300)
plt.ylim(1e-5,500.0)
plt.yscale('log')

# %%
import seaborn as sns
import numpy as np
ngap=3
weights = np.exp(mod.trace['logprob_marg_00'][:,ngap]-total_prob)
plt.hist(mod.trace['mono_periods_'+pl][:,ngap],bins=20,weights=weights,color=sns.color_palette()[0])
#sns.distplot(mod.trace["mono_periods_00"][:,ngap], hist=True, kde=True,norm_hist=False,
#             hist_kws={'edgecolor':'None','log':True, 'weights':weights},
#             kde_kws={'weights':weights,'clip':mod.planets['00']['per_gaps'][ngap,:2]})
#plt.xlim(60,80)
plt.yscale('log')
plt.ylim(1e-5,500.0)
# Out:
# (1e-05, 500.0)

# %%
outs=mono.MonoVetting(281731203,mission='tess')
# Out:
# /Users/hosborn/python/MonoToolsData/TIC00281731203 {}
# loading from  /Users/hosborn/python/MonoToolsData/TIC00281731203/TIC00281731203_starpars.csv
# [1.73497, 0.0747598, 0.108677] [5466.0, 116.472, 134.701] [3.94175, 0.0901541, 0.0710911] [0.13084164941120996, 0.0008860574553592894, 0.0008966164427714012]
# {'00': {'tcen': 1546.6834988467456, 'depth': 0.0034445729534320346, 'period': 8.927854933004202, 'orbit_flag': 'FP - Confusion with 01', 'flag': 'FP - confusion'}, '01': {'tcen': 1558.3169368428514, 'depth': 0.003387301233591481, 'period': 11.63343799610584, 'orbit_flag': 'duo', 'flag': 'planet'}}
# {'00': {'tcen': 1546.6834988467456, 'depth': 0.0034445729534320346, 'period': 8.927854933004202, 'orbit_flag': 'FP - Confusion with 01', 'flag': 'FP - confusion'}, '01': {'tcen': 1558.3169368428514, 'depth': 0.003387301233591481, 'period': 11.63343799610584, 'orbit_flag': 'duo', 'flag': 'planet'}}
# Planets to model: ['01']
# ['/Users/hosborn/python/MonoToolsData/TIC00281731203/TIC00281731203_2020-07-07_0', '/Users/hosborn/python/MonoToolsData/TIC00281731203/TIC00281731203'] False
# ['/Users/hosborn/python/MonoToolsData/TIC00281731203/TIC00281731203_2020-07-07_0', '/Users/hosborn/python/MonoToolsData/TIC00281731203/TIC00281731203'] False
# LOADED MCMC
# 1 planets | monos: [] multis: ['01'] duos: [] use GP= True
# extramask with n= 14523
# flux_flat 3701 3701
# flux_err 3701 3701
# flux 3701 3701
# cadence 3701 3701
# mask 3701 3701
# no_trans_mask 3701 3701
# near_trans 3701 3701
# 2503 points in new lightcurve, compared to  15700  in original mask, leaving  2814 points in the lc
# True making tele_index
# [-6.9058285]
# 17024 17337
# ['t2']
# ['t2'] ['t2'] [] [-6.9058285] 17024
# True 0.05 25.258021643512166 1.2437999689483794 5.78885566072571
# 0.0009672642 0.0013959144 1.9589662551879884e-05 0.0013215129729360342
# True 0.015208749999999998
# optimizing logp for variables: [mean, w0, power, logs2]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# message: Optimization terminated successfully.
# logp: -9.974349029343113 -> 4.033678637403016
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [power, w0, logs2, mean]
# Sampling 4 chains, 0 divergences: 100%|██████████| 5976/5976 [00:04<00:00, 1459.21draws/s]
# Forming Pymc3 model with: monos: [] multis: ['01'] duos: []
# init periods: [11.633438] [0.00932994]
# -6.907755278982137 -> 0.22314355131420976 rors: [-2.88963534]
# [-6.9058285] 3388 / 3701
# [False False False ... False False False] [False False False ... False False False] [False False False ... False False False]
# --
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-10-40fcbcdc0b74> in <module>
# ----> 1 outs=mono.MonoVetting(281731203,mission='tess')
#
# ~/Postdoc/MonoTools/MonoTools/MonoSearch.py in MonoVetting(ID, mission, tcen, tdur, overwrite, do_search, do_fit, useL2, PL_ror_thresh, variable_llk_thresh, file_loc, plot, **kwargs)
#    2806                 mod.LoadPickle()
#    2807             if mod is not None and do_fit and (not hasattr(mod,'trace') or overwrites['fit']):
# -> 2808                 mod.RunMcmc()
#    2809                 pickle.dump(mod,open(file_loc+"/"+file_loc.split('/')[-1]+'_model.pickle','wb'))
#    2810
#
# ~/Postdoc/MonoTools/MonoTools/MonoFit.py in RunMcmc(self, n_draws, plot, do_per_gap_cuts, overwrite, **kwargs)
#    1248         if not hasattr(self,'trace') or overwrite:
#    1249             if not hasattr(self,'init_soln'):
# -> 1250                 self.init_model()
#    1251             #Running sampler:
#    1252             np.random.seed(int(self.ID))
#
# ~/Postdoc/MonoTools/MonoTools/MonoFit.py in init_model(self, assume_circ, overwrite, use_GP, train_GP, constrain_LD, ld_mult, useL2, FeH, LoadFromFile, cutDistance, force_match_input, debug, pred_all_time, marginalise_all, use_multinest, use_pymc3, bin_oot, **kwargs)
#     508
#     509         if use_pymc3:
# --> 510             self.init_pymc3()
#     511         elif use_multinest:
#     512             self.run_multinest(**kwargs)
#
# ~/Postdoc/MonoTools/MonoTools/MonoFit.py in init_pymc3(self, ld_mult)
#     942                     # This is the eccentricity prior from Kipping (2013) / https://arxiv.org/abs/1306.4982
#     943                     multi_orbit = xo.orbits.KeplerianOrbit(
# --> 944                         r_star=Rs, rho_star=rho_S,ecc=multi_eccs, omega=multi_omegas,
#     945                         period=multi_periods, t0=multi_t0s, b=multi_bs)
#     946                 print("generating multi lcs:")
#
# UnboundLocalError: local variable 'multi_eccs' referenced before assignment
