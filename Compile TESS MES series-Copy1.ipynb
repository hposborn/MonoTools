# %%
import pandas as pd
import numpy as np

# %%
from NamastePymc3 import NamastePymc3 as namaste

namaste.g141335886

# %%
tce_csvs=pd.read_html('https://archive.stsci.edu/tess/bulk_downloads/bulk_downloads_tce.html')[0]

# %%
for i,row in tce_csvs.iterrows():
    csvs=pd.read_csv('https://archive.stsci.edu/missions/tess/catalogs/tce/'+row[tce_csvs.columns[2]])
    csvs['sector']=i
# Out:
#         TCE Data Validation Statistics: Single Sector  \
#                                          Sector Start
#          TCE Data Validation Statistics: Multi Sector
#                                          Sector Start
# 0                                           Sector 21
# 1                                           Sector 20
# 2                                           Sector 19
# 3                                           Sector 18
# 4                                           Sector 17
# 5                                           Sector 16
# 6                                           Sector 15
# 7                                           Sector 14
# 8                                           Sector 13
# 9                                           Sector 12
# 10                                          Sector 11
# 11                                          Sector 10
# 12                                           Sector 9
# ...
